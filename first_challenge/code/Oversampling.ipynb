# %% [markdown]
# # Notebook description

# %% [markdown]
# In this notebook, before executing each of the K cross-validation steps, we perform **oversampling** on the training set, in order to deal with the problem of class imbalance. By using this techinque, we try to help our BiGRU-based RNN learn how to classify samples belonging to the less frequent classes ("high pain" and "low pain").

# %% [markdown]
# # Google Drive connection

# %%
from google.colab import drive
drive.mount("/gdrive")
current_dir = "/gdrive/My\\ Drive/challengeAN2DL"
# %cd $current_dir
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/.shortcut-targets-by-id/1FBs0a25Urpk8cZPLeXuOnI8nzY3Yx1TA/challengeAN2DL

# %% [markdown]
# # Import libraries

# %%
# Set seed for reproducibility
SEED = 170412

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# # Data loading

# %%
# path to datasets
DATASET_NAME_TRAINING = "an2dl2526c1/pirate_pain_train.csv"
DATASET_NAME_LABELS = "an2dl2526c1/pirate_pain_train_labels.csv"
DATASET_NAME_TEST = "an2dl2526c1/pirate_pain_test.csv"

# datset loading
df = pd.read_csv(DATASET_NAME_TRAINING)
labels = pd.read_csv(DATASET_NAME_LABELS)
df_test = pd.read_csv(DATASET_NAME_TEST)

# %% [markdown]
# # Data preprocessing

# %%
# OVERSAMPLING FUNCTION
# this function randomly duplicates entire sequences belonging to the minority classes, returning a perfectly balanced dataset.

def oversample_sequences_keep_majority(
    df,
    sample_col='sample_index',
    label_col='pain_level',
    random_state=42
):
    rng = np.random.default_rng(random_state)

    # consistency check: each sequence must have timestamps belonging to the same class
    per_seq_label_nunique = df.groupby(sample_col)[label_col].nunique()
    if (per_seq_label_nunique > 1).any():
        bad = per_seq_label_nunique[per_seq_label_nunique > 1].index.tolist()
        raise ValueError(f"Sequenze con label incoerente: {bad}")

    # labels for each sequence
    seq_labels = df.groupby(sample_col)[label_col].first()

    # class frequency computation
    class_counts = seq_labels.value_counts().sort_index()
    print("Class counts (before oversampling):")
    print(class_counts)
    target_per_class = class_counts.max()
    maj_class = class_counts.idxmax()


    dfs = [df]
    next_sample_index = df[sample_col].max() + 1

    # for each minority class, we duplicate random sequences, until we reach a count of "target_per_class" sequences
    for cls, count in class_counts.items():
        if cls == maj_class:
            continue
        deficit = target_per_class - count
        if deficit <= 0:
            continue
        cls_seq_ids = seq_labels[seq_labels == cls].index.to_numpy()
        chosen_ids = rng.choice(cls_seq_ids, size=deficit, replace=True)
        for orig_id in chosen_ids:
            seq_df = df[df[sample_col] == orig_id].copy()
            seq_df[sample_col] = next_sample_index  # nuovo id
            dfs.append(seq_df)
            next_sample_index += 1

    # new oversampled dataset
    df_over = pd.concat(dfs, ignore_index=True)

    # final frequency check
    new_seq_labels = df_over.groupby(sample_col)[label_col].first()
    new_class_counts = new_seq_labels.value_counts().sort_index()
    print("\nClass counts (after oversampling):")
    print(new_class_counts)

    return df_over

# %%
# Drop constant feature "joint_30"
df = df.drop('joint_30', axis=1)
df_test = df_test.drop('joint_30', axis=1)

# Drop dependent features
df = df.drop('n_eyes', axis=1)
df_test = df_test.drop('n_eyes', axis=1)
df = df.drop('n_legs', axis=1)
df_test = df_test.drop('n_legs', axis=1)
df = df.drop('n_hands', axis=1)
df_test = df_test.drop('n_hands', axis=1)

# Transformation to float32 values
for index in range(4):
    i = index + 1
    column = 'pain_survey_' + str(i)
    df[column] = df[column].astype(np.float32)
    df_test[column] = df_test[column].astype(np.float32)
for index in range(30):
    column = 'joint_' + str(index).zfill(2)
    df[column] = df[column].astype(np.float32)
    df_test[column] = df_test[column].astype(np.float32)

# %%
# add labels to train set
df = df.merge(labels, on='sample_index', how='left')
df = df.rename(columns={'label': 'pain_level'})

# select the meaningful features for training (we discard sample index and timestamp)
scale_columns = df.columns[2:-1].tolist()

# %% [markdown]
# # Sequence building

# %%
# define the size of sequences used to train the network
WINDOW_SIZE = 64
# define the stride used to build training sequences starting from the original ones
STRIDE = 16

# %%
# SEQUENCE BUILDING FUNCTION
# for each sequence of the dataframe, this function creates new sequences by adding padding and shifting the window multiple times, depending on the stride.

def build_sequences(df, window=40, stride=40):
    # Sanity check to ensure the window is divisible by the stride
    assert window % stride == 0

    # Initialise lists to store sequences and their corresponding labels
    dataset = []
    labels = []

    # Iterate over unique IDs in the DataFrame
    for id in df['sample_index'].unique():
        # Extract sensor data for the current ID
        temp = df[df['sample_index'] == id][scale_columns].values

        # Retrieve the activity label for the current ID
        label = df[df['sample_index'] == id]['pain_level'].values[0]

        # Calculate padding length to ensure full windows
        padding_len = window - len(temp) % window

        # Create zero padding and concatenate with the data
        padding = np.zeros((padding_len, len(scale_columns)), dtype='float32')
        temp = np.concatenate((temp, padding))

        # Build feature windows and associate them with labels
        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            labels.append(label)
            idx += stride

    # Convert lists to numpy arrays for further processing
    dataset = np.array(dataset)
    labels = np.array(labels)

    return dataset, labels

# %%
# Define the number of samples (sequences) in each batch
BATCH_SIZE = 128

# %%
# this function creates a data loader starting from a dataset, its related batch size and other additional parameters

def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %% [markdown]
# # Model building

# %%
def recurrent_summary(model, input_size):
    """
    Custom summary function that emulates torchinfo's output while correctly
    counting parameters for RNN/GRU/LSTM layers.

    This function is designed for models whose direct children are
    nn.Linear, nn.RNN, nn.GRU, or nn.LSTM layers.

    Args:
        model (nn.Module): The model to analyze.
        input_size (tuple): Shape of the input tensor (e.g., (seq_len, features)).
    """

    # Dictionary to store output shapes captured by forward hooks
    output_shapes = {}
    # List to track hook handles for later removal
    hooks = []

    def get_hook(name):
        """Factory function to create a forward hook for a specific module."""
        def hook(module, input, output):
            # Handle RNN layer outputs (returns a tuple)
            if isinstance(output, tuple):
                # output[0]: all hidden states with shape (batch, seq_len, hidden*directions)
                shape1 = list(output[0].shape)
                shape1[0] = -1  # Replace batch dimension with -1

                # output[1]: final hidden state h_n (or tuple (h_n, c_n) for LSTM)
                if isinstance(output[1], tuple):  # LSTM case: (h_n, c_n)
                    shape2 = list(output[1][0].shape)  # Extract h_n only
                else:  # RNN/GRU case: h_n only
                    shape2 = list(output[1].shape)

                # Replace batch dimension (middle position) with -1
                shape2[1] = -1

                output_shapes[name] = f"[{shape1}, {shape2}]"

            # Handle standard layer outputs (e.g., Linear)
            else:
                shape = list(output.shape)
                shape[0] = -1  # Replace batch dimension with -1
                output_shapes[name] = f"{shape}"
        return hook

    # 1. Determine the device where model parameters reside
    try:
        device = next(model.parameters()).device
    except StopIteration:
        device = torch.device("cpu")  # Fallback for models without parameters

    # 2. Create a dummy input tensor with batch_size=1
    dummy_input = torch.randn(1, *input_size).to(device)

    # 3. Register forward hooks on target layers
    # Iterate through direct children of the model (e.g., self.rnn, self.classifier)
    for name, module in model.named_children():
        if isinstance(module, (nn.Linear, nn.RNN, nn.GRU, nn.LSTM)):
            # Register the hook and store its handle for cleanup
            hook_handle = module.register_forward_hook(get_hook(name))
            hooks.append(hook_handle)

    # 4. Execute a dummy forward pass in evaluation mode
    model.eval()
    with torch.no_grad():
        try:
            model(dummy_input)
        except Exception as e:
            print(f"Error during dummy forward pass: {e}")
            # Clean up hooks even if an error occurs
            for h in hooks:
                h.remove()
            return

    # 5. Remove all registered hooks
    for h in hooks:
        h.remove()

    # --- 6. Print the summary table ---

    print("-" * 79)
    # Column headers
    print(f"{'Layer (type)':<25} {'Output Shape':<28} {'Param #':<18}")
    print("=" * 79)

    total_params = 0
    total_trainable_params = 0

    # Iterate through modules again to collect and display parameter information
    for name, module in model.named_children():
        if name in output_shapes:
            # Count total and trainable parameters for this module
            module_params = sum(p.numel() for p in module.parameters())
            trainable_params = sum(p.numel() for p in module.parameters() if p.requires_grad)

            total_params += module_params
            total_trainable_params += trainable_params

            # Format strings for display
            layer_name = f"{name} ({type(module).__name__})"
            output_shape_str = str(output_shapes[name])
            params_str = f"{trainable_params:,}"

            print(f"{layer_name:<25} {output_shape_str:<28} {params_str:<15}")

    print("=" * 79)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {total_trainable_params:,}")
    print(f"Non-trainable params: {total_params - total_trainable_params:,}")
    print("-" * 79)

# %%
class RecurrentClassifier(nn.Module):
    """
    Generic RNN classifier (RNN, LSTM, GRU).
    Uses the last hidden state for classification.
    """
    def __init__(
            self,
            input_size,
            hidden_size,
            num_layers,
            num_classes,
            rnn_type='GRU',        # 'RNN', 'LSTM', or 'GRU'
            bidirectional=False,
            dropout_rate=0.2
            ):
        super().__init__()

        self.rnn_type = rnn_type
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.bidirectional = bidirectional

        # Map string name to PyTorch RNN class
        rnn_map = {
            'RNN': nn.RNN,
            'LSTM': nn.LSTM,
            'GRU': nn.GRU
        }

        if rnn_type not in rnn_map:
            raise ValueError("rnn_type must be 'RNN', 'LSTM', or 'GRU'")

        rnn_module = rnn_map[rnn_type]

        # Dropout is only applied between layers (if num_layers > 1)
        dropout_val = dropout_rate if num_layers > 1 else 0

        # Create the recurrent layer
        self.rnn = rnn_module(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,       # Input shape: (batch, seq_len, features)
            bidirectional=bidirectional,
            dropout=dropout_val
        )

        # Calculate input size for the final classifier
        if self.bidirectional:
            classifier_input_size = hidden_size * 2 # Concat fwd + bwd
        else:
            classifier_input_size = hidden_size

        self.classifier = nn.Linear(classifier_input_size, num_classes)

    def forward(self, x):
        """
        x shape: (batch_size, seq_length, input_size)
        """

        # rnn_out shape: (batch_size, seq_len, hidden_size * num_directions)
        rnn_out, hidden = self.rnn(x)

        # LSTM returns (h_n, c_n), we only need h_n
        if self.rnn_type == 'LSTM':
            hidden = hidden[0]

        # hidden shape: (num_layers * num_directions, batch_size, hidden_size)

        if self.bidirectional:
            # Reshape to (num_layers, 2, batch_size, hidden_size)
            hidden = hidden.view(self.num_layers, 2, -1, self.hidden_size)

            # Concat last fwd (hidden[-1, 0, ...]) and bwd (hidden[-1, 1, ...])
            # Final shape: (batch_size, hidden_size * 2)
            hidden_to_classify = torch.cat([hidden[-1, 0, :, :], hidden[-1, 1, :, :]], dim=1)
        else:
            # Take the last layer's hidden state
            # Final shape: (batch_size, hidden_size)
            hidden_to_classify = hidden[-1]

        # Get logits
        logits = self.classifier(hidden_to_classify)
        return logits

# %% [markdown]
# # Network and training hyperparameters

# %%
# HYPERPARAMETERS

# Training configuration
LEARNING_RATE = 7e-4
EPOCHS = 300
PATIENCE = 50

# Architecture
HIDDEN_LAYERS = 2        # number of hidden layers
HIDDEN_SIZE = 128       # units per layer

# Regularisation
DROPOUT_RATE = 0.4         # Dropout probability
L1_LAMBDA = 0            # L1 penalty
L2_LAMBDA = 2e-2            # L2 penalty

# Loss function
criterion = nn.CrossEntropyLoss()

# CROSS VALIDATION FOLDS
K = 5

# %% [markdown]
# # Model Training

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """
    Log training metrics and model parameters to TensorBoard for visualization.

    Args:
        writer (SummaryWriter): TensorBoard SummaryWriter object for logging
        epoch (int): Current epoch number (used as x-axis in TensorBoard plots)
        train_loss (float): Training loss for this epoch
        train_f1 (float): Training f1 score for this epoch
        val_loss (float): Validation loss for this epoch
        val_f1 (float): Validation f1 score for this epoch
        model (nn.Module): The neural network model (for logging weights/gradients)

    Note:
        This function logs scalar metrics (loss/f1 score) and histograms of model
        parameters and gradients, which helps monitor training progress and detect
        issues like vanishing/exploding gradients.
    """
    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# # Cross Validation

# %%
def k_shuffle_split_cross_validation_round_rnn(df, train_split_ratio, epochs, criterion, device,
                            k, batch_size, hidden_layers, hidden_size, learning_rate, dropout_rate,
                            bidirectional, rnn_type, l1_lambda=0, l2_lambda=0, patience=0, window_size=WINDOW_SIZE, stride=STRIDE,
                            evaluation_metric="val_f1", mode='max', restore_best_weights=True, writer=None,
                            verbose=10, seed=SEED, experiment_name=""):

    # Initialise containers for results across all splits

    fold_losses = {}
    fold_metrics = {}
    best_scores = {}

    # Retrieve number of input features and number of classes

    scale_columns = df.columns[2:-1].tolist()
    in_features = len(scale_columns)
    num_classes = len(df['pain_level'].unique())

    rnn_model = RecurrentClassifier(
        input_size=in_features,
        hidden_size=hidden_size,
        num_layers=hidden_layers,
        num_classes=num_classes,
        dropout_rate=dropout_rate,
        bidirectional=bidirectional,
        rnn_type=rnn_type
        ).to(device)

    # Store initial weights to reset model for each split
    initial_state = copy.deepcopy(rnn_model.state_dict())

    # Iterate through K random splits
    for split_idx in range(k):

        if verbose > 0:
            print(f"Split {split_idx+1}/{k}")
        # Create random split

        unique_pirates = df['sample_index'].unique()
        random.seed(seed + split_idx) # Different shuffle for every index
        random.shuffle(unique_pirates)

        N_TRAIN_PIRATES = int(len(unique_pirates) * train_split_ratio)
        N_VAL_PIRATES = len(unique_pirates) - N_TRAIN_PIRATES

        train_pirates = unique_pirates[:N_TRAIN_PIRATES]
        val_pirates = unique_pirates[N_TRAIN_PIRATES:]

        df_train = df[df['sample_index'].isin(train_pirates)].copy()
        df_train = oversample_sequences_keep_majority(df_train,sample_col='sample_index',label_col='pain_level',random_state=SEED)
        N_TRAIN_PIRATES = int(len(df_train['sample_index'].unique()))
        df_val = df[df['sample_index'].isin(val_pirates)].copy()

        label_mapping = {
            'no_pain': 0,
            'low_pain': 1,
            'high_pain': 2
        }

        df_train['pain_level'] = df_train['pain_level'].map(label_mapping)

        df_val['pain_level'] = df_val['pain_level'].map(label_mapping)

        # Calculate the minimum and maximum values from the training data only
        mins = df_train[scale_columns].min()
        maxs = df_train[scale_columns].max()

        # Apply normalisation to the specified columns in all datasets
        for column in scale_columns:
            # Normalise the training set
            df_train[column] = (df_train[column] - mins[column]) / (maxs[column] - mins[column])

            # Normalise the validation set
            df_val[column] = (df_val[column] - mins[column]) / (maxs[column] - mins[column])


        # Build sequences
        X_train, y_train = build_sequences(df_train, window_size, stride)
        X_val, y_val = build_sequences(df_val, window_size, stride)

        # Create PyTorch datasets
        train_ds = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
        val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val))

        # Create data loaders
        train_loader = make_loader(train_ds, batch_size=batch_size, shuffle=True, drop_last=False)
        val_loader   = make_loader(val_ds, batch_size=batch_size, shuffle=False, drop_last=False)

        # Reset model to initial weights for fair comparison across splits
        rnn_model.load_state_dict(initial_state)

        optimizer = torch.optim.AdamW(rnn_model.parameters(), lr=learning_rate, weight_decay=l2_lambda)

        # Enable mixed precision training for GPU acceleration
        scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

        # Create directory for model checkpoints

        os.makedirs(f"models/{experiment_name}", exist_ok=True)

        # Train model on current split
        rnn_model, training_history = fit(
            model=rnn_model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=epochs,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            device=device,
            writer=writer,
            patience=patience,
            verbose=verbose,
            experiment_name=experiment_name+"/split_"+str(split_idx),
            l1_lambda=l1_lambda,
            evaluation_metric=evaluation_metric,
            mode=mode,
            restore_best_weights=restore_best_weights,
            )

        # Store results for this split
        fold_losses[f"split_{split_idx}"] = training_history['val_loss']
        fold_metrics[f"split_{split_idx}"] = training_history['val_f1']
        best_scores[f"split_{split_idx}"] = max(training_history['val_f1'])

    # Compute mean and standard deviation of best scores across splits
    best_scores["mean"] = np.mean([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])
    best_scores["std"] = np.std([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])

    if verbose > 0:
        print(f"Best score: {best_scores['mean']:.4f}±{best_scores['std']:.4f}")

    return fold_losses, fold_metrics, best_scores

# %%
# CALL TO CROSS-VALIDATION METHOD
# %%time
# Execute K-fold cross-validation with desired configuration
losses, metrics, best_scores = k_shuffle_split_cross_validation_round_rnn(
    df=df,
    train_split_ratio=0.8,
    epochs=EPOCHS,
    criterion=criterion,
    device=device,
    k=K,
    batch_size=BATCH_SIZE,
    hidden_layers=HIDDEN_LAYERS,
    hidden_size=HIDDEN_SIZE,
    learning_rate=LEARNING_RATE,
    dropout_rate=DROPOUT_RATE,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    verbose=1,
    patience=PATIENCE,
    seed=SEED,
    experiment_name="oversampling",
    window_size=WINDOW_SIZE,
    stride=STRIDE,
    rnn_type="GRU",
    bidirectional=True
)
# Out:
# Split 1/5
# Class counts (before oversampling):
# pain_level
# high_pain     48
# low_pain      74
# no_pain      406
# Name: count, dtype: int64
#
# Class counts (after oversampling):
# pain_level
# high_pain    406
# low_pain     406
# no_pain      406
# Name: count, dtype: int64
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9700, F1 Score=0.5047 | Val: Loss=0.6655, F1 Score=0.7881
# Epoch   2/300 | Train: Loss=0.7840, F1 Score=0.6376 | Val: Loss=0.6174, F1 Score=0.7985
# Epoch   3/300 | Train: Loss=0.5841, F1 Score=0.7581 | Val: Loss=0.5949, F1 Score=0.8084
# Epoch   4/300 | Train: Loss=0.4398, F1 Score=0.8313 | Val: Loss=0.4780, F1 Score=0.8446
# Epoch   5/300 | Train: Loss=0.3535, F1 Score=0.8622 | Val: Loss=0.4155, F1 Score=0.8529
# Epoch   6/300 | Train: Loss=0.2640, F1 Score=0.9024 | Val: Loss=0.3350, F1 Score=0.8848
# Epoch   7/300 | Train: Loss=0.2542, F1 Score=0.9065 | Val: Loss=0.3713, F1 Score=0.8927
# Epoch   8/300 | Train: Loss=0.2046, F1 Score=0.9249 | Val: Loss=0.2931, F1 Score=0.9150
# Epoch   9/300 | Train: Loss=0.1760, F1 Score=0.9361 | Val: Loss=0.2298, F1 Score=0.9300
# Epoch  10/300 | Train: Loss=0.1692, F1 Score=0.9354 | Val: Loss=0.2872, F1 Score=0.9264
# Epoch  11/300 | Train: Loss=0.1318, F1 Score=0.9518 | Val: Loss=0.2511, F1 Score=0.9425
# Epoch  12/300 | Train: Loss=0.1447, F1 Score=0.9473 | Val: Loss=0.2905, F1 Score=0.9198
# Epoch  13/300 | Train: Loss=0.0988, F1 Score=0.9646 | Val: Loss=0.6259, F1 Score=0.8115
# Epoch  14/300 | Train: Loss=0.1281, F1 Score=0.9534 | Val: Loss=0.2501, F1 Score=0.9297
# Epoch  15/300 | Train: Loss=0.0951, F1 Score=0.9649 | Val: Loss=0.1814, F1 Score=0.9633
# Epoch  16/300 | Train: Loss=0.0873, F1 Score=0.9681 | Val: Loss=0.2640, F1 Score=0.9368
# Epoch  17/300 | Train: Loss=0.0887, F1 Score=0.9669 | Val: Loss=0.2352, F1 Score=0.9480
# Epoch  18/300 | Train: Loss=0.0608, F1 Score=0.9781 | Val: Loss=0.2389, F1 Score=0.9482
# Epoch  19/300 | Train: Loss=0.0593, F1 Score=0.9801 | Val: Loss=0.2683, F1 Score=0.9453
# Epoch  20/300 | Train: Loss=0.0938, F1 Score=0.9670 | Val: Loss=0.2510, F1 Score=0.9414
# Epoch  21/300 | Train: Loss=0.0564, F1 Score=0.9805 | Val: Loss=0.2574, F1 Score=0.9427
# Epoch  22/300 | Train: Loss=0.0742, F1 Score=0.9741 | Val: Loss=0.2352, F1 Score=0.9538
# Epoch  23/300 | Train: Loss=0.0772, F1 Score=0.9759 | Val: Loss=0.2193, F1 Score=0.9543
# Epoch  24/300 | Train: Loss=0.0554, F1 Score=0.9817 | Val: Loss=0.1536, F1 Score=0.9584
# Epoch  25/300 | Train: Loss=0.0629, F1 Score=0.9783 | Val: Loss=0.2675, F1 Score=0.9401
# Epoch  26/300 | Train: Loss=0.0475, F1 Score=0.9830 | Val: Loss=0.2682, F1 Score=0.9296
# Epoch  27/300 | Train: Loss=0.0466, F1 Score=0.9828 | Val: Loss=0.2366, F1 Score=0.9565
# Epoch  28/300 | Train: Loss=0.0359, F1 Score=0.9871 | Val: Loss=0.2420, F1 Score=0.9563
# Epoch  29/300 | Train: Loss=0.0506, F1 Score=0.9829 | Val: Loss=0.3296, F1 Score=0.9307
# Epoch  30/300 | Train: Loss=0.0546, F1 Score=0.9818 | Val: Loss=0.2235, F1 Score=0.9611
# Epoch  31/300 | Train: Loss=0.0235, F1 Score=0.9929 | Val: Loss=0.2355, F1 Score=0.9596
# Epoch  32/300 | Train: Loss=0.0448, F1 Score=0.9852 | Val: Loss=0.2894, F1 Score=0.9368
# Epoch  33/300 | Train: Loss=0.0336, F1 Score=0.9881 | Val: Loss=0.2434, F1 Score=0.9500
# Epoch  34/300 | Train: Loss=0.0223, F1 Score=0.9922 | Val: Loss=0.2230, F1 Score=0.9553
# Epoch  35/300 | Train: Loss=0.0316, F1 Score=0.9890 | Val: Loss=0.2063, F1 Score=0.9593
# Epoch  36/300 | Train: Loss=0.0217, F1 Score=0.9927 | Val: Loss=0.3103, F1 Score=0.9351
# Epoch  37/300 | Train: Loss=0.0380, F1 Score=0.9844 | Val: Loss=0.2884, F1 Score=0.9390
# Epoch  38/300 | Train: Loss=0.0236, F1 Score=0.9918 | Val: Loss=0.2501, F1 Score=0.9536
# Epoch  39/300 | Train: Loss=0.0123, F1 Score=0.9962 | Val: Loss=0.2981, F1 Score=0.9377
# Epoch  40/300 | Train: Loss=0.0723, F1 Score=0.9774 | Val: Loss=0.3010, F1 Score=0.9296
# Epoch  41/300 | Train: Loss=0.0568, F1 Score=0.9838 | Val: Loss=0.2146, F1 Score=0.9546
# Epoch  42/300 | Train: Loss=0.0219, F1 Score=0.9921 | Val: Loss=0.1940, F1 Score=0.9611
# Epoch  43/300 | Train: Loss=0.0464, F1 Score=0.9849 | Val: Loss=0.2505, F1 Score=0.9427
# Epoch  44/300 | Train: Loss=0.0201, F1 Score=0.9943 | Val: Loss=0.2107, F1 Score=0.9588
# Epoch  45/300 | Train: Loss=0.0137, F1 Score=0.9954 | Val: Loss=0.2459, F1 Score=0.9546
# Epoch  46/300 | Train: Loss=0.0142, F1 Score=0.9952 | Val: Loss=0.2156, F1 Score=0.9668
# Epoch  47/300 | Train: Loss=0.0080, F1 Score=0.9980 | Val: Loss=0.2708, F1 Score=0.9498
# Epoch  48/300 | Train: Loss=0.0111, F1 Score=0.9954 | Val: Loss=0.2448, F1 Score=0.9621
# Epoch  49/300 | Train: Loss=0.0252, F1 Score=0.9917 | Val: Loss=0.2747, F1 Score=0.9494
# Epoch  50/300 | Train: Loss=0.0230, F1 Score=0.9920 | Val: Loss=0.2259, F1 Score=0.9669
# Epoch  51/300 | Train: Loss=0.0115, F1 Score=0.9969 | Val: Loss=0.2899, F1 Score=0.9417
# Epoch  52/300 | Train: Loss=0.0560, F1 Score=0.9813 | Val: Loss=0.5301, F1 Score=0.8886
# Epoch  53/300 | Train: Loss=0.0361, F1 Score=0.9877 | Val: Loss=0.1994, F1 Score=0.9606
# Epoch  54/300 | Train: Loss=0.0175, F1 Score=0.9948 | Val: Loss=0.2904, F1 Score=0.9457
# Epoch  55/300 | Train: Loss=0.0212, F1 Score=0.9927 | Val: Loss=0.2494, F1 Score=0.9569
# Epoch  56/300 | Train: Loss=0.0091, F1 Score=0.9973 | Val: Loss=0.2597, F1 Score=0.9577
# Epoch  57/300 | Train: Loss=0.0112, F1 Score=0.9968 | Val: Loss=0.2676, F1 Score=0.9464
# Epoch  58/300 | Train: Loss=0.0363, F1 Score=0.9872 | Val: Loss=0.2469, F1 Score=0.9546
# Epoch  59/300 | Train: Loss=0.0210, F1 Score=0.9935 | Val: Loss=0.2447, F1 Score=0.9601
# Epoch  60/300 | Train: Loss=0.0087, F1 Score=0.9970 | Val: Loss=0.4557, F1 Score=0.8980
# Epoch  61/300 | Train: Loss=0.0166, F1 Score=0.9943 | Val: Loss=0.2921, F1 Score=0.9541
# Epoch  62/300 | Train: Loss=0.0095, F1 Score=0.9971 | Val: Loss=0.2747, F1 Score=0.9539
# Epoch  63/300 | Train: Loss=0.0110, F1 Score=0.9964 | Val: Loss=0.2813, F1 Score=0.9555
# Epoch  64/300 | Train: Loss=0.0061, F1 Score=0.9981 | Val: Loss=0.3431, F1 Score=0.9520
# Epoch  65/300 | Train: Loss=0.0161, F1 Score=0.9943 | Val: Loss=0.3294, F1 Score=0.9404
# Epoch  66/300 | Train: Loss=0.0331, F1 Score=0.9902 | Val: Loss=0.2514, F1 Score=0.9558
# Epoch  67/300 | Train: Loss=0.0324, F1 Score=0.9899 | Val: Loss=0.2379, F1 Score=0.9487
# Epoch  68/300 | Train: Loss=0.0109, F1 Score=0.9964 | Val: Loss=0.2969, F1 Score=0.9476
# Epoch  69/300 | Train: Loss=0.0079, F1 Score=0.9976 | Val: Loss=0.2514, F1 Score=0.9593
# Epoch  70/300 | Train: Loss=0.0041, F1 Score=0.9988 | Val: Loss=0.2545, F1 Score=0.9650
# Epoch  71/300 | Train: Loss=0.0057, F1 Score=0.9984 | Val: Loss=0.2836, F1 Score=0.9532
# Epoch  72/300 | Train: Loss=0.0059, F1 Score=0.9984 | Val: Loss=0.2966, F1 Score=0.9580
# Epoch  73/300 | Train: Loss=0.0496, F1 Score=0.9829 | Val: Loss=0.2551, F1 Score=0.9617
# Epoch  74/300 | Train: Loss=0.0070, F1 Score=0.9981 | Val: Loss=0.2815, F1 Score=0.9582
# Epoch  75/300 | Train: Loss=0.0051, F1 Score=0.9986 | Val: Loss=0.2827, F1 Score=0.9581
# Epoch  76/300 | Train: Loss=0.0119, F1 Score=0.9960 | Val: Loss=0.3174, F1 Score=0.9502
# Epoch  77/300 | Train: Loss=0.0137, F1 Score=0.9953 | Val: Loss=0.2391, F1 Score=0.9558
# Epoch  78/300 | Train: Loss=0.0458, F1 Score=0.9853 | Val: Loss=0.2706, F1 Score=0.9549
# Epoch  79/300 | Train: Loss=0.0068, F1 Score=0.9979 | Val: Loss=0.2417, F1 Score=0.9608
# Epoch  80/300 | Train: Loss=0.0050, F1 Score=0.9985 | Val: Loss=0.2175, F1 Score=0.9604
# Epoch  81/300 | Train: Loss=0.0034, F1 Score=0.9994 | Val: Loss=0.2655, F1 Score=0.9586
# Epoch  82/300 | Train: Loss=0.0023, F1 Score=0.9994 | Val: Loss=0.2658, F1 Score=0.9619
# Epoch  83/300 | Train: Loss=0.0020, F1 Score=0.9995 | Val: Loss=0.3281, F1 Score=0.9443
# Epoch  84/300 | Train: Loss=0.0804, F1 Score=0.9754 | Val: Loss=0.2655, F1 Score=0.9508
# Epoch  85/300 | Train: Loss=0.0079, F1 Score=0.9981 | Val: Loss=0.2365, F1 Score=0.9578
# Epoch  86/300 | Train: Loss=0.0027, F1 Score=0.9995 | Val: Loss=0.2496, F1 Score=0.9604
# Epoch  87/300 | Train: Loss=0.0016, F1 Score=0.9997 | Val: Loss=0.2722, F1 Score=0.9559
# Epoch  88/300 | Train: Loss=0.0082, F1 Score=0.9977 | Val: Loss=0.2427, F1 Score=0.9530
# Epoch  89/300 | Train: Loss=0.0027, F1 Score=0.9993 | Val: Loss=0.2385, F1 Score=0.9604
# Epoch  90/300 | Train: Loss=0.0022, F1 Score=0.9994 | Val: Loss=0.2745, F1 Score=0.9543
# Epoch  91/300 | Train: Loss=0.0016, F1 Score=0.9998 | Val: Loss=0.2788, F1 Score=0.9566
# Epoch  92/300 | Train: Loss=0.0016, F1 Score=0.9995 | Val: Loss=0.3028, F1 Score=0.9587
# Epoch  93/300 | Train: Loss=0.0195, F1 Score=0.9927 | Val: Loss=0.2502, F1 Score=0.9592
# Epoch  94/300 | Train: Loss=0.0193, F1 Score=0.9936 | Val: Loss=0.2290, F1 Score=0.9497
# Epoch  95/300 | Train: Loss=0.0062, F1 Score=0.9979 | Val: Loss=0.2884, F1 Score=0.9535
# Epoch  96/300 | Train: Loss=0.0017, F1 Score=0.9997 | Val: Loss=0.2661, F1 Score=0.9564
# Epoch  97/300 | Train: Loss=0.0009, F1 Score=0.9998 | Val: Loss=0.2847, F1 Score=0.9601
# Epoch  98/300 | Train: Loss=0.0009, F1 Score=0.9997 | Val: Loss=0.2903, F1 Score=0.9585
# Epoch  99/300 | Train: Loss=0.0056, F1 Score=0.9984 | Val: Loss=0.2740, F1 Score=0.9595
# Epoch 100/300 | Train: Loss=0.0191, F1 Score=0.9933 | Val: Loss=0.3102, F1 Score=0.9341
# Early stopping triggered after 100 epochs.
# Best model restored from epoch 50 with val_f1 0.9669
# Split 2/5
# Class counts (before oversampling):
# pain_level
# high_pain     47
# low_pain      78
# no_pain      403
# Name: count, dtype: int64
#
# Class counts (after oversampling):
# pain_level
# high_pain    403
# low_pain     403
# no_pain      403
# Name: count, dtype: int64
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9628, F1 Score=0.5065 | Val: Loss=0.7984, F1 Score=0.7716
# Epoch   2/300 | Train: Loss=0.7715, F1 Score=0.6451 | Val: Loss=0.7811, F1 Score=0.8044
# Epoch   3/300 | Train: Loss=0.5624, F1 Score=0.7781 | Val: Loss=0.5719, F1 Score=0.8203
# Epoch   4/300 | Train: Loss=0.4280, F1 Score=0.8403 | Val: Loss=0.4159, F1 Score=0.8930
# Epoch   5/300 | Train: Loss=0.3786, F1 Score=0.8614 | Val: Loss=0.4246, F1 Score=0.8833
# Epoch   6/300 | Train: Loss=0.3002, F1 Score=0.8880 | Val: Loss=0.4675, F1 Score=0.8540
# Epoch   7/300 | Train: Loss=0.2880, F1 Score=0.8953 | Val: Loss=0.3816, F1 Score=0.8947
# Epoch   8/300 | Train: Loss=0.2282, F1 Score=0.9190 | Val: Loss=0.4633, F1 Score=0.8307
# Epoch   9/300 | Train: Loss=0.2207, F1 Score=0.9221 | Val: Loss=0.2687, F1 Score=0.9306
# Epoch  10/300 | Train: Loss=0.2306, F1 Score=0.9151 | Val: Loss=0.2937, F1 Score=0.9219
# Epoch  11/300 | Train: Loss=0.1764, F1 Score=0.9378 | Val: Loss=0.4209, F1 Score=0.8838
# Epoch  12/300 | Train: Loss=0.1497, F1 Score=0.9466 | Val: Loss=0.3319, F1 Score=0.9043
# Epoch  13/300 | Train: Loss=0.1329, F1 Score=0.9529 | Val: Loss=0.3272, F1 Score=0.9125
# Epoch  14/300 | Train: Loss=0.1267, F1 Score=0.9548 | Val: Loss=0.2650, F1 Score=0.9240
# Epoch  15/300 | Train: Loss=0.1742, F1 Score=0.9374 | Val: Loss=0.2331, F1 Score=0.9322
# Epoch  16/300 | Train: Loss=0.2302, F1 Score=0.9252 | Val: Loss=0.2353, F1 Score=0.9294
# Epoch  17/300 | Train: Loss=0.1013, F1 Score=0.9649 | Val: Loss=0.2842, F1 Score=0.9203
# Epoch  18/300 | Train: Loss=0.0924, F1 Score=0.9668 | Val: Loss=0.2104, F1 Score=0.9446
# Epoch  19/300 | Train: Loss=0.0877, F1 Score=0.9685 | Val: Loss=0.2485, F1 Score=0.9322
# Epoch  20/300 | Train: Loss=0.0700, F1 Score=0.9748 | Val: Loss=0.2607, F1 Score=0.9310
# Epoch  21/300 | Train: Loss=0.0984, F1 Score=0.9641 | Val: Loss=0.2150, F1 Score=0.9457
# Epoch  22/300 | Train: Loss=0.1027, F1 Score=0.9621 | Val: Loss=0.2680, F1 Score=0.9146
# Epoch  23/300 | Train: Loss=0.0796, F1 Score=0.9711 | Val: Loss=0.2591, F1 Score=0.9401
# Epoch  24/300 | Train: Loss=0.0770, F1 Score=0.9725 | Val: Loss=0.2413, F1 Score=0.9519
# Epoch  25/300 | Train: Loss=0.0786, F1 Score=0.9719 | Val: Loss=0.2315, F1 Score=0.9319
# Epoch  26/300 | Train: Loss=0.0645, F1 Score=0.9773 | Val: Loss=0.2326, F1 Score=0.9447
# Epoch  27/300 | Train: Loss=0.0473, F1 Score=0.9837 | Val: Loss=0.2438, F1 Score=0.9392
# Epoch  28/300 | Train: Loss=0.0385, F1 Score=0.9863 | Val: Loss=0.2306, F1 Score=0.9497
# Epoch  29/300 | Train: Loss=0.0454, F1 Score=0.9847 | Val: Loss=0.3362, F1 Score=0.9241
# Epoch  30/300 | Train: Loss=0.0350, F1 Score=0.9884 | Val: Loss=0.2365, F1 Score=0.9581
# Epoch  31/300 | Train: Loss=0.0831, F1 Score=0.9732 | Val: Loss=0.2194, F1 Score=0.9488
# Epoch  32/300 | Train: Loss=0.0305, F1 Score=0.9901 | Val: Loss=0.2435, F1 Score=0.9452
# Epoch  33/300 | Train: Loss=0.0243, F1 Score=0.9926 | Val: Loss=0.2723, F1 Score=0.9448
# Epoch  34/300 | Train: Loss=0.0535, F1 Score=0.9804 | Val: Loss=0.2592, F1 Score=0.9364
# Epoch  35/300 | Train: Loss=0.0285, F1 Score=0.9906 | Val: Loss=0.2262, F1 Score=0.9476
# Epoch  36/300 | Train: Loss=0.0185, F1 Score=0.9941 | Val: Loss=0.2509, F1 Score=0.9464
# Epoch  37/300 | Train: Loss=0.0520, F1 Score=0.9822 | Val: Loss=0.2111, F1 Score=0.9493
# Epoch  38/300 | Train: Loss=0.0328, F1 Score=0.9890 | Val: Loss=0.2676, F1 Score=0.9503
# Epoch  39/300 | Train: Loss=0.0199, F1 Score=0.9928 | Val: Loss=0.3222, F1 Score=0.9405
# Epoch  40/300 | Train: Loss=0.0221, F1 Score=0.9926 | Val: Loss=0.2518, F1 Score=0.9545
# Epoch  41/300 | Train: Loss=0.0664, F1 Score=0.9779 | Val: Loss=0.3463, F1 Score=0.9236
# Epoch  42/300 | Train: Loss=0.0424, F1 Score=0.9882 | Val: Loss=0.2654, F1 Score=0.9442
# Epoch  43/300 | Train: Loss=0.0341, F1 Score=0.9893 | Val: Loss=0.2523, F1 Score=0.9440
# Epoch  44/300 | Train: Loss=0.0139, F1 Score=0.9968 | Val: Loss=0.2309, F1 Score=0.9550
# Epoch  45/300 | Train: Loss=0.0254, F1 Score=0.9921 | Val: Loss=0.3137, F1 Score=0.9349
# Epoch  46/300 | Train: Loss=0.0595, F1 Score=0.9805 | Val: Loss=0.2582, F1 Score=0.9437
# Epoch  47/300 | Train: Loss=0.0168, F1 Score=0.9949 | Val: Loss=0.2702, F1 Score=0.9519
# Epoch  48/300 | Train: Loss=0.0136, F1 Score=0.9955 | Val: Loss=0.2485, F1 Score=0.9561
# Epoch  49/300 | Train: Loss=0.0079, F1 Score=0.9982 | Val: Loss=0.2642, F1 Score=0.9506
# Epoch  50/300 | Train: Loss=0.0144, F1 Score=0.9948 | Val: Loss=0.2486, F1 Score=0.9467
# Epoch  51/300 | Train: Loss=0.0412, F1 Score=0.9868 | Val: Loss=0.2549, F1 Score=0.9441
# Epoch  52/300 | Train: Loss=0.0074, F1 Score=0.9979 | Val: Loss=0.2676, F1 Score=0.9511
# Epoch  53/300 | Train: Loss=0.0227, F1 Score=0.9945 | Val: Loss=0.2385, F1 Score=0.9433
# Epoch  54/300 | Train: Loss=0.0222, F1 Score=0.9927 | Val: Loss=0.2669, F1 Score=0.9486
# Epoch  55/300 | Train: Loss=0.0143, F1 Score=0.9956 | Val: Loss=0.2750, F1 Score=0.9456
# Epoch  56/300 | Train: Loss=0.0102, F1 Score=0.9965 | Val: Loss=0.3216, F1 Score=0.9371
# Epoch  57/300 | Train: Loss=0.0645, F1 Score=0.9798 | Val: Loss=0.2535, F1 Score=0.9483
# Epoch  58/300 | Train: Loss=0.0117, F1 Score=0.9962 | Val: Loss=0.2283, F1 Score=0.9563
# Epoch  59/300 | Train: Loss=0.0094, F1 Score=0.9975 | Val: Loss=0.2561, F1 Score=0.9514
# Epoch  60/300 | Train: Loss=0.0041, F1 Score=0.9988 | Val: Loss=0.2721, F1 Score=0.9590
# Epoch  61/300 | Train: Loss=0.0015, F1 Score=0.9999 | Val: Loss=0.2905, F1 Score=0.9555
# Epoch  62/300 | Train: Loss=0.0157, F1 Score=0.9946 | Val: Loss=0.2458, F1 Score=0.9496
# Epoch  63/300 | Train: Loss=0.0078, F1 Score=0.9979 | Val: Loss=0.3036, F1 Score=0.9537
# Epoch  64/300 | Train: Loss=0.0094, F1 Score=0.9972 | Val: Loss=0.4022, F1 Score=0.9278
# Epoch  65/300 | Train: Loss=0.0406, F1 Score=0.9869 | Val: Loss=0.3082, F1 Score=0.9511
# Epoch  66/300 | Train: Loss=0.0060, F1 Score=0.9983 | Val: Loss=0.2679, F1 Score=0.9555
# Epoch  67/300 | Train: Loss=0.0040, F1 Score=0.9988 | Val: Loss=0.2998, F1 Score=0.9566
# Epoch  68/300 | Train: Loss=0.0289, F1 Score=0.9902 | Val: Loss=0.3516, F1 Score=0.9381
# Epoch  69/300 | Train: Loss=0.0138, F1 Score=0.9953 | Val: Loss=0.3273, F1 Score=0.9513
# Epoch  70/300 | Train: Loss=0.0776, F1 Score=0.9744 | Val: Loss=0.2301, F1 Score=0.9545
# Epoch  71/300 | Train: Loss=0.0071, F1 Score=0.9985 | Val: Loss=0.2151, F1 Score=0.9554
# Epoch  72/300 | Train: Loss=0.0029, F1 Score=0.9996 | Val: Loss=0.2229, F1 Score=0.9584
# Epoch  73/300 | Train: Loss=0.0032, F1 Score=0.9994 | Val: Loss=0.2440, F1 Score=0.9462
# Epoch  74/300 | Train: Loss=0.0019, F1 Score=0.9998 | Val: Loss=0.2580, F1 Score=0.9540
# Epoch  75/300 | Train: Loss=0.0064, F1 Score=0.9977 | Val: Loss=0.4738, F1 Score=0.9098
# Epoch  76/300 | Train: Loss=0.0124, F1 Score=0.9964 | Val: Loss=0.2183, F1 Score=0.9649
# Epoch  77/300 | Train: Loss=0.0049, F1 Score=0.9986 | Val: Loss=0.2404, F1 Score=0.9568
# Epoch  78/300 | Train: Loss=0.0035, F1 Score=0.9989 | Val: Loss=0.2724, F1 Score=0.9614
# Epoch  79/300 | Train: Loss=0.0303, F1 Score=0.9915 | Val: Loss=0.5182, F1 Score=0.9036
# Epoch  80/300 | Train: Loss=0.0304, F1 Score=0.9907 | Val: Loss=0.3354, F1 Score=0.9410
# Epoch  81/300 | Train: Loss=0.0038, F1 Score=0.9994 | Val: Loss=0.2825, F1 Score=0.9520
# Epoch  82/300 | Train: Loss=0.0057, F1 Score=0.9986 | Val: Loss=0.2832, F1 Score=0.9518
# Epoch  83/300 | Train: Loss=0.0026, F1 Score=0.9993 | Val: Loss=0.3052, F1 Score=0.9474
# Epoch  84/300 | Train: Loss=0.0017, F1 Score=0.9997 | Val: Loss=0.3227, F1 Score=0.9452
# Epoch  85/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=0.3175, F1 Score=0.9478
# Epoch  86/300 | Train: Loss=0.0006, F1 Score=0.9999 | Val: Loss=0.3986, F1 Score=0.9476
# Epoch  87/300 | Train: Loss=0.0053, F1 Score=0.9983 | Val: Loss=0.4126, F1 Score=0.9414
# Epoch  88/300 | Train: Loss=0.0855, F1 Score=0.9744 | Val: Loss=0.2738, F1 Score=0.9470
# Epoch  89/300 | Train: Loss=0.0187, F1 Score=0.9940 | Val: Loss=0.5084, F1 Score=0.9122
# Epoch  90/300 | Train: Loss=0.0128, F1 Score=0.9974 | Val: Loss=0.3163, F1 Score=0.9497
# Epoch  91/300 | Train: Loss=0.0028, F1 Score=0.9994 | Val: Loss=0.3091, F1 Score=0.9523
# Epoch  92/300 | Train: Loss=0.0061, F1 Score=0.9983 | Val: Loss=0.3644, F1 Score=0.9380
# Epoch  93/300 | Train: Loss=0.0023, F1 Score=0.9997 | Val: Loss=0.3108, F1 Score=0.9525
# Epoch  94/300 | Train: Loss=0.0006, F1 Score=1.0000 | Val: Loss=0.3253, F1 Score=0.9518
# Epoch  95/300 | Train: Loss=0.0011, F1 Score=0.9999 | Val: Loss=0.3314, F1 Score=0.9524
# Epoch  96/300 | Train: Loss=0.0005, F1 Score=1.0000 | Val: Loss=0.3569, F1 Score=0.9448
# Epoch  97/300 | Train: Loss=0.0009, F1 Score=0.9999 | Val: Loss=0.4369, F1 Score=0.9314
# Epoch  98/300 | Train: Loss=0.0449, F1 Score=0.9863 | Val: Loss=0.2144, F1 Score=0.9541
# Epoch  99/300 | Train: Loss=0.0030, F1 Score=0.9997 | Val: Loss=0.2931, F1 Score=0.9507
# Epoch 100/300 | Train: Loss=0.0008, F1 Score=1.0000 | Val: Loss=0.3009, F1 Score=0.9499
# Epoch 101/300 | Train: Loss=0.0006, F1 Score=1.0000 | Val: Loss=0.3049, F1 Score=0.9499
# Epoch 102/300 | Train: Loss=0.0005, F1 Score=1.0000 | Val: Loss=0.3342, F1 Score=0.9477
# Epoch 103/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.3166, F1 Score=0.9500
# Epoch 104/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.3339, F1 Score=0.9485
# Epoch 105/300 | Train: Loss=0.0030, F1 Score=0.9992 | Val: Loss=0.3052, F1 Score=0.9559
# Epoch 106/300 | Train: Loss=0.0236, F1 Score=0.9919 | Val: Loss=0.3832, F1 Score=0.9355
# Epoch 107/300 | Train: Loss=0.0025, F1 Score=0.9995 | Val: Loss=0.3225, F1 Score=0.9477
# Epoch 108/300 | Train: Loss=0.0010, F1 Score=0.9999 | Val: Loss=0.3423, F1 Score=0.9482
# Epoch 109/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.3471, F1 Score=0.9459
# Epoch 110/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.3632, F1 Score=0.9461
# Epoch 111/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.3609, F1 Score=0.9468
# Epoch 112/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.3644, F1 Score=0.9468
# Epoch 113/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.3766, F1 Score=0.9476
# Epoch 114/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.3735, F1 Score=0.9468
# Epoch 115/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.3621, F1 Score=0.9475
# Epoch 116/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.3867, F1 Score=0.9476
# Epoch 117/300 | Train: Loss=0.1200, F1 Score=0.9640 | Val: Loss=0.2784, F1 Score=0.9237
# Epoch 118/300 | Train: Loss=0.0321, F1 Score=0.9903 | Val: Loss=0.3053, F1 Score=0.9398
# Epoch 119/300 | Train: Loss=0.0148, F1 Score=0.9962 | Val: Loss=0.2213, F1 Score=0.9445
# Epoch 120/300 | Train: Loss=0.0170, F1 Score=0.9952 | Val: Loss=0.4334, F1 Score=0.9123
# Epoch 121/300 | Train: Loss=0.0396, F1 Score=0.9873 | Val: Loss=0.2095, F1 Score=0.9509
# Epoch 122/300 | Train: Loss=0.0043, F1 Score=0.9992 | Val: Loss=0.1818, F1 Score=0.9612
# Epoch 123/300 | Train: Loss=0.0018, F1 Score=0.9999 | Val: Loss=0.1961, F1 Score=0.9605
# Epoch 124/300 | Train: Loss=0.0016, F1 Score=0.9998 | Val: Loss=0.2032, F1 Score=0.9612
# Epoch 125/300 | Train: Loss=0.0009, F1 Score=1.0000 | Val: Loss=0.2290, F1 Score=0.9565
# Epoch 126/300 | Train: Loss=0.0007, F1 Score=1.0000 | Val: Loss=0.2437, F1 Score=0.9556
# Early stopping triggered after 126 epochs.
# Best model restored from epoch 76 with val_f1 0.9649
# Split 3/5
# Class counts (before oversampling):
# pain_level
# high_pain     45
# low_pain      75
# no_pain      408
# Name: count, dtype: int64
#
# Class counts (after oversampling):
# pain_level
# high_pain    408
# low_pain     408
# no_pain      408
# Name: count, dtype: int64
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9374, F1 Score=0.5428 | Val: Loss=1.0821, F1 Score=0.5717
# Epoch   2/300 | Train: Loss=0.6992, F1 Score=0.7133 | Val: Loss=0.4788, F1 Score=0.8492
# Epoch   3/300 | Train: Loss=0.5386, F1 Score=0.7883 | Val: Loss=0.7981, F1 Score=0.7366
# Epoch   4/300 | Train: Loss=0.4218, F1 Score=0.8419 | Val: Loss=0.9702, F1 Score=0.6899
# Epoch   5/300 | Train: Loss=0.4009, F1 Score=0.8446 | Val: Loss=0.4933, F1 Score=0.8550
# Epoch   6/300 | Train: Loss=0.2883, F1 Score=0.8904 | Val: Loss=0.5773, F1 Score=0.8330
# Epoch   7/300 | Train: Loss=0.2851, F1 Score=0.8963 | Val: Loss=0.4576, F1 Score=0.8537
# Epoch   8/300 | Train: Loss=0.2739, F1 Score=0.9009 | Val: Loss=0.6243, F1 Score=0.8183
# Epoch   9/300 | Train: Loss=0.2115, F1 Score=0.9229 | Val: Loss=0.4050, F1 Score=0.8799
# Epoch  10/300 | Train: Loss=0.1683, F1 Score=0.9376 | Val: Loss=0.5399, F1 Score=0.7879
# Epoch  11/300 | Train: Loss=0.1334, F1 Score=0.9526 | Val: Loss=0.7469, F1 Score=0.7656
# Epoch  12/300 | Train: Loss=0.1449, F1 Score=0.9478 | Val: Loss=0.6219, F1 Score=0.8268
# Epoch  13/300 | Train: Loss=0.1092, F1 Score=0.9637 | Val: Loss=0.4914, F1 Score=0.8604
# Epoch  14/300 | Train: Loss=0.0871, F1 Score=0.9694 | Val: Loss=0.5577, F1 Score=0.8738
# Epoch  15/300 | Train: Loss=0.1980, F1 Score=0.9352 | Val: Loss=0.3896, F1 Score=0.8862
# Epoch  16/300 | Train: Loss=0.0676, F1 Score=0.9775 | Val: Loss=0.4747, F1 Score=0.8779
# Epoch  17/300 | Train: Loss=0.0676, F1 Score=0.9750 | Val: Loss=0.5173, F1 Score=0.8603
# Epoch  18/300 | Train: Loss=0.0803, F1 Score=0.9731 | Val: Loss=0.5091, F1 Score=0.8619
# Epoch  19/300 | Train: Loss=0.0538, F1 Score=0.9811 | Val: Loss=0.4557, F1 Score=0.8811
# Epoch  20/300 | Train: Loss=0.0533, F1 Score=0.9803 | Val: Loss=0.4621, F1 Score=0.8857
# Epoch  21/300 | Train: Loss=0.0990, F1 Score=0.9665 | Val: Loss=0.4015, F1 Score=0.8989
# Epoch  22/300 | Train: Loss=0.0444, F1 Score=0.9847 | Val: Loss=0.4567, F1 Score=0.8794
# Epoch  23/300 | Train: Loss=0.0540, F1 Score=0.9811 | Val: Loss=0.4455, F1 Score=0.8901
# Epoch  24/300 | Train: Loss=0.0363, F1 Score=0.9882 | Val: Loss=0.4371, F1 Score=0.8947
# Epoch  25/300 | Train: Loss=0.0370, F1 Score=0.9880 | Val: Loss=0.4242, F1 Score=0.9123
# Epoch  26/300 | Train: Loss=0.0337, F1 Score=0.9895 | Val: Loss=0.4292, F1 Score=0.9025
# Epoch  27/300 | Train: Loss=0.0497, F1 Score=0.9831 | Val: Loss=0.7504, F1 Score=0.8138
# Epoch  28/300 | Train: Loss=0.0512, F1 Score=0.9807 | Val: Loss=0.4624, F1 Score=0.8848
# Epoch  29/300 | Train: Loss=0.0207, F1 Score=0.9941 | Val: Loss=0.5716, F1 Score=0.8872
# Epoch  30/300 | Train: Loss=0.0229, F1 Score=0.9933 | Val: Loss=0.6049, F1 Score=0.8500
# Epoch  31/300 | Train: Loss=0.1000, F1 Score=0.9649 | Val: Loss=0.3611, F1 Score=0.9019
# Epoch  32/300 | Train: Loss=0.0262, F1 Score=0.9917 | Val: Loss=0.4452, F1 Score=0.8919
# Epoch  33/300 | Train: Loss=0.0219, F1 Score=0.9937 | Val: Loss=0.4840, F1 Score=0.8984
# Epoch  34/300 | Train: Loss=0.0154, F1 Score=0.9950 | Val: Loss=0.4907, F1 Score=0.8918
# Epoch  35/300 | Train: Loss=0.0135, F1 Score=0.9959 | Val: Loss=0.4349, F1 Score=0.9183
# Epoch  36/300 | Train: Loss=0.0196, F1 Score=0.9935 | Val: Loss=0.5387, F1 Score=0.8834
# Epoch  37/300 | Train: Loss=0.0772, F1 Score=0.9742 | Val: Loss=0.4013, F1 Score=0.9093
# Epoch  38/300 | Train: Loss=0.0167, F1 Score=0.9957 | Val: Loss=0.3956, F1 Score=0.9193
# Epoch  39/300 | Train: Loss=0.0080, F1 Score=0.9978 | Val: Loss=0.4458, F1 Score=0.9055
# Epoch  40/300 | Train: Loss=0.0160, F1 Score=0.9957 | Val: Loss=0.3606, F1 Score=0.9073
# Epoch  41/300 | Train: Loss=0.0214, F1 Score=0.9932 | Val: Loss=0.3982, F1 Score=0.9080
# Epoch  42/300 | Train: Loss=0.0062, F1 Score=0.9983 | Val: Loss=0.4489, F1 Score=0.8947
# Epoch  43/300 | Train: Loss=0.0106, F1 Score=0.9965 | Val: Loss=0.4117, F1 Score=0.9074
# Epoch  44/300 | Train: Loss=0.0146, F1 Score=0.9956 | Val: Loss=0.4315, F1 Score=0.9068
# Epoch  45/300 | Train: Loss=0.0458, F1 Score=0.9855 | Val: Loss=0.3574, F1 Score=0.9044
# Epoch  46/300 | Train: Loss=0.0081, F1 Score=0.9978 | Val: Loss=0.4410, F1 Score=0.9166
# Epoch  47/300 | Train: Loss=0.0163, F1 Score=0.9949 | Val: Loss=0.5441, F1 Score=0.8810
# Epoch  48/300 | Train: Loss=0.0676, F1 Score=0.9780 | Val: Loss=0.4423, F1 Score=0.8946
# Epoch  49/300 | Train: Loss=0.0238, F1 Score=0.9919 | Val: Loss=0.3792, F1 Score=0.9177
# Epoch  50/300 | Train: Loss=0.0055, F1 Score=0.9987 | Val: Loss=0.3993, F1 Score=0.9250
# Epoch  51/300 | Train: Loss=0.0025, F1 Score=0.9995 | Val: Loss=0.4193, F1 Score=0.9200
# Epoch  52/300 | Train: Loss=0.0011, F1 Score=1.0000 | Val: Loss=0.4548, F1 Score=0.9201
# Epoch  53/300 | Train: Loss=0.0012, F1 Score=0.9998 | Val: Loss=0.6256, F1 Score=0.8935
# Epoch  54/300 | Train: Loss=0.0983, F1 Score=0.9679 | Val: Loss=0.3579, F1 Score=0.9087
# Epoch  55/300 | Train: Loss=0.0105, F1 Score=0.9972 | Val: Loss=0.5124, F1 Score=0.8988
# Epoch  56/300 | Train: Loss=0.0106, F1 Score=0.9967 | Val: Loss=0.5073, F1 Score=0.9003
# Epoch  57/300 | Train: Loss=0.0048, F1 Score=0.9992 | Val: Loss=0.4545, F1 Score=0.9201
# Epoch  58/300 | Train: Loss=0.0022, F1 Score=0.9997 | Val: Loss=0.5231, F1 Score=0.9117
# Epoch  59/300 | Train: Loss=0.0038, F1 Score=0.9990 | Val: Loss=0.5123, F1 Score=0.9079
# Epoch  60/300 | Train: Loss=0.0061, F1 Score=0.9984 | Val: Loss=0.4904, F1 Score=0.9127
# Epoch  61/300 | Train: Loss=0.0310, F1 Score=0.9907 | Val: Loss=0.4574, F1 Score=0.9147
# Epoch  62/300 | Train: Loss=0.0114, F1 Score=0.9972 | Val: Loss=0.4033, F1 Score=0.9082
# Epoch  63/300 | Train: Loss=0.0074, F1 Score=0.9975 | Val: Loss=0.5563, F1 Score=0.8913
# Epoch  64/300 | Train: Loss=0.0397, F1 Score=0.9883 | Val: Loss=0.5422, F1 Score=0.8879
# Epoch  65/300 | Train: Loss=0.0073, F1 Score=0.9979 | Val: Loss=0.5448, F1 Score=0.8991
# Epoch  66/300 | Train: Loss=0.0386, F1 Score=0.9878 | Val: Loss=0.6965, F1 Score=0.8610
# Epoch  67/300 | Train: Loss=0.0557, F1 Score=0.9817 | Val: Loss=0.4431, F1 Score=0.9092
# Epoch  68/300 | Train: Loss=0.0038, F1 Score=0.9992 | Val: Loss=0.4291, F1 Score=0.9179
# Epoch  69/300 | Train: Loss=0.0032, F1 Score=0.9993 | Val: Loss=0.4393, F1 Score=0.9211
# Epoch  70/300 | Train: Loss=0.0010, F1 Score=1.0000 | Val: Loss=0.4691, F1 Score=0.9164
# Epoch  71/300 | Train: Loss=0.0008, F1 Score=1.0000 | Val: Loss=0.4848, F1 Score=0.9119
# Epoch  72/300 | Train: Loss=0.0007, F1 Score=1.0000 | Val: Loss=0.5516, F1 Score=0.9189
# Epoch  73/300 | Train: Loss=0.0270, F1 Score=0.9906 | Val: Loss=0.4470, F1 Score=0.9034
# Epoch  74/300 | Train: Loss=0.0035, F1 Score=0.9994 | Val: Loss=0.4289, F1 Score=0.9212
# Epoch  75/300 | Train: Loss=0.0013, F1 Score=0.9999 | Val: Loss=0.4926, F1 Score=0.9183
# Epoch  76/300 | Train: Loss=0.0005, F1 Score=1.0000 | Val: Loss=0.4841, F1 Score=0.9219
# Epoch  77/300 | Train: Loss=0.0005, F1 Score=1.0000 | Val: Loss=0.5173, F1 Score=0.9161
# Epoch  78/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.5227, F1 Score=0.9150
# Epoch  79/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.5259, F1 Score=0.9153
# Epoch  80/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5264, F1 Score=0.9177
# Epoch  81/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5423, F1 Score=0.9161
# Epoch  82/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5504, F1 Score=0.9171
# Epoch  83/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5460, F1 Score=0.9162
# Epoch  84/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5630, F1 Score=0.9170
# Epoch  85/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5674, F1 Score=0.9180
# Epoch  86/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5689, F1 Score=0.9170
# Epoch  87/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5720, F1 Score=0.9165
# Epoch  88/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5816, F1 Score=0.9172
# Epoch  89/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5794, F1 Score=0.9176
# Epoch  90/300 | Train: Loss=0.1949, F1 Score=0.9466 | Val: Loss=0.4567, F1 Score=0.8897
# Epoch  91/300 | Train: Loss=0.1178, F1 Score=0.9590 | Val: Loss=0.3363, F1 Score=0.8963
# Epoch  92/300 | Train: Loss=0.0226, F1 Score=0.9927 | Val: Loss=0.4188, F1 Score=0.8980
# Epoch  93/300 | Train: Loss=0.0098, F1 Score=0.9975 | Val: Loss=0.3793, F1 Score=0.9141
# Epoch  94/300 | Train: Loss=0.0298, F1 Score=0.9895 | Val: Loss=0.4733, F1 Score=0.8974
# Epoch  95/300 | Train: Loss=0.0335, F1 Score=0.9895 | Val: Loss=0.4578, F1 Score=0.8967
# Epoch  96/300 | Train: Loss=0.0066, F1 Score=0.9987 | Val: Loss=0.4901, F1 Score=0.9034
# Epoch  97/300 | Train: Loss=0.0024, F1 Score=0.9999 | Val: Loss=0.4886, F1 Score=0.9042
# Epoch  98/300 | Train: Loss=0.0020, F1 Score=0.9997 | Val: Loss=0.4743, F1 Score=0.9069
# Epoch  99/300 | Train: Loss=0.0023, F1 Score=0.9996 | Val: Loss=0.5606, F1 Score=0.9051
# Epoch 100/300 | Train: Loss=0.0010, F1 Score=0.9999 | Val: Loss=0.5298, F1 Score=0.9063
# Early stopping triggered after 100 epochs.
# Best model restored from epoch 50 with val_f1 0.9250
# Split 4/5
# Class counts (before oversampling):
# pain_level
# high_pain     46
# low_pain      75
# no_pain      407
# Name: count, dtype: int64
#
# Class counts (after oversampling):
# pain_level
# high_pain    407
# low_pain     407
# no_pain      407
# Name: count, dtype: int64
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9656, F1 Score=0.5073 | Val: Loss=0.9339, F1 Score=0.6686
# Epoch   2/300 | Train: Loss=0.7307, F1 Score=0.6737 | Val: Loss=0.6746, F1 Score=0.8129
# Epoch   3/300 | Train: Loss=0.5430, F1 Score=0.7801 | Val: Loss=0.5899, F1 Score=0.8291
# Epoch   4/300 | Train: Loss=0.4520, F1 Score=0.8259 | Val: Loss=0.4767, F1 Score=0.8466
# Epoch   5/300 | Train: Loss=0.3910, F1 Score=0.8489 | Val: Loss=0.4468, F1 Score=0.8663
# Epoch   6/300 | Train: Loss=0.3045, F1 Score=0.8841 | Val: Loss=0.4177, F1 Score=0.8770
# Epoch   7/300 | Train: Loss=0.2942, F1 Score=0.8829 | Val: Loss=0.3335, F1 Score=0.9120
# Epoch   8/300 | Train: Loss=0.2172, F1 Score=0.9172 | Val: Loss=0.4052, F1 Score=0.8813
# Epoch   9/300 | Train: Loss=0.1746, F1 Score=0.9360 | Val: Loss=0.3449, F1 Score=0.9013
# Epoch  10/300 | Train: Loss=0.2401, F1 Score=0.9126 | Val: Loss=0.3810, F1 Score=0.8893
# Epoch  11/300 | Train: Loss=0.1434, F1 Score=0.9484 | Val: Loss=0.4027, F1 Score=0.8895
# Epoch  12/300 | Train: Loss=0.1115, F1 Score=0.9618 | Val: Loss=0.5651, F1 Score=0.8645
# Epoch  13/300 | Train: Loss=0.1474, F1 Score=0.9430 | Val: Loss=0.3560, F1 Score=0.9071
# Epoch  14/300 | Train: Loss=0.0781, F1 Score=0.9717 | Val: Loss=0.3855, F1 Score=0.9108
# Epoch  15/300 | Train: Loss=0.0743, F1 Score=0.9737 | Val: Loss=0.4134, F1 Score=0.9006
# Epoch  16/300 | Train: Loss=0.0945, F1 Score=0.9656 | Val: Loss=0.4185, F1 Score=0.9126
# Epoch  17/300 | Train: Loss=0.0763, F1 Score=0.9718 | Val: Loss=0.4120, F1 Score=0.8936
# Epoch  18/300 | Train: Loss=0.0541, F1 Score=0.9833 | Val: Loss=0.3306, F1 Score=0.9150
# Epoch  19/300 | Train: Loss=0.1574, F1 Score=0.9444 | Val: Loss=0.4488, F1 Score=0.8911
# Epoch  20/300 | Train: Loss=0.0504, F1 Score=0.9840 | Val: Loss=0.3798, F1 Score=0.9162
# Epoch  21/300 | Train: Loss=0.0432, F1 Score=0.9872 | Val: Loss=0.4213, F1 Score=0.9036
# Epoch  22/300 | Train: Loss=0.0421, F1 Score=0.9858 | Val: Loss=0.3949, F1 Score=0.9275
# Epoch  23/300 | Train: Loss=0.0554, F1 Score=0.9807 | Val: Loss=0.4684, F1 Score=0.9138
# Epoch  24/300 | Train: Loss=0.0389, F1 Score=0.9864 | Val: Loss=0.3591, F1 Score=0.9299
# Epoch  25/300 | Train: Loss=0.0765, F1 Score=0.9726 | Val: Loss=0.3752, F1 Score=0.9122
# Epoch  26/300 | Train: Loss=0.0287, F1 Score=0.9913 | Val: Loss=0.3591, F1 Score=0.9319
# Epoch  27/300 | Train: Loss=0.0439, F1 Score=0.9852 | Val: Loss=0.3787, F1 Score=0.9308
# Epoch  28/300 | Train: Loss=0.0275, F1 Score=0.9908 | Val: Loss=0.3727, F1 Score=0.9357
# Epoch  29/300 | Train: Loss=0.0483, F1 Score=0.9833 | Val: Loss=0.4950, F1 Score=0.9034
# Epoch  30/300 | Train: Loss=0.0403, F1 Score=0.9874 | Val: Loss=0.5834, F1 Score=0.8858
# Epoch  31/300 | Train: Loss=0.0441, F1 Score=0.9863 | Val: Loss=0.4240, F1 Score=0.9327
# Epoch  32/300 | Train: Loss=0.0240, F1 Score=0.9922 | Val: Loss=0.4926, F1 Score=0.9182
# Epoch  33/300 | Train: Loss=0.0178, F1 Score=0.9939 | Val: Loss=0.5066, F1 Score=0.9114
# Epoch  34/300 | Train: Loss=0.0228, F1 Score=0.9928 | Val: Loss=0.5563, F1 Score=0.9088
# Epoch  35/300 | Train: Loss=0.0241, F1 Score=0.9916 | Val: Loss=0.5131, F1 Score=0.9278
# Epoch  36/300 | Train: Loss=0.0247, F1 Score=0.9918 | Val: Loss=0.4621, F1 Score=0.9339
# Epoch  37/300 | Train: Loss=0.0555, F1 Score=0.9814 | Val: Loss=0.3881, F1 Score=0.9364
# Epoch  38/300 | Train: Loss=0.0155, F1 Score=0.9956 | Val: Loss=0.4316, F1 Score=0.9365
# Epoch  39/300 | Train: Loss=0.0161, F1 Score=0.9948 | Val: Loss=0.4685, F1 Score=0.9192
# Epoch  40/300 | Train: Loss=0.0574, F1 Score=0.9804 | Val: Loss=0.4100, F1 Score=0.9241
# Epoch  41/300 | Train: Loss=0.0344, F1 Score=0.9886 | Val: Loss=0.5465, F1 Score=0.9081
# Epoch  42/300 | Train: Loss=0.0159, F1 Score=0.9950 | Val: Loss=0.4694, F1 Score=0.9311
# Epoch  43/300 | Train: Loss=0.0099, F1 Score=0.9971 | Val: Loss=0.4908, F1 Score=0.9197
# Epoch  44/300 | Train: Loss=0.0385, F1 Score=0.9860 | Val: Loss=0.5142, F1 Score=0.9387
# Epoch  45/300 | Train: Loss=0.0311, F1 Score=0.9891 | Val: Loss=0.4510, F1 Score=0.9239
# Epoch  46/300 | Train: Loss=0.0212, F1 Score=0.9925 | Val: Loss=0.4506, F1 Score=0.9310
# Epoch  47/300 | Train: Loss=0.0127, F1 Score=0.9956 | Val: Loss=0.4844, F1 Score=0.9245
# Epoch  48/300 | Train: Loss=0.0097, F1 Score=0.9967 | Val: Loss=0.4757, F1 Score=0.9373
# Epoch  49/300 | Train: Loss=0.0778, F1 Score=0.9747 | Val: Loss=0.4285, F1 Score=0.9214
# Epoch  50/300 | Train: Loss=0.0184, F1 Score=0.9948 | Val: Loss=0.4774, F1 Score=0.9218
# Epoch  51/300 | Train: Loss=0.0106, F1 Score=0.9973 | Val: Loss=0.4378, F1 Score=0.9355
# Epoch  52/300 | Train: Loss=0.0116, F1 Score=0.9964 | Val: Loss=0.5010, F1 Score=0.9287
# Epoch  53/300 | Train: Loss=0.0180, F1 Score=0.9939 | Val: Loss=0.5222, F1 Score=0.9278
# Epoch  54/300 | Train: Loss=0.0073, F1 Score=0.9983 | Val: Loss=0.5875, F1 Score=0.9182
# Epoch  55/300 | Train: Loss=0.0040, F1 Score=0.9993 | Val: Loss=0.5082, F1 Score=0.9386
# Epoch  56/300 | Train: Loss=0.0043, F1 Score=0.9988 | Val: Loss=0.5369, F1 Score=0.9285
# Epoch  57/300 | Train: Loss=0.0052, F1 Score=0.9985 | Val: Loss=0.5774, F1 Score=0.9275
# Epoch  58/300 | Train: Loss=0.0061, F1 Score=0.9985 | Val: Loss=0.5396, F1 Score=0.9248
# Epoch  59/300 | Train: Loss=0.0869, F1 Score=0.9758 | Val: Loss=0.4686, F1 Score=0.8700
# Epoch  60/300 | Train: Loss=0.0335, F1 Score=0.9900 | Val: Loss=0.4073, F1 Score=0.9369
# Epoch  61/300 | Train: Loss=0.0100, F1 Score=0.9973 | Val: Loss=0.4305, F1 Score=0.9431
# Epoch  62/300 | Train: Loss=0.0169, F1 Score=0.9952 | Val: Loss=0.4897, F1 Score=0.9269
# Epoch  63/300 | Train: Loss=0.0062, F1 Score=0.9984 | Val: Loss=0.4128, F1 Score=0.9369
# Epoch  64/300 | Train: Loss=0.0193, F1 Score=0.9939 | Val: Loss=0.4390, F1 Score=0.9334
# Epoch  65/300 | Train: Loss=0.0046, F1 Score=0.9989 | Val: Loss=0.4480, F1 Score=0.9410
# Epoch  66/300 | Train: Loss=0.0038, F1 Score=0.9989 | Val: Loss=0.5043, F1 Score=0.9224
# Epoch  67/300 | Train: Loss=0.0056, F1 Score=0.9988 | Val: Loss=0.4250, F1 Score=0.9382
# Epoch  68/300 | Train: Loss=0.0126, F1 Score=0.9959 | Val: Loss=0.9842, F1 Score=0.8455
# Epoch  69/300 | Train: Loss=0.0622, F1 Score=0.9802 | Val: Loss=0.4205, F1 Score=0.9242
# Epoch  70/300 | Train: Loss=0.0092, F1 Score=0.9975 | Val: Loss=0.4441, F1 Score=0.9319
# Epoch  71/300 | Train: Loss=0.0052, F1 Score=0.9985 | Val: Loss=0.5278, F1 Score=0.9210
# Epoch  72/300 | Train: Loss=0.0081, F1 Score=0.9975 | Val: Loss=0.4522, F1 Score=0.9388
# Epoch  73/300 | Train: Loss=0.0042, F1 Score=0.9986 | Val: Loss=0.4789, F1 Score=0.9289
# Epoch  74/300 | Train: Loss=0.0062, F1 Score=0.9985 | Val: Loss=0.5082, F1 Score=0.9360
# Epoch  75/300 | Train: Loss=0.0043, F1 Score=0.9986 | Val: Loss=0.5044, F1 Score=0.9314
# Epoch  76/300 | Train: Loss=0.0441, F1 Score=0.9858 | Val: Loss=0.5372, F1 Score=0.9165
# Epoch  77/300 | Train: Loss=0.0135, F1 Score=0.9962 | Val: Loss=0.4815, F1 Score=0.9337
# Epoch  78/300 | Train: Loss=0.0025, F1 Score=0.9996 | Val: Loss=0.4920, F1 Score=0.9415
# Epoch  79/300 | Train: Loss=0.0016, F1 Score=1.0000 | Val: Loss=0.5209, F1 Score=0.9437
# Epoch  80/300 | Train: Loss=0.0037, F1 Score=0.9986 | Val: Loss=0.5641, F1 Score=0.9282
# Epoch  81/300 | Train: Loss=0.0126, F1 Score=0.9953 | Val: Loss=0.5882, F1 Score=0.9177
# Epoch  82/300 | Train: Loss=0.0233, F1 Score=0.9919 | Val: Loss=0.5031, F1 Score=0.9333
# Epoch  83/300 | Train: Loss=0.0126, F1 Score=0.9955 | Val: Loss=0.5020, F1 Score=0.9388
# Epoch  84/300 | Train: Loss=0.1497, F1 Score=0.9617 | Val: Loss=0.3815, F1 Score=0.9243
# Epoch  85/300 | Train: Loss=0.0085, F1 Score=0.9985 | Val: Loss=0.4709, F1 Score=0.9165
# Epoch  86/300 | Train: Loss=0.0041, F1 Score=0.9995 | Val: Loss=0.4783, F1 Score=0.9243
# Epoch  87/300 | Train: Loss=0.0039, F1 Score=0.9992 | Val: Loss=0.4856, F1 Score=0.9397
# Epoch  88/300 | Train: Loss=0.0140, F1 Score=0.9955 | Val: Loss=0.4609, F1 Score=0.9271
# Epoch  89/300 | Train: Loss=0.0032, F1 Score=0.9993 | Val: Loss=0.4899, F1 Score=0.9330
# Epoch  90/300 | Train: Loss=0.0020, F1 Score=0.9997 | Val: Loss=0.5181, F1 Score=0.9319
# Epoch  91/300 | Train: Loss=0.0010, F1 Score=1.0000 | Val: Loss=0.5197, F1 Score=0.9334
# Epoch  92/300 | Train: Loss=0.0008, F1 Score=0.9999 | Val: Loss=0.5084, F1 Score=0.9311
# Epoch  93/300 | Train: Loss=0.0201, F1 Score=0.9929 | Val: Loss=0.5358, F1 Score=0.9143
# Epoch  94/300 | Train: Loss=0.0075, F1 Score=0.9981 | Val: Loss=0.5556, F1 Score=0.9308
# Epoch  95/300 | Train: Loss=0.0022, F1 Score=0.9996 | Val: Loss=0.5453, F1 Score=0.9351
# Epoch  96/300 | Train: Loss=0.0017, F1 Score=0.9996 | Val: Loss=0.5557, F1 Score=0.9323
# Epoch  97/300 | Train: Loss=0.0011, F1 Score=0.9999 | Val: Loss=0.5690, F1 Score=0.9355
# Epoch  98/300 | Train: Loss=0.0516, F1 Score=0.9852 | Val: Loss=0.3694, F1 Score=0.9388
# Epoch  99/300 | Train: Loss=0.0074, F1 Score=0.9984 | Val: Loss=0.3997, F1 Score=0.9378
# Epoch 100/300 | Train: Loss=0.0015, F1 Score=0.9998 | Val: Loss=0.4208, F1 Score=0.9436
# Epoch 101/300 | Train: Loss=0.0008, F1 Score=1.0000 | Val: Loss=0.4469, F1 Score=0.9428
# Epoch 102/300 | Train: Loss=0.0011, F1 Score=0.9999 | Val: Loss=0.4412, F1 Score=0.9408
# Epoch 103/300 | Train: Loss=0.0017, F1 Score=0.9995 | Val: Loss=0.4724, F1 Score=0.9415
# Epoch 104/300 | Train: Loss=0.0163, F1 Score=0.9949 | Val: Loss=0.4344, F1 Score=0.9314
# Epoch 105/300 | Train: Loss=0.0276, F1 Score=0.9905 | Val: Loss=0.3859, F1 Score=0.9367
# Epoch 106/300 | Train: Loss=0.0034, F1 Score=0.9993 | Val: Loss=0.3891, F1 Score=0.9432
# Epoch 107/300 | Train: Loss=0.0009, F1 Score=1.0000 | Val: Loss=0.4103, F1 Score=0.9437
# Epoch 108/300 | Train: Loss=0.0011, F1 Score=0.9997 | Val: Loss=0.4064, F1 Score=0.9469
# Epoch 109/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=0.4220, F1 Score=0.9446
# Epoch 110/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.4290, F1 Score=0.9446
# Epoch 111/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.4293, F1 Score=0.9461
# Epoch 112/300 | Train: Loss=0.0006, F1 Score=1.0000 | Val: Loss=0.4573, F1 Score=0.9415
# Epoch 113/300 | Train: Loss=0.0113, F1 Score=0.9971 | Val: Loss=0.6211, F1 Score=0.9060
# Epoch 114/300 | Train: Loss=0.0693, F1 Score=0.9782 | Val: Loss=0.3603, F1 Score=0.9345
# Epoch 115/300 | Train: Loss=0.0023, F1 Score=0.9998 | Val: Loss=0.3914, F1 Score=0.9392
# Epoch 116/300 | Train: Loss=0.0021, F1 Score=0.9994 | Val: Loss=0.4392, F1 Score=0.9418
# Epoch 117/300 | Train: Loss=0.0010, F1 Score=0.9998 | Val: Loss=0.4341, F1 Score=0.9427
# Epoch 118/300 | Train: Loss=0.0006, F1 Score=1.0000 | Val: Loss=0.4453, F1 Score=0.9429
# Epoch 119/300 | Train: Loss=0.0011, F1 Score=0.9997 | Val: Loss=0.4793, F1 Score=0.9437
# Epoch 120/300 | Train: Loss=0.0085, F1 Score=0.9972 | Val: Loss=0.4809, F1 Score=0.9233
# Epoch 121/300 | Train: Loss=0.0378, F1 Score=0.9881 | Val: Loss=0.3576, F1 Score=0.9368
# Epoch 122/300 | Train: Loss=0.0044, F1 Score=0.9991 | Val: Loss=0.4071, F1 Score=0.9390
# Epoch 123/300 | Train: Loss=0.0012, F1 Score=0.9998 | Val: Loss=0.4286, F1 Score=0.9430
# Epoch 124/300 | Train: Loss=0.0012, F1 Score=0.9997 | Val: Loss=0.4276, F1 Score=0.9435
# Epoch 125/300 | Train: Loss=0.0011, F1 Score=0.9998 | Val: Loss=0.4439, F1 Score=0.9437
# Epoch 126/300 | Train: Loss=0.0033, F1 Score=0.9991 | Val: Loss=0.4192, F1 Score=0.9393
# Epoch 127/300 | Train: Loss=0.0463, F1 Score=0.9855 | Val: Loss=0.4070, F1 Score=0.9360
# Epoch 128/300 | Train: Loss=0.0072, F1 Score=0.9981 | Val: Loss=0.4149, F1 Score=0.9363
# Epoch 129/300 | Train: Loss=0.0010, F1 Score=0.9999 | Val: Loss=0.4303, F1 Score=0.9428
# Epoch 130/300 | Train: Loss=0.0028, F1 Score=0.9992 | Val: Loss=0.4303, F1 Score=0.9364
# Epoch 131/300 | Train: Loss=0.0005, F1 Score=1.0000 | Val: Loss=0.4882, F1 Score=0.9328
# Epoch 132/300 | Train: Loss=0.0003, F1 Score=1.0000 | Val: Loss=0.4889, F1 Score=0.9395
# Epoch 133/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.4815, F1 Score=0.9381
# Epoch 134/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.4940, F1 Score=0.9372
# Epoch 135/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.4790, F1 Score=0.9394
# Epoch 136/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5072, F1 Score=0.9462
# Epoch 137/300 | Train: Loss=0.0002, F1 Score=1.0000 | Val: Loss=0.5093, F1 Score=0.9395
# Epoch 138/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5049, F1 Score=0.9418
# Epoch 139/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5130, F1 Score=0.9395
# Epoch 140/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5175, F1 Score=0.9418
# Epoch 141/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5138, F1 Score=0.9418
# Epoch 142/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5147, F1 Score=0.9425
# Epoch 143/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5198, F1 Score=0.9396
# Epoch 144/300 | Train: Loss=0.0001, F1 Score=1.0000 | Val: Loss=0.5192, F1 Score=0.9403
# Epoch 145/300 | Train: Loss=0.0040, F1 Score=0.9992 | Val: Loss=0.7132, F1 Score=0.9324
# Epoch 146/300 | Train: Loss=0.1463, F1 Score=0.9591 | Val: Loss=0.2927, F1 Score=0.9379
# Epoch 147/300 | Train: Loss=0.0086, F1 Score=0.9981 | Val: Loss=0.3453, F1 Score=0.9408
# Epoch 148/300 | Train: Loss=0.0047, F1 Score=0.9991 | Val: Loss=0.3418, F1 Score=0.9454
# Epoch 149/300 | Train: Loss=0.0023, F1 Score=0.9996 | Val: Loss=0.3751, F1 Score=0.9448
# Epoch 150/300 | Train: Loss=0.0039, F1 Score=0.9987 | Val: Loss=0.4585, F1 Score=0.9386
# Epoch 151/300 | Train: Loss=0.0151, F1 Score=0.9956 | Val: Loss=0.3620, F1 Score=0.9369
# Epoch 152/300 | Train: Loss=0.0066, F1 Score=0.9984 | Val: Loss=0.3404, F1 Score=0.9423
# Epoch 153/300 | Train: Loss=0.0010, F1 Score=0.9999 | Val: Loss=0.3681, F1 Score=0.9426
# Epoch 154/300 | Train: Loss=0.0008, F1 Score=0.9998 | Val: Loss=0.3474, F1 Score=0.9462
# Epoch 155/300 | Train: Loss=0.0009, F1 Score=1.0000 | Val: Loss=0.4172, F1 Score=0.9407
# Epoch 156/300 | Train: Loss=0.0236, F1 Score=0.9922 | Val: Loss=0.4805, F1 Score=0.9173
# Epoch 157/300 | Train: Loss=0.0056, F1 Score=0.9985 | Val: Loss=0.4053, F1 Score=0.9354
# Epoch 158/300 | Train: Loss=0.0020, F1 Score=0.9995 | Val: Loss=0.3911, F1 Score=0.9415
# Early stopping triggered after 158 epochs.
# Best model restored from epoch 108 with val_f1 0.9469
# Split 5/5
# Class counts (before oversampling):
# pain_level
# high_pain     44
# low_pain      73
# no_pain      411
# Name: count, dtype: int64
#
# Class counts (after oversampling):
# pain_level
# high_pain    411
# low_pain     411
# no_pain      411
# Name: count, dtype: int64
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9458, F1 Score=0.5271 | Val: Loss=0.8079, F1 Score=0.7205
# Epoch   2/300 | Train: Loss=0.7395, F1 Score=0.6600 | Val: Loss=0.8354, F1 Score=0.6492
# Epoch   3/300 | Train: Loss=0.6130, F1 Score=0.7515 | Val: Loss=0.5307, F1 Score=0.8198
# Epoch   4/300 | Train: Loss=0.3960, F1 Score=0.8513 | Val: Loss=0.5486, F1 Score=0.8627
# Epoch   5/300 | Train: Loss=0.4056, F1 Score=0.8444 | Val: Loss=0.7925, F1 Score=0.7035
# Epoch   6/300 | Train: Loss=0.2424, F1 Score=0.9132 | Val: Loss=0.4892, F1 Score=0.8630
# Epoch   7/300 | Train: Loss=0.2035, F1 Score=0.9249 | Val: Loss=0.4379, F1 Score=0.8814
# Epoch   8/300 | Train: Loss=0.2289, F1 Score=0.9171 | Val: Loss=0.4303, F1 Score=0.8787
# Epoch   9/300 | Train: Loss=0.1687, F1 Score=0.9403 | Val: Loss=0.5075, F1 Score=0.8489
# Epoch  10/300 | Train: Loss=0.1459, F1 Score=0.9482 | Val: Loss=0.4619, F1 Score=0.8789
# Epoch  11/300 | Train: Loss=0.1245, F1 Score=0.9571 | Val: Loss=0.9043, F1 Score=0.8127
# Epoch  12/300 | Train: Loss=0.2018, F1 Score=0.9299 | Val: Loss=0.4408, F1 Score=0.8809
# Epoch  13/300 | Train: Loss=0.1372, F1 Score=0.9513 | Val: Loss=0.4406, F1 Score=0.8882
# Epoch  14/300 | Train: Loss=0.0843, F1 Score=0.9703 | Val: Loss=0.4592, F1 Score=0.8988
# Epoch  15/300 | Train: Loss=0.1134, F1 Score=0.9600 | Val: Loss=0.4920, F1 Score=0.8794
# Epoch  16/300 | Train: Loss=0.0700, F1 Score=0.9760 | Val: Loss=0.5523, F1 Score=0.8810
# Epoch  17/300 | Train: Loss=0.0896, F1 Score=0.9667 | Val: Loss=0.5135, F1 Score=0.8939
# Epoch  18/300 | Train: Loss=0.0752, F1 Score=0.9743 | Val: Loss=0.5227, F1 Score=0.8921
# Epoch  19/300 | Train: Loss=0.0713, F1 Score=0.9750 | Val: Loss=0.5567, F1 Score=0.8963
# Epoch  20/300 | Train: Loss=0.0540, F1 Score=0.9792 | Val: Loss=0.5149, F1 Score=0.9055
# Epoch  21/300 | Train: Loss=0.0413, F1 Score=0.9868 | Val: Loss=0.5422, F1 Score=0.9031
# Epoch  22/300 | Train: Loss=0.0953, F1 Score=0.9664 | Val: Loss=0.5137, F1 Score=0.9031
# Epoch  23/300 | Train: Loss=0.0531, F1 Score=0.9806 | Val: Loss=0.5925, F1 Score=0.8965
# Epoch  24/300 | Train: Loss=0.0461, F1 Score=0.9838 | Val: Loss=0.6120, F1 Score=0.8912
# Epoch  25/300 | Train: Loss=0.0423, F1 Score=0.9864 | Val: Loss=0.7758, F1 Score=0.8627
# Epoch  26/300 | Train: Loss=0.0505, F1 Score=0.9839 | Val: Loss=0.6204, F1 Score=0.8855
# Epoch  27/300 | Train: Loss=0.0319, F1 Score=0.9887 | Val: Loss=0.5518, F1 Score=0.8983
# Epoch  28/300 | Train: Loss=0.0416, F1 Score=0.9840 | Val: Loss=0.5953, F1 Score=0.8910
# Epoch  29/300 | Train: Loss=0.0365, F1 Score=0.9890 | Val: Loss=0.6777, F1 Score=0.8846
# Epoch  30/300 | Train: Loss=0.0974, F1 Score=0.9667 | Val: Loss=0.4420, F1 Score=0.9106
# Epoch  31/300 | Train: Loss=0.0218, F1 Score=0.9936 | Val: Loss=0.5152, F1 Score=0.9136
# Epoch  32/300 | Train: Loss=0.0130, F1 Score=0.9968 | Val: Loss=0.5935, F1 Score=0.9073
# Epoch  33/300 | Train: Loss=0.0252, F1 Score=0.9906 | Val: Loss=0.5716, F1 Score=0.9097
# Epoch  34/300 | Train: Loss=0.0197, F1 Score=0.9931 | Val: Loss=0.6155, F1 Score=0.9091
# Epoch  35/300 | Train: Loss=0.0205, F1 Score=0.9935 | Val: Loss=0.6556, F1 Score=0.8975
# Epoch  36/300 | Train: Loss=0.0306, F1 Score=0.9891 | Val: Loss=0.6318, F1 Score=0.8879
# Epoch  37/300 | Train: Loss=0.0758, F1 Score=0.9771 | Val: Loss=0.6485, F1 Score=0.8446
# Epoch  38/300 | Train: Loss=0.0488, F1 Score=0.9831 | Val: Loss=0.5027, F1 Score=0.9050
# Epoch  39/300 | Train: Loss=0.0201, F1 Score=0.9938 | Val: Loss=0.5463, F1 Score=0.9003
# Epoch  40/300 | Train: Loss=0.0265, F1 Score=0.9907 | Val: Loss=0.5256, F1 Score=0.9050
# Epoch  41/300 | Train: Loss=0.0314, F1 Score=0.9885 | Val: Loss=0.5523, F1 Score=0.9035
# Epoch  42/300 | Train: Loss=0.0113, F1 Score=0.9973 | Val: Loss=0.5080, F1 Score=0.9009
# Epoch  43/300 | Train: Loss=0.0202, F1 Score=0.9936 | Val: Loss=0.5478, F1 Score=0.9084
# Epoch  44/300 | Train: Loss=0.0155, F1 Score=0.9950 | Val: Loss=0.6200, F1 Score=0.8986
# Epoch  45/300 | Train: Loss=0.0101, F1 Score=0.9964 | Val: Loss=0.5724, F1 Score=0.9054
# Epoch  46/300 | Train: Loss=0.0595, F1 Score=0.9824 | Val: Loss=0.9335, F1 Score=0.8272
# Epoch  47/300 | Train: Loss=0.0545, F1 Score=0.9833 | Val: Loss=0.5403, F1 Score=0.8937
# Epoch  48/300 | Train: Loss=0.0131, F1 Score=0.9958 | Val: Loss=0.4973, F1 Score=0.9156
# Epoch  49/300 | Train: Loss=0.0125, F1 Score=0.9959 | Val: Loss=0.4782, F1 Score=0.9191
# Epoch  50/300 | Train: Loss=0.0138, F1 Score=0.9951 | Val: Loss=0.4824, F1 Score=0.9162
# Epoch  51/300 | Train: Loss=0.0080, F1 Score=0.9980 | Val: Loss=0.5391, F1 Score=0.9126
# Epoch  52/300 | Train: Loss=0.0154, F1 Score=0.9947 | Val: Loss=0.5423, F1 Score=0.9154
# Epoch  53/300 | Train: Loss=0.0120, F1 Score=0.9964 | Val: Loss=0.5427, F1 Score=0.9131
# Epoch  54/300 | Train: Loss=0.0038, F1 Score=0.9990 | Val: Loss=0.5463, F1 Score=0.9082
# Epoch  55/300 | Train: Loss=0.0122, F1 Score=0.9959 | Val: Loss=0.7376, F1 Score=0.8891
# Epoch  56/300 | Train: Loss=0.0949, F1 Score=0.9700 | Val: Loss=0.3674, F1 Score=0.9183
# Epoch  57/300 | Train: Loss=0.0161, F1 Score=0.9959 | Val: Loss=0.5152, F1 Score=0.8959
# Epoch  58/300 | Train: Loss=0.0121, F1 Score=0.9959 | Val: Loss=0.4621, F1 Score=0.9093
# Epoch  59/300 | Train: Loss=0.0119, F1 Score=0.9957 | Val: Loss=0.5646, F1 Score=0.8945
# Epoch  60/300 | Train: Loss=0.0053, F1 Score=0.9985 | Val: Loss=0.5216, F1 Score=0.9110
# Epoch  61/300 | Train: Loss=0.0057, F1 Score=0.9983 | Val: Loss=0.5333, F1 Score=0.9119
# Epoch  62/300 | Train: Loss=0.0082, F1 Score=0.9969 | Val: Loss=0.5672, F1 Score=0.8886
# Epoch  63/300 | Train: Loss=0.0757, F1 Score=0.9766 | Val: Loss=0.3735, F1 Score=0.9099
# Epoch  64/300 | Train: Loss=0.0085, F1 Score=0.9981 | Val: Loss=0.4511, F1 Score=0.9228
# Epoch  65/300 | Train: Loss=0.0080, F1 Score=0.9974 | Val: Loss=0.4528, F1 Score=0.9143
# Epoch  66/300 | Train: Loss=0.0090, F1 Score=0.9973 | Val: Loss=0.5061, F1 Score=0.9172
# Epoch  67/300 | Train: Loss=0.0034, F1 Score=0.9992 | Val: Loss=0.4941, F1 Score=0.9270
# Epoch  68/300 | Train: Loss=0.0095, F1 Score=0.9968 | Val: Loss=0.5653, F1 Score=0.9117
# Epoch  69/300 | Train: Loss=0.0040, F1 Score=0.9988 | Val: Loss=0.5740, F1 Score=0.9056
# Epoch  70/300 | Train: Loss=0.0026, F1 Score=0.9990 | Val: Loss=0.5598, F1 Score=0.9108
# Epoch  71/300 | Train: Loss=0.0162, F1 Score=0.9959 | Val: Loss=0.6201, F1 Score=0.9059
# Epoch  72/300 | Train: Loss=0.0124, F1 Score=0.9956 | Val: Loss=0.5467, F1 Score=0.9060
# Epoch  73/300 | Train: Loss=0.0317, F1 Score=0.9876 | Val: Loss=0.5855, F1 Score=0.9078
# Epoch  74/300 | Train: Loss=0.0262, F1 Score=0.9923 | Val: Loss=0.6818, F1 Score=0.8913
# Epoch  75/300 | Train: Loss=0.0043, F1 Score=0.9986 | Val: Loss=0.5973, F1 Score=0.9056
# Epoch  76/300 | Train: Loss=0.0067, F1 Score=0.9971 | Val: Loss=0.5333, F1 Score=0.9068
# Epoch  77/300 | Train: Loss=0.0051, F1 Score=0.9984 | Val: Loss=0.5651, F1 Score=0.9181
# Epoch  78/300 | Train: Loss=0.0032, F1 Score=0.9992 | Val: Loss=0.5696, F1 Score=0.9144
# Epoch  79/300 | Train: Loss=0.0100, F1 Score=0.9960 | Val: Loss=0.7562, F1 Score=0.8843
# Epoch  80/300 | Train: Loss=0.0736, F1 Score=0.9759 | Val: Loss=0.4289, F1 Score=0.9114
# Epoch  81/300 | Train: Loss=0.0068, F1 Score=0.9983 | Val: Loss=0.4866, F1 Score=0.9077
# Epoch  82/300 | Train: Loss=0.0027, F1 Score=0.9995 | Val: Loss=0.5057, F1 Score=0.9088
# Epoch  83/300 | Train: Loss=0.0021, F1 Score=0.9995 | Val: Loss=0.5121, F1 Score=0.9173
# Epoch  84/300 | Train: Loss=0.0019, F1 Score=0.9995 | Val: Loss=0.5039, F1 Score=0.9129
# Epoch  85/300 | Train: Loss=0.0035, F1 Score=0.9986 | Val: Loss=0.5095, F1 Score=0.9128
# Epoch  86/300 | Train: Loss=0.0198, F1 Score=0.9935 | Val: Loss=0.5206, F1 Score=0.9132
# Epoch  87/300 | Train: Loss=0.0079, F1 Score=0.9977 | Val: Loss=0.6299, F1 Score=0.8984
# Epoch  88/300 | Train: Loss=0.0030, F1 Score=0.9991 | Val: Loss=0.5738, F1 Score=0.9221
# Epoch  89/300 | Train: Loss=0.0015, F1 Score=0.9998 | Val: Loss=0.5999, F1 Score=0.9124
# Epoch  90/300 | Train: Loss=0.0034, F1 Score=0.9987 | Val: Loss=0.6251, F1 Score=0.9137
# Epoch  91/300 | Train: Loss=0.0368, F1 Score=0.9890 | Val: Loss=0.5316, F1 Score=0.9022
# Epoch  92/300 | Train: Loss=0.0113, F1 Score=0.9971 | Val: Loss=0.5620, F1 Score=0.9124
# Epoch  93/300 | Train: Loss=0.0035, F1 Score=0.9992 | Val: Loss=0.5377, F1 Score=0.9182
# Epoch  94/300 | Train: Loss=0.0041, F1 Score=0.9988 | Val: Loss=0.5004, F1 Score=0.9200
# Epoch  95/300 | Train: Loss=0.0024, F1 Score=0.9994 | Val: Loss=0.5938, F1 Score=0.9110
# Epoch  96/300 | Train: Loss=0.0038, F1 Score=0.9990 | Val: Loss=0.6346, F1 Score=0.9041
# Epoch  97/300 | Train: Loss=0.0029, F1 Score=0.9991 | Val: Loss=0.5380, F1 Score=0.9195
# Epoch  98/300 | Train: Loss=0.0286, F1 Score=0.9910 | Val: Loss=0.5331, F1 Score=0.9123
# Epoch  99/300 | Train: Loss=0.0140, F1 Score=0.9941 | Val: Loss=0.5606, F1 Score=0.9079
# Epoch 100/300 | Train: Loss=0.0217, F1 Score=0.9920 | Val: Loss=0.5067, F1 Score=0.9246
# Epoch 101/300 | Train: Loss=0.0024, F1 Score=0.9995 | Val: Loss=0.5593, F1 Score=0.9163
# Epoch 102/300 | Train: Loss=0.0026, F1 Score=0.9988 | Val: Loss=0.4689, F1 Score=0.9265
# Epoch 103/300 | Train: Loss=0.0029, F1 Score=0.9990 | Val: Loss=0.4877, F1 Score=0.9230
# Epoch 104/300 | Train: Loss=0.0010, F1 Score=0.9998 | Val: Loss=0.5135, F1 Score=0.9253
# Epoch 105/300 | Train: Loss=0.0025, F1 Score=0.9993 | Val: Loss=0.6103, F1 Score=0.9192
# Epoch 106/300 | Train: Loss=0.0007, F1 Score=0.9999 | Val: Loss=0.5402, F1 Score=0.9242
# Epoch 107/300 | Train: Loss=0.0005, F1 Score=1.0000 | Val: Loss=0.5340, F1 Score=0.9159
# Epoch 108/300 | Train: Loss=0.0010, F1 Score=0.9996 | Val: Loss=0.5763, F1 Score=0.9250
# Epoch 109/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=0.5761, F1 Score=0.9251
# Epoch 110/300 | Train: Loss=0.0017, F1 Score=0.9995 | Val: Loss=0.5597, F1 Score=0.9236
# Epoch 111/300 | Train: Loss=0.0339, F1 Score=0.9877 | Val: Loss=0.4694, F1 Score=0.9198
# Epoch 112/300 | Train: Loss=0.0075, F1 Score=0.9985 | Val: Loss=0.5369, F1 Score=0.9201
# Epoch 113/300 | Train: Loss=0.0018, F1 Score=0.9998 | Val: Loss=0.5117, F1 Score=0.9166
# Epoch 114/300 | Train: Loss=0.0034, F1 Score=0.9993 | Val: Loss=0.6004, F1 Score=0.9181
# Epoch 115/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=0.6187, F1 Score=0.9167
# Epoch 116/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=0.5601, F1 Score=0.9214
# Epoch 117/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=0.5715, F1 Score=0.9220
# Early stopping triggered after 117 epochs.
# Best model restored from epoch 67 with val_f1 0.9270
# Best score: 0.9461±0.0179
# CPU times: user 12min 22s, sys: 1min 40s, total: 14min 2s
# Wall time: 15min 42s

# %%
# @title Plot History
# Create figure with two subplots sharing x axis
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 5), sharex=True)

# Color palette for K splits
colors = plt.cm.get_cmap('tab10', K)

# Plot validation loss for each split
for split in range(K):
    axes[0].plot(losses[f'split_{split}'][:-PATIENCE], label=f'Split {split+1}',
                 color=colors(split), alpha=0.6)
axes[0].set_title('Validation Loss per Split')
axes[0].set_ylabel('Loss')
axes[0].set_xlabel('Epoch')
axes[0].grid(alpha=0.3)

# Plot validation F1 score for each split
for split in range(K):
    axes[1].plot(metrics[f'split_{split}'][:-PATIENCE], label=f'Split {split+1}',
                 color=colors(split), alpha=0.6)
axes[1].set_title('Validation F1 Score per Split')
axes[1].set_ylabel('F1 Score')
axes[1].set_xlabel('Epoch')
axes[1].grid(alpha=0.3)

# Add shared legend on the right
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='small')

# Adjust layout
plt.tight_layout()
plt.subplots_adjust(right=0.975)
plt.show()
