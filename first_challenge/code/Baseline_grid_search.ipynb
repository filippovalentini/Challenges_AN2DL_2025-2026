# %% [markdown]
# # Notebook description

# %% [markdown]
# In this notebook we report the best result restored from the **first grid search** performed during the challenge. In particular, among the multiple candidate parameter combinations, the one used for this LSTM-based RNN provided the highest cross-validation F1-score; still, the score is much smaller than the one obtained in further experiments.

# %% [markdown]
# # Google Drive connection

# %%
from google.colab import drive
drive.mount("/gdrive")
current_dir = "/gdrive/My\\ Drive/challengeAN2DL"
# %cd $current_dir
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1FBs0a25Urpk8cZPLeXuOnI8nzY3Yx1TA/challengeAN2DL

# %% [markdown]
# # Import libraries

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# # Data loading

# %%
# path to datasets
DATASET_NAME_TRAINING = "an2dl2526c1/pirate_pain_train.csv"
DATASET_NAME_LABELS = "an2dl2526c1/pirate_pain_train_labels.csv"
DATASET_NAME_TEST = "an2dl2526c1/pirate_pain_test.csv"

# datset loading
df = pd.read_csv(DATASET_NAME_TRAINING)
labels = pd.read_csv(DATASET_NAME_LABELS)
df_test = pd.read_csv(DATASET_NAME_TEST)

# %% [markdown]
# # Data exploration, analysis and preprocessing

# %%
# Drop constant feature "joint_30"
df = df.drop('joint_30', axis=1)
df_test = df_test.drop('joint_30', axis=1)

# Drop dependent features
df = df.drop('n_eyes', axis=1)
df_test = df_test.drop('n_eyes', axis=1)
df = df.drop('n_legs', axis=1)
df_test = df_test.drop('n_legs', axis=1)
df = df.drop('n_hands', axis=1)
df_test = df_test.drop('n_hands', axis=1)

# Transformation to float32 values
for index in range(4):
    i = index + 1
    column = 'pain_survey_' + str(i)
    df[column] = df[column].astype(np.float32)
    df_test[column] = df_test[column].astype(np.float32)
for index in range(30):
    column = 'joint_' + str(index).zfill(2)
    df[column] = df[column].astype(np.float32)
    df_test[column] = df_test[column].astype(np.float32)

# %%
# add labels to train set
df = df.merge(labels, on='sample_index', how='left')
df = df.rename(columns={'label': 'pain_level'})

# select the meaningful features for training (we discard sample index and timestamp)
scale_columns = df.columns[2:-1].tolist()

# %% [markdown]
# # Sequence building

# %%
# define the size of sequences used to train the network
WINDOW_SIZE = 64
# define the stride used to build training sequences starting from the original ones
STRIDE = 16

# %%
# SEQUENCE BUILDING FUNCTION
# for each sequence of the dataframe, this function creates new sequences by adding padding and shifting the window multiple times, depending on the stride.

def build_sequences(df, window=40, stride=40):
    # Sanity check to ensure the window is divisible by the stride
    assert window % stride == 0

    # Initialise lists to store sequences and their corresponding labels
    dataset = []
    labels = []

    # Iterate over unique IDs in the DataFrame
    for id in df['sample_index'].unique():
        # Extract sensor data for the current ID
        temp = df[df['sample_index'] == id][scale_columns].values

        # Retrieve the activity label for the current ID
        label = df[df['sample_index'] == id]['pain_level'].values[0]

        # Calculate padding length to ensure full windows
        padding_len = window - len(temp) % window

        # Create zero padding and concatenate with the data
        padding = np.zeros((padding_len, len(scale_columns)), dtype='float32')
        temp = np.concatenate((temp, padding))

        # Build feature windows and associate them with labels
        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            labels.append(label)
            idx += stride

    # Convert lists to numpy arrays for further processing
    dataset = np.array(dataset)
    labels = np.array(labels)

    return dataset, labels

# %%
# Define the number of samples (sequences) in each batch
BATCH_SIZE = 32

# %%
# this function creates a data loader starting from a dataset, its related batch size and other additional parameters

def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %% [markdown]
# # Model building

# %%
def recurrent_summary(model, input_size):
    """
    Custom summary function that emulates torchinfo's output while correctly
    counting parameters for RNN/GRU/LSTM layers.

    This function is designed for models whose direct children are
    nn.Linear, nn.RNN, nn.GRU, or nn.LSTM layers.

    Args:
        model (nn.Module): The model to analyze.
        input_size (tuple): Shape of the input tensor (e.g., (seq_len, features)).
    """

    # Dictionary to store output shapes captured by forward hooks
    output_shapes = {}
    # List to track hook handles for later removal
    hooks = []

    def get_hook(name):
        """Factory function to create a forward hook for a specific module."""
        def hook(module, input, output):
            # Handle RNN layer outputs (returns a tuple)
            if isinstance(output, tuple):
                # output[0]: all hidden states with shape (batch, seq_len, hidden*directions)
                shape1 = list(output[0].shape)
                shape1[0] = -1  # Replace batch dimension with -1

                # output[1]: final hidden state h_n (or tuple (h_n, c_n) for LSTM)
                if isinstance(output[1], tuple):  # LSTM case: (h_n, c_n)
                    shape2 = list(output[1][0].shape)  # Extract h_n only
                else:  # RNN/GRU case: h_n only
                    shape2 = list(output[1].shape)

                # Replace batch dimension (middle position) with -1
                shape2[1] = -1

                output_shapes[name] = f"[{shape1}, {shape2}]"

            # Handle standard layer outputs (e.g., Linear)
            else:
                shape = list(output.shape)
                shape[0] = -1  # Replace batch dimension with -1
                output_shapes[name] = f"{shape}"
        return hook

    # 1. Determine the device where model parameters reside
    try:
        device = next(model.parameters()).device
    except StopIteration:
        device = torch.device("cpu")  # Fallback for models without parameters

    # 2. Create a dummy input tensor with batch_size=1
    dummy_input = torch.randn(1, *input_size).to(device)

    # 3. Register forward hooks on target layers
    # Iterate through direct children of the model (e.g., self.rnn, self.classifier)
    for name, module in model.named_children():
        if isinstance(module, (nn.Linear, nn.RNN, nn.GRU, nn.LSTM)):
            # Register the hook and store its handle for cleanup
            hook_handle = module.register_forward_hook(get_hook(name))
            hooks.append(hook_handle)

    # 4. Execute a dummy forward pass in evaluation mode
    model.eval()
    with torch.no_grad():
        try:
            model(dummy_input)
        except Exception as e:
            print(f"Error during dummy forward pass: {e}")
            # Clean up hooks even if an error occurs
            for h in hooks:
                h.remove()
            return

    # 5. Remove all registered hooks
    for h in hooks:
        h.remove()

    # --- 6. Print the summary table ---

    print("-" * 79)
    # Column headers
    print(f"{'Layer (type)':<25} {'Output Shape':<28} {'Param #':<18}")
    print("=" * 79)

    total_params = 0
    total_trainable_params = 0

    # Iterate through modules again to collect and display parameter information
    for name, module in model.named_children():
        if name in output_shapes:
            # Count total and trainable parameters for this module
            module_params = sum(p.numel() for p in module.parameters())
            trainable_params = sum(p.numel() for p in module.parameters() if p.requires_grad)

            total_params += module_params
            total_trainable_params += trainable_params

            # Format strings for display
            layer_name = f"{name} ({type(module).__name__})"
            output_shape_str = str(output_shapes[name])
            params_str = f"{trainable_params:,}"

            print(f"{layer_name:<25} {output_shape_str:<28} {params_str:<15}")

    print("=" * 79)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {total_trainable_params:,}")
    print(f"Non-trainable params: {total_params - total_trainable_params:,}")
    print("-" * 79)

# %%
class RecurrentClassifier(nn.Module):
    """
    Generic RNN classifier (RNN, LSTM, GRU).
    Uses the last hidden state for classification.
    """
    def __init__(
            self,
            input_size,
            hidden_size,
            num_layers,
            num_classes,
            rnn_type='GRU',        # 'RNN', 'LSTM', or 'GRU'
            bidirectional=False,
            dropout_rate=0.2 #apply/disapply the temporary, it puts =0 the past input h(t-1), simulates a new sequence
            ):
        super().__init__()

        self.rnn_type = rnn_type
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.bidirectional = bidirectional

        # Map string name to PyTorch RNN class
        rnn_map = {
            'RNN': nn.RNN,
            'LSTM': nn.LSTM,
            'GRU': nn.GRU
        }

        if rnn_type not in rnn_map:
            raise ValueError("rnn_type must be 'RNN', 'LSTM', or 'GRU'")

        rnn_module = rnn_map[rnn_type]

        # Dropout is only applied between layers (if num_layers > 1)
        dropout_val = dropout_rate if num_layers > 1 else 0

        # Create the recurrent layer
        self.rnn = rnn_module(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,       # Input shape: (batch, seq_len, features)
            bidirectional=bidirectional,
            dropout=dropout_val
        )

        # Calculate input size for the final classifier
        if self.bidirectional:
            classifier_input_size = hidden_size * 2 # Concat fwd + bwd
        else:
            classifier_input_size = hidden_size

        # Final classification layer
        self.classifier = nn.Linear(classifier_input_size, num_classes)

    def forward(self, x):
        """
        x shape: (batch_size, seq_length, input_size)
        """

        # rnn_out shape: (batch_size, seq_len, hidden_size * num_directions)
        rnn_out, hidden = self.rnn(x)

        # LSTM returns (h_n, c_n), we only need h_n
        if self.rnn_type == 'LSTM':
            hidden = hidden[0]

        # hidden shape: (num_layers * num_directions, batch_size, hidden_size)

        if self.bidirectional:
            # Reshape to (num_layers, 2, batch_size, hidden_size)
            hidden = hidden.view(self.num_layers, 2, -1, self.hidden_size)

            # Concat last fwd (hidden[-1, 0, ...]) and bwd (hidden[-1, 1, ...])
            # Final shape: (batch_size, hidden_size * 2)
            hidden_to_classify = torch.cat([hidden[-1, 0, :, :], hidden[-1, 1, :, :]], dim=1)
        else:
            # Take the last layer's hidden state
            # Final shape: (batch_size, hidden_size)
            hidden_to_classify = hidden[-1]

        # Get logits
        logits = self.classifier(hidden_to_classify)
        return logits

# %% [markdown]
# # Network and training hyperparameters

# %%
# HYPERPARAMETERS

# Training configuration
LEARNING_RATE = 5e-4
EPOCHS = 300
PATIENCE = 50

# Architecture
HIDDEN_LAYERS = 2        # number of hidden layers
HIDDEN_SIZE = 128       # units per layer

# Regularisation
DROPOUT_RATE = 0.4         # Dropout probability
L1_LAMBDA = 0            # L1 penalty
L2_LAMBDA = 0.01            # L2 penalty

# Loss function
criterion = nn.CrossEntropyLoss()

# CROSS VALIDATION FOLDS
K = 5

# %% [markdown]
# # Model Training

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """
    Log training metrics and model parameters to TensorBoard for visualization.

    Args:
        writer (SummaryWriter): TensorBoard SummaryWriter object for logging
        epoch (int): Current epoch number (used as x-axis in TensorBoard plots)
        train_loss (float): Training loss for this epoch
        train_f1 (float): Training f1 score for this epoch
        val_loss (float): Validation loss for this epoch
        val_f1 (float): Validation f1 score for this epoch
        model (nn.Module): The neural network model (for logging weights/gradients)

    Note:
        This function logs scalar metrics (loss/f1 score) and histograms of model
        parameters and gradients, which helps monitor training progress and detect
        issues like vanishing/exploding gradients.
    """
    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# # Cross Validation

# %%
def k_shuffle_split_cross_validation_round_rnn(df, train_split_ratio, epochs, criterion, device,
                            k, batch_size, hidden_layers, hidden_size, learning_rate, dropout_rate,
                            bidirectional, rnn_type, l1_lambda=0, l2_lambda=0, patience=0, window_size=WINDOW_SIZE, stride=STRIDE,
                            evaluation_metric="val_f1", mode='max', restore_best_weights=True, writer=None,
                            verbose=10, seed=SEED, experiment_name=""):

    # Initialise containers for results across all splits

    fold_losses = {}
    fold_metrics = {}
    best_scores = {}

    # Retrieve number of input features and number of classes
    scale_columns = df.columns[2:-1].tolist()
    in_features = len(scale_columns)
    num_classes = len(df['pain_level'].unique())

    rnn_model = RecurrentClassifier(
        input_size=in_features,
        hidden_size=hidden_size,
        num_layers=hidden_layers,
        num_classes=num_classes,
        dropout_rate=dropout_rate,
        bidirectional=bidirectional,
        rnn_type=rnn_type
        ).to(device)

    # Store initial weights to reset model for each split
    initial_state = copy.deepcopy(rnn_model.state_dict())

    # Iterate through K random splits
    for split_idx in range(k):

        if verbose > 0:
            print(f"Split {split_idx+1}/{k}")
        # Create random split

        unique_pirates = df['sample_index'].unique()
        random.seed(seed + split_idx) # Different shuffle for every index
        random.shuffle(unique_pirates)

        N_TRAIN_PIRATES = int(len(unique_pirates) * train_split_ratio)
        N_VAL_PIRATES = len(unique_pirates) - N_TRAIN_PIRATES

        train_pirates = unique_pirates[:N_TRAIN_PIRATES]
        val_pirates = unique_pirates[N_TRAIN_PIRATES:]

        df_train = df[df['sample_index'].isin(train_pirates)].copy()
        df_val = df[df['sample_index'].isin(val_pirates)].copy()

        label_mapping = {
            'no_pain': 0,
            'low_pain': 1,
            'high_pain': 2
        }

        df_train['pain_level'] = df_train['pain_level'].map(label_mapping)

        df_val['pain_level'] = df_val['pain_level'].map(label_mapping)

        # Calculate the minimum and maximum values from the training data only
        mins = df_train[scale_columns].min()
        maxs = df_train[scale_columns].max()

        # Apply normalisation to the specified columns in all datasets
        for column in scale_columns:
            # Normalise the training set
            df_train[column] = (df_train[column] - mins[column]) / (maxs[column] - mins[column])

            # Normalise the validation set
            df_val[column] = (df_val[column] - mins[column]) / (maxs[column] - mins[column])

        # Build sequences
        X_train, y_train = build_sequences(df_train, window_size, stride)
        X_val, y_val = build_sequences(df_val, window_size, stride)

        # Create PyTorch datasets
        train_ds = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
        val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val))

        # Create data loaders
        train_loader = make_loader(train_ds, batch_size=batch_size, shuffle=True, drop_last=False)
        val_loader   = make_loader(val_ds, batch_size=batch_size, shuffle=False, drop_last=False)

        # Reset model to initial weights for fair comparison across splits
        rnn_model.load_state_dict(initial_state)

        optimizer = torch.optim.AdamW(rnn_model.parameters(), lr=learning_rate, weight_decay=l2_lambda)

        # Enable mixed precision training for GPU acceleration
        scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

        # Create directory for model checkpoints

        os.makedirs(f"models/{experiment_name}", exist_ok=True)

        # Train model on current split
        rnn_model, training_history = fit(
            model=rnn_model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=epochs,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            device=device,
            writer=writer,
            patience=patience,
            verbose=verbose,
            experiment_name=experiment_name+"/split_"+str(split_idx),
            l1_lambda=l1_lambda,
            evaluation_metric=evaluation_metric,
            mode=mode,
            restore_best_weights=restore_best_weights,
            )

        # Store results for this split
        fold_losses[f"split_{split_idx}"] = training_history['val_loss']
        fold_metrics[f"split_{split_idx}"] = training_history['val_f1']
        best_scores[f"split_{split_idx}"] = max(training_history['val_f1'])

    # Compute mean and standard deviation of best scores across splits
    best_scores["mean"] = np.mean([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])
    best_scores["std"] = np.std([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])

    if verbose > 0:
        print(f"Best score: {best_scores['mean']:.4f}±{best_scores['std']:.4f}")

    return fold_losses, fold_metrics, best_scores

# %%
# CALL TO CROSS-VALIDATION METHOD
# %%time
# Execute K-fold cross-validation with baseline configuration
losses, metrics, best_scores = k_shuffle_split_cross_validation_round_rnn(
    df=df,
    train_split_ratio=0.8,
    epochs=EPOCHS,
    criterion=criterion,
    device=device,
    k=K,
    batch_size=BATCH_SIZE,
    hidden_layers=HIDDEN_LAYERS,
    hidden_size=HIDDEN_SIZE,
    learning_rate=LEARNING_RATE,
    dropout_rate=DROPOUT_RATE,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    verbose=1,
    patience=PATIENCE,
    seed=SEED,
    experiment_name="baseline_cv",
    window_size=WINDOW_SIZE,
    stride=STRIDE,
    rnn_type="LSTM",
    bidirectional=True
)
# Out:
# Split 1/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.6798, F1 Score=0.6799 | Val: Loss=0.6641, F1 Score=0.6867
# Epoch   2/300 | Train: Loss=0.5803, F1 Score=0.7506 | Val: Loss=0.6479, F1 Score=0.7153
# Epoch   3/300 | Train: Loss=0.5146, F1 Score=0.7806 | Val: Loss=0.7397, F1 Score=0.7868
# Epoch   4/300 | Train: Loss=0.4209, F1 Score=0.8185 | Val: Loss=0.5189, F1 Score=0.7870
# Epoch   5/300 | Train: Loss=0.4064, F1 Score=0.8358 | Val: Loss=0.4781, F1 Score=0.8155
# Epoch   6/300 | Train: Loss=0.3584, F1 Score=0.8667 | Val: Loss=0.5053, F1 Score=0.8079
# Epoch   7/300 | Train: Loss=0.3380, F1 Score=0.8750 | Val: Loss=0.4461, F1 Score=0.8380
# Epoch   8/300 | Train: Loss=0.2901, F1 Score=0.8979 | Val: Loss=0.5665, F1 Score=0.8363
# Epoch   9/300 | Train: Loss=0.3067, F1 Score=0.8884 | Val: Loss=0.4859, F1 Score=0.8361
# Epoch  10/300 | Train: Loss=0.2631, F1 Score=0.9071 | Val: Loss=0.4482, F1 Score=0.8478
# Epoch  11/300 | Train: Loss=0.2722, F1 Score=0.9043 | Val: Loss=0.4612, F1 Score=0.8510
# Epoch  12/300 | Train: Loss=0.2882, F1 Score=0.8947 | Val: Loss=0.5264, F1 Score=0.8450
# Epoch  13/300 | Train: Loss=0.2336, F1 Score=0.9165 | Val: Loss=0.3909, F1 Score=0.8682
# Epoch  14/300 | Train: Loss=0.2102, F1 Score=0.9257 | Val: Loss=0.4680, F1 Score=0.8525
# Epoch  15/300 | Train: Loss=0.2376, F1 Score=0.9147 | Val: Loss=0.5800, F1 Score=0.8098
# Epoch  16/300 | Train: Loss=0.2402, F1 Score=0.9113 | Val: Loss=0.4279, F1 Score=0.8532
# Epoch  17/300 | Train: Loss=0.2010, F1 Score=0.9260 | Val: Loss=0.4646, F1 Score=0.8689
# Epoch  18/300 | Train: Loss=0.1979, F1 Score=0.9295 | Val: Loss=0.5104, F1 Score=0.8592
# Epoch  19/300 | Train: Loss=0.1943, F1 Score=0.9361 | Val: Loss=0.3536, F1 Score=0.8914
# Epoch  20/300 | Train: Loss=0.2639, F1 Score=0.9127 | Val: Loss=0.5326, F1 Score=0.8172
# Epoch  21/300 | Train: Loss=0.2046, F1 Score=0.9241 | Val: Loss=0.4417, F1 Score=0.8635
# Epoch  22/300 | Train: Loss=0.1737, F1 Score=0.9396 | Val: Loss=0.3349, F1 Score=0.8880
# Epoch  23/300 | Train: Loss=0.1498, F1 Score=0.9461 | Val: Loss=0.4755, F1 Score=0.8673
# Epoch  24/300 | Train: Loss=0.1525, F1 Score=0.9453 | Val: Loss=0.3336, F1 Score=0.8981
# Epoch  25/300 | Train: Loss=0.1545, F1 Score=0.9450 | Val: Loss=0.3835, F1 Score=0.8753
# Epoch  26/300 | Train: Loss=0.1499, F1 Score=0.9480 | Val: Loss=0.4506, F1 Score=0.8753
# Epoch  27/300 | Train: Loss=0.1365, F1 Score=0.9520 | Val: Loss=0.4267, F1 Score=0.8953
# Epoch  28/300 | Train: Loss=0.1556, F1 Score=0.9443 | Val: Loss=0.3818, F1 Score=0.8911
# Epoch  29/300 | Train: Loss=0.1253, F1 Score=0.9610 | Val: Loss=0.4438, F1 Score=0.8811
# Epoch  30/300 | Train: Loss=0.2214, F1 Score=0.9244 | Val: Loss=0.5064, F1 Score=0.8700
# Epoch  31/300 | Train: Loss=0.2284, F1 Score=0.9280 | Val: Loss=0.4648, F1 Score=0.8503
# Epoch  32/300 | Train: Loss=0.1816, F1 Score=0.9360 | Val: Loss=0.4218, F1 Score=0.8760
# Epoch  33/300 | Train: Loss=0.1340, F1 Score=0.9535 | Val: Loss=0.3376, F1 Score=0.9118
# Epoch  88/300 | Train: Loss=0.0633, F1 Score=0.9814 | Val: Loss=0.3520, F1 Score=0.9109
# Epoch  89/300 | Train: Loss=0.0508, F1 Score=0.9842 | Val: Loss=0.4975, F1 Score=0.8833
# Epoch  90/300 | Train: Loss=0.0970, F1 Score=0.9679 | Val: Loss=0.3492, F1 Score=0.9174
# Epoch  91/300 | Train: Loss=0.0337, F1 Score=0.9902 | Val: Loss=0.3668, F1 Score=0.9173
# Epoch  92/300 | Train: Loss=0.0563, F1 Score=0.9820 | Val: Loss=0.4132, F1 Score=0.9056
# Epoch  93/300 | Train: Loss=0.0350, F1 Score=0.9891 | Val: Loss=0.3454, F1 Score=0.9259
# Epoch  94/300 | Train: Loss=0.0600, F1 Score=0.9801 | Val: Loss=0.3136, F1 Score=0.9272
# Epoch  95/300 | Train: Loss=0.0229, F1 Score=0.9907 | Val: Loss=0.3740, F1 Score=0.9324
# Epoch  96/300 | Train: Loss=0.0243, F1 Score=0.9915 | Val: Loss=0.3315, F1 Score=0.9158
# Epoch  97/300 | Train: Loss=0.0192, F1 Score=0.9935 | Val: Loss=0.3674, F1 Score=0.9125
# Epoch  98/300 | Train: Loss=0.0173, F1 Score=0.9941 | Val: Loss=0.5319, F1 Score=0.8986
# Epoch  99/300 | Train: Loss=0.1644, F1 Score=0.9540 | Val: Loss=0.4018, F1 Score=0.8960
# Epoch 100/300 | Train: Loss=0.0716, F1 Score=0.9736 | Val: Loss=0.3705, F1 Score=0.9000
# Epoch 101/300 | Train: Loss=0.0524, F1 Score=0.9829 | Val: Loss=0.4182, F1 Score=0.8990
# Epoch 102/300 | Train: Loss=0.0446, F1 Score=0.9854 | Val: Loss=0.4624, F1 Score=0.8891
# Epoch 103/300 | Train: Loss=0.0780, F1 Score=0.9740 | Val: Loss=0.3079, F1 Score=0.9068
# Epoch 104/300 | Train: Loss=0.0429, F1 Score=0.9837 | Val: Loss=0.3743, F1 Score=0.9091
# Epoch 105/300 | Train: Loss=0.0462, F1 Score=0.9843 | Val: Loss=0.3727, F1 Score=0.9077
# Epoch 106/300 | Train: Loss=0.0317, F1 Score=0.9887 | Val: Loss=0.4354, F1 Score=0.9125
# Epoch 107/300 | Train: Loss=0.0243, F1 Score=0.9915 | Val: Loss=0.4426, F1 Score=0.9089
# Epoch 108/300 | Train: Loss=0.0188, F1 Score=0.9936 | Val: Loss=0.4100, F1 Score=0.9185
# Epoch 109/300 | Train: Loss=0.0214, F1 Score=0.9920 | Val: Loss=0.6773, F1 Score=0.8948
# Epoch 110/300 | Train: Loss=0.0940, F1 Score=0.9776 | Val: Loss=0.3922, F1 Score=0.8973
# Epoch 111/300 | Train: Loss=0.0921, F1 Score=0.9708 | Val: Loss=0.4372, F1 Score=0.8536
# Epoch 112/300 | Train: Loss=0.0493, F1 Score=0.9835 | Val: Loss=0.3729, F1 Score=0.9015
# Epoch 113/300 | Train: Loss=0.0412, F1 Score=0.9858 | Val: Loss=0.3149, F1 Score=0.9181
# Epoch 114/300 | Train: Loss=0.0292, F1 Score=0.9896 | Val: Loss=0.5494, F1 Score=0.8971
# Epoch 141/300 | Train: Loss=0.0506, F1 Score=0.9823 | Val: Loss=0.4983, F1 Score=0.8938
# Epoch 142/300 | Train: Loss=0.0271, F1 Score=0.9918 | Val: Loss=0.5208, F1 Score=0.9057
# Epoch 143/300 | Train: Loss=0.0585, F1 Score=0.9844 | Val: Loss=0.2968, F1 Score=0.9261
# Epoch 144/300 | Train: Loss=0.0267, F1 Score=0.9917 | Val: Loss=0.3081, F1 Score=0.9301
# Epoch 145/300 | Train: Loss=0.0162, F1 Score=0.9934 | Val: Loss=0.3665, F1 Score=0.9245
# Early stopping triggered after 145 epochs.
# Best model restored from epoch 95 with val_f1 0.9324
# Split 2/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.6678, F1 Score=0.6870 | Val: Loss=0.7551, F1 Score=0.6474
# Epoch   2/300 | Train: Loss=0.5692, F1 Score=0.7577 | Val: Loss=0.6531, F1 Score=0.6978
# Epoch   3/300 | Train: Loss=0.5040, F1 Score=0.7832 | Val: Loss=0.6639, F1 Score=0.7505
# Epoch   4/300 | Train: Loss=0.4432, F1 Score=0.8170 | Val: Loss=0.5778, F1 Score=0.7634
# Epoch   5/300 | Train: Loss=0.3804, F1 Score=0.8366 | Val: Loss=0.4937, F1 Score=0.7926
# Epoch   6/300 | Train: Loss=0.3400, F1 Score=0.8590 | Val: Loss=0.5164, F1 Score=0.8036
# Epoch   7/300 | Train: Loss=0.3075, F1 Score=0.8779 | Val: Loss=0.4755, F1 Score=0.8237
# Epoch   8/300 | Train: Loss=0.3466, F1 Score=0.8705 | Val: Loss=0.6142, F1 Score=0.7563
# Epoch   9/300 | Train: Loss=0.4146, F1 Score=0.8398 | Val: Loss=0.6672, F1 Score=0.7721
# Epoch  10/300 | Train: Loss=0.3367, F1 Score=0.8630 | Val: Loss=0.6892, F1 Score=0.7772
# Epoch  11/300 | Train: Loss=0.3041, F1 Score=0.8927 | Val: Loss=0.5430, F1 Score=0.8048
# Epoch  12/300 | Train: Loss=0.2902, F1 Score=0.8969 | Val: Loss=0.5301, F1 Score=0.8243
# Epoch  13/300 | Train: Loss=0.2670, F1 Score=0.9109 | Val: Loss=0.4893, F1 Score=0.8390
# Epoch  14/300 | Train: Loss=0.2808, F1 Score=0.9025 | Val: Loss=0.4994, F1 Score=0.8403
# Epoch  15/300 | Train: Loss=0.2308, F1 Score=0.9167 | Val: Loss=0.5355, F1 Score=0.8406
# Epoch  16/300 | Train: Loss=0.2709, F1 Score=0.9032 | Val: Loss=0.4905, F1 Score=0.8286
# Epoch  17/300 | Train: Loss=0.2302, F1 Score=0.9137 | Val: Loss=0.4980, F1 Score=0.8509
# Epoch  18/300 | Train: Loss=0.2303, F1 Score=0.9202 | Val: Loss=0.5323, F1 Score=0.8465
# Epoch  19/300 | Train: Loss=0.2210, F1 Score=0.9245 | Val: Loss=0.5009, F1 Score=0.8515
# Epoch  20/300 | Train: Loss=0.2183, F1 Score=0.9246 | Val: Loss=0.5706, F1 Score=0.8258
# Epoch  21/300 | Train: Loss=0.2479, F1 Score=0.9107 | Val: Loss=0.5119, F1 Score=0.8414
# Epoch  76/300 | Train: Loss=0.0552, F1 Score=0.9830 | Val: Loss=0.5845, F1 Score=0.8644
# Epoch  77/300 | Train: Loss=0.1499, F1 Score=0.9518 | Val: Loss=0.4409, F1 Score=0.8592
# Epoch  78/300 | Train: Loss=0.0723, F1 Score=0.9769 | Val: Loss=0.5192, F1 Score=0.8766
# Epoch  79/300 | Train: Loss=0.0492, F1 Score=0.9845 | Val: Loss=0.5052, F1 Score=0.8848
# Epoch  80/300 | Train: Loss=0.0540, F1 Score=0.9847 | Val: Loss=0.5537, F1 Score=0.8736
# Epoch  81/300 | Train: Loss=0.0479, F1 Score=0.9852 | Val: Loss=0.5949, F1 Score=0.8776
# Epoch  82/300 | Train: Loss=0.0555, F1 Score=0.9818 | Val: Loss=0.5315, F1 Score=0.8719
# Epoch  83/300 | Train: Loss=0.0635, F1 Score=0.9803 | Val: Loss=0.6516, F1 Score=0.8684
# Epoch  84/300 | Train: Loss=0.0541, F1 Score=0.9834 | Val: Loss=0.5590, F1 Score=0.8694
# Epoch  85/300 | Train: Loss=0.0409, F1 Score=0.9871 | Val: Loss=0.5619, F1 Score=0.8779
# Epoch  86/300 | Train: Loss=0.0349, F1 Score=0.9873 | Val: Loss=0.6733, F1 Score=0.8630
# Epoch  87/300 | Train: Loss=0.0703, F1 Score=0.9773 | Val: Loss=0.5837, F1 Score=0.8713
# Epoch  88/300 | Train: Loss=0.0494, F1 Score=0.9862 | Val: Loss=0.5117, F1 Score=0.8915
# Epoch  89/300 | Train: Loss=0.0573, F1 Score=0.9823 | Val: Loss=0.5125, F1 Score=0.8813
# Epoch  90/300 | Train: Loss=0.0291, F1 Score=0.9909 | Val: Loss=0.5512, F1 Score=0.8858
# Epoch  91/300 | Train: Loss=0.1217, F1 Score=0.9628 | Val: Loss=0.7232, F1 Score=0.8280
# Epoch  92/300 | Train: Loss=0.1085, F1 Score=0.9672 | Val: Loss=0.5182, F1 Score=0.8713
# Epoch  93/300 | Train: Loss=0.0611, F1 Score=0.9799 | Val: Loss=0.5420, F1 Score=0.8753
# Epoch  94/300 | Train: Loss=0.0588, F1 Score=0.9824 | Val: Loss=0.5450, F1 Score=0.8806
# Epoch  95/300 | Train: Loss=0.0461, F1 Score=0.9871 | Val: Loss=0.5862, F1 Score=0.8844
# Epoch  96/300 | Train: Loss=0.0457, F1 Score=0.9856 | Val: Loss=0.5343, F1 Score=0.8833
# Epoch  97/300 | Train: Loss=0.0356, F1 Score=0.9894 | Val: Loss=0.5928, F1 Score=0.8798
# Epoch  98/300 | Train: Loss=0.0967, F1 Score=0.9676 | Val: Loss=0.5104, F1 Score=0.8680
# Epoch  99/300 | Train: Loss=0.0420, F1 Score=0.9879 | Val: Loss=0.5559, F1 Score=0.8869
# Epoch 100/300 | Train: Loss=0.0267, F1 Score=0.9913 | Val: Loss=0.6026, F1 Score=0.8933
# Epoch 101/300 | Train: Loss=0.0310, F1 Score=0.9909 | Val: Loss=0.5848, F1 Score=0.8860
# Epoch 183/300 | Train: Loss=0.0301, F1 Score=0.9913 | Val: Loss=0.5854, F1 Score=0.8923
# Epoch 184/300 | Train: Loss=0.0156, F1 Score=0.9945 | Val: Loss=0.5863, F1 Score=0.8900
# Epoch 185/300 | Train: Loss=0.0229, F1 Score=0.9943 | Val: Loss=0.6261, F1 Score=0.8849
# Epoch 186/300 | Train: Loss=0.0358, F1 Score=0.9886 | Val: Loss=0.6005, F1 Score=0.8887
# Epoch 187/300 | Train: Loss=0.0083, F1 Score=0.9977 | Val: Loss=0.6425, F1 Score=0.8890
# Epoch 188/300 | Train: Loss=0.0122, F1 Score=0.9956 | Val: Loss=0.6651, F1 Score=0.8906
# Epoch 189/300 | Train: Loss=0.0124, F1 Score=0.9962 | Val: Loss=0.7925, F1 Score=0.8786
# Epoch 190/300 | Train: Loss=0.0537, F1 Score=0.9835 | Val: Loss=0.8595, F1 Score=0.8600
# Epoch 191/300 | Train: Loss=0.0324, F1 Score=0.9899 | Val: Loss=0.5891, F1 Score=0.8897
# Epoch 192/300 | Train: Loss=0.0077, F1 Score=0.9975 | Val: Loss=0.6679, F1 Score=0.8821
# Epoch 193/300 | Train: Loss=0.0054, F1 Score=0.9983 | Val: Loss=0.6851, F1 Score=0.8811
# Epoch 194/300 | Train: Loss=0.0112, F1 Score=0.9968 | Val: Loss=0.6402, F1 Score=0.8864
# Epoch 195/300 | Train: Loss=0.0244, F1 Score=0.9935 | Val: Loss=0.6348, F1 Score=0.8840
# Epoch 196/300 | Train: Loss=0.0350, F1 Score=0.9884 | Val: Loss=0.6035, F1 Score=0.8862
# Epoch 197/300 | Train: Loss=0.0285, F1 Score=0.9907 | Val: Loss=0.6768, F1 Score=0.8802
# Epoch 198/300 | Train: Loss=0.0083, F1 Score=0.9975 | Val: Loss=0.7201, F1 Score=0.8736
# Epoch 199/300 | Train: Loss=0.0083, F1 Score=0.9977 | Val: Loss=0.6920, F1 Score=0.8755
# Epoch 200/300 | Train: Loss=0.0066, F1 Score=0.9985 | Val: Loss=0.7520, F1 Score=0.8714
# Epoch 201/300 | Train: Loss=0.0232, F1 Score=0.9926 | Val: Loss=0.5828, F1 Score=0.8973
# Epoch 202/300 | Train: Loss=0.0079, F1 Score=0.9977 | Val: Loss=0.5987, F1 Score=0.8946
# Epoch 203/300 | Train: Loss=0.0301, F1 Score=0.9909 | Val: Loss=0.6942, F1 Score=0.8830
# Early stopping triggered after 203 epochs.
# Best model restored from epoch 153 with val_f1 0.8979
# Split 3/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.6799, F1 Score=0.6788 | Val: Loss=0.6202, F1 Score=0.6834
# Epoch   2/300 | Train: Loss=0.5686, F1 Score=0.7511 | Val: Loss=0.8082, F1 Score=0.6741
# Epoch   3/300 | Train: Loss=0.5710, F1 Score=0.7533 | Val: Loss=0.6166, F1 Score=0.7573
# Epoch   4/300 | Train: Loss=0.4680, F1 Score=0.8143 | Val: Loss=0.5230, F1 Score=0.7773
# Epoch  32/300 | Train: Loss=0.1752, F1 Score=0.9423 | Val: Loss=0.5499, F1 Score=0.8419
# Epoch  33/300 | Train: Loss=0.1520, F1 Score=0.9490 | Val: Loss=0.5026, F1 Score=0.8650
# Epoch  34/300 | Train: Loss=0.2340, F1 Score=0.9249 | Val: Loss=0.5432, F1 Score=0.8550
# Epoch  35/300 | Train: Loss=0.1283, F1 Score=0.9571 | Val: Loss=0.5018, F1 Score=0.8742
# Epoch  36/300 | Train: Loss=0.1087, F1 Score=0.9654 | Val: Loss=0.5412, F1 Score=0.8702
# Epoch  37/300 | Train: Loss=0.1612, F1 Score=0.9445 | Val: Loss=0.4727, F1 Score=0.8632
# Epoch  38/300 | Train: Loss=0.1768, F1 Score=0.9456 | Val: Loss=0.5042, F1 Score=0.8622
# Epoch  39/300 | Train: Loss=0.1900, F1 Score=0.9417 | Val: Loss=0.5213, F1 Score=0.8368
# Epoch  40/300 | Train: Loss=0.2063, F1 Score=0.9285 | Val: Loss=0.4079, F1 Score=0.8802
# Epoch  41/300 | Train: Loss=0.1535, F1 Score=0.9465 | Val: Loss=0.4130, F1 Score=0.8699
# Epoch  42/300 | Train: Loss=0.1142, F1 Score=0.9607 | Val: Loss=0.5509, F1 Score=0.8518
# Epoch  43/300 | Train: Loss=0.0983, F1 Score=0.9669 | Val: Loss=0.5246, F1 Score=0.8531
# Epoch  44/300 | Train: Loss=0.0874, F1 Score=0.9724 | Val: Loss=0.6328, F1 Score=0.8250
# Epoch  45/300 | Train: Loss=0.1220, F1 Score=0.9617 | Val: Loss=0.6091, F1 Score=0.8312
# Epoch  46/300 | Train: Loss=0.0822, F1 Score=0.9760 | Val: Loss=0.7112, F1 Score=0.8478
# Epoch  47/300 | Train: Loss=0.1749, F1 Score=0.9446 | Val: Loss=0.5541, F1 Score=0.8446
# Epoch  48/300 | Train: Loss=0.1708, F1 Score=0.9446 | Val: Loss=0.4673, F1 Score=0.8765
# Epoch  49/300 | Train: Loss=0.1004, F1 Score=0.9682 | Val: Loss=0.5804, F1 Score=0.8622
# Epoch  50/300 | Train: Loss=0.0967, F1 Score=0.9712 | Val: Loss=0.6561, F1 Score=0.8545
# Epoch  51/300 | Train: Loss=0.0788, F1 Score=0.9734 | Val: Loss=0.5875, F1 Score=0.8661
# Epoch  52/300 | Train: Loss=0.0695, F1 Score=0.9782 | Val: Loss=0.5521, F1 Score=0.8648
# Epoch  53/300 | Train: Loss=0.0929, F1 Score=0.9709 | Val: Loss=0.5122, F1 Score=0.8611
# Epoch  54/300 | Train: Loss=0.1032, F1 Score=0.9612 | Val: Loss=0.4969, F1 Score=0.8676
# Epoch  55/300 | Train: Loss=0.0912, F1 Score=0.9704 | Val: Loss=0.7647, F1 Score=0.8422
# Epoch  56/300 | Train: Loss=0.1921, F1 Score=0.9366 | Val: Loss=0.5493, F1 Score=0.8561
# Epoch  57/300 | Train: Loss=0.0915, F1 Score=0.9686 | Val: Loss=0.6176, F1 Score=0.8612
# Epoch  58/300 | Train: Loss=0.1035, F1 Score=0.9690 | Val: Loss=0.5609, F1 Score=0.8649
# Epoch  85/300 | Train: Loss=0.0361, F1 Score=0.9878 | Val: Loss=0.6093, F1 Score=0.8894
# Epoch  86/300 | Train: Loss=0.1311, F1 Score=0.9621 | Val: Loss=0.5218, F1 Score=0.8801
# Epoch  87/300 | Train: Loss=0.0701, F1 Score=0.9786 | Val: Loss=0.5311, F1 Score=0.8657
# Epoch  88/300 | Train: Loss=0.1215, F1 Score=0.9616 | Val: Loss=0.5309, F1 Score=0.8659
# Epoch  89/300 | Train: Loss=0.0647, F1 Score=0.9780 | Val: Loss=0.5202, F1 Score=0.8871
# Epoch  90/300 | Train: Loss=0.0441, F1 Score=0.9844 | Val: Loss=1.1912, F1 Score=0.6741
# Epoch  91/300 | Train: Loss=0.2408, F1 Score=0.9266 | Val: Loss=0.4871, F1 Score=0.8567
# Epoch  92/300 | Train: Loss=0.0712, F1 Score=0.9746 | Val: Loss=0.6009, F1 Score=0.8700
# Epoch  93/300 | Train: Loss=0.0687, F1 Score=0.9750 | Val: Loss=0.5415, F1 Score=0.8684
# Epoch  94/300 | Train: Loss=0.0441, F1 Score=0.9864 | Val: Loss=0.5850, F1 Score=0.8827
# Epoch  95/300 | Train: Loss=0.0523, F1 Score=0.9811 | Val: Loss=0.5497, F1 Score=0.8762
# Epoch  96/300 | Train: Loss=0.0330, F1 Score=0.9887 | Val: Loss=0.6159, F1 Score=0.8680
# Epoch  97/300 | Train: Loss=0.0315, F1 Score=0.9879 | Val: Loss=0.5356, F1 Score=0.8836
# Epoch  98/300 | Train: Loss=0.0405, F1 Score=0.9875 | Val: Loss=0.5624, F1 Score=0.8665
# Epoch  99/300 | Train: Loss=0.0366, F1 Score=0.9867 | Val: Loss=0.5878, F1 Score=0.8566
# Epoch 100/300 | Train: Loss=0.1942, F1 Score=0.9396 | Val: Loss=0.4989, F1 Score=0.8710
# Epoch 101/300 | Train: Loss=0.0656, F1 Score=0.9759 | Val: Loss=0.5606, F1 Score=0.8801
# Epoch 102/300 | Train: Loss=0.1953, F1 Score=0.9384 | Val: Loss=0.5735, F1 Score=0.8493
# Epoch 103/300 | Train: Loss=0.0983, F1 Score=0.9687 | Val: Loss=0.6411, F1 Score=0.8650
# Epoch 104/300 | Train: Loss=0.0939, F1 Score=0.9682 | Val: Loss=0.6190, F1 Score=0.8685
# Epoch 105/300 | Train: Loss=0.0767, F1 Score=0.9753 | Val: Loss=0.5361, F1 Score=0.8716
# Epoch 106/300 | Train: Loss=0.0695, F1 Score=0.9764 | Val: Loss=0.5247, F1 Score=0.8722
# Epoch 107/300 | Train: Loss=0.0810, F1 Score=0.9750 | Val: Loss=0.5390, F1 Score=0.8608
# Epoch 108/300 | Train: Loss=0.1712, F1 Score=0.9479 | Val: Loss=0.5905, F1 Score=0.8647
# Epoch 109/300 | Train: Loss=0.1029, F1 Score=0.9603 | Val: Loss=0.6042, F1 Score=0.8647
# Epoch 110/300 | Train: Loss=0.0912, F1 Score=0.9669 | Val: Loss=0.5588, F1 Score=0.8788
# Epoch 111/300 | Train: Loss=0.0595, F1 Score=0.9779 | Val: Loss=0.6645, F1 Score=0.8724
# Epoch 112/300 | Train: Loss=0.1614, F1 Score=0.9488 | Val: Loss=0.6060, F1 Score=0.8003
# Epoch 113/300 | Train: Loss=0.1025, F1 Score=0.9643 | Val: Loss=0.5413, F1 Score=0.8686
# Epoch 114/300 | Train: Loss=0.0629, F1 Score=0.9792 | Val: Loss=0.5717, F1 Score=0.8641
# Epoch 115/300 | Train: Loss=0.0557, F1 Score=0.9808 | Val: Loss=0.5601, F1 Score=0.8682
# Epoch 116/300 | Train: Loss=0.1288, F1 Score=0.9623 | Val: Loss=0.4740, F1 Score=0.8358
# Epoch 117/300 | Train: Loss=0.0920, F1 Score=0.9667 | Val: Loss=0.6035, F1 Score=0.8627
# Epoch 118/300 | Train: Loss=0.0612, F1 Score=0.9768 | Val: Loss=0.6207, F1 Score=0.8843
# Epoch 119/300 | Train: Loss=0.0555, F1 Score=0.9813 | Val: Loss=0.5637, F1 Score=0.8783
# Epoch 120/300 | Train: Loss=0.0697, F1 Score=0.9787 | Val: Loss=0.6322, F1 Score=0.8695
# Epoch 121/300 | Train: Loss=0.0382, F1 Score=0.9874 | Val: Loss=0.4266, F1 Score=0.9045
# Epoch 122/300 | Train: Loss=0.0509, F1 Score=0.9830 | Val: Loss=0.6074, F1 Score=0.8869
# Epoch 123/300 | Train: Loss=0.1540, F1 Score=0.9574 | Val: Loss=0.5888, F1 Score=0.8691
# Epoch 124/300 | Train: Loss=0.0453, F1 Score=0.9834 | Val: Loss=0.6621, F1 Score=0.8708
# Epoch 125/300 | Train: Loss=0.0465, F1 Score=0.9853 | Val: Loss=0.6923, F1 Score=0.8740
# Epoch 126/300 | Train: Loss=0.0395, F1 Score=0.9873 | Val: Loss=0.6571, F1 Score=0.8636
# Epoch 127/300 | Train: Loss=0.0565, F1 Score=0.9813 | Val: Loss=0.6755, F1 Score=0.8617
# Epoch 128/300 | Train: Loss=0.0793, F1 Score=0.9751 | Val: Loss=0.5936, F1 Score=0.8683
# Epoch 129/300 | Train: Loss=0.0339, F1 Score=0.9890 | Val: Loss=0.6528, F1 Score=0.8666
# Epoch 130/300 | Train: Loss=0.0219, F1 Score=0.9924 | Val: Loss=0.6997, F1 Score=0.8649
# Epoch 131/300 | Train: Loss=0.0238, F1 Score=0.9919 | Val: Loss=0.6999, F1 Score=0.8709
# Epoch 132/300 | Train: Loss=0.0635, F1 Score=0.9814 | Val: Loss=0.6451, F1 Score=0.8427
# Epoch 133/300 | Train: Loss=0.0430, F1 Score=0.9862 | Val: Loss=0.6562, F1 Score=0.8631
# Epoch 134/300 | Train: Loss=0.0332, F1 Score=0.9864 | Val: Loss=0.6499, F1 Score=0.8785
# Epoch 135/300 | Train: Loss=0.0265, F1 Score=0.9924 | Val: Loss=0.5554, F1 Score=0.8884
# Epoch 136/300 | Train: Loss=0.0211, F1 Score=0.9913 | Val: Loss=0.6964, F1 Score=0.8698
# Epoch 137/300 | Train: Loss=0.0279, F1 Score=0.9896 | Val: Loss=0.7492, F1 Score=0.8682
# Epoch 138/300 | Train: Loss=0.0304, F1 Score=0.9898 | Val: Loss=0.7415, F1 Score=0.8778
# Epoch 166/300 | Train: Loss=0.0447, F1 Score=0.9872 | Val: Loss=0.6571, F1 Score=0.8645
# Epoch 167/300 | Train: Loss=0.0305, F1 Score=0.9886 | Val: Loss=0.7436, F1 Score=0.8714
# Epoch 168/300 | Train: Loss=0.0312, F1 Score=0.9885 | Val: Loss=0.6951, F1 Score=0.8757
# Epoch 169/300 | Train: Loss=0.0574, F1 Score=0.9803 | Val: Loss=0.7275, F1 Score=0.8674
# Epoch 170/300 | Train: Loss=0.0254, F1 Score=0.9896 | Val: Loss=0.7718, F1 Score=0.8730
# Epoch 171/300 | Train: Loss=0.0202, F1 Score=0.9937 | Val: Loss=0.7536, F1 Score=0.8749
# Early stopping triggered after 171 epochs.
# Best model restored from epoch 121 with val_f1 0.9045
# Split 4/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.6512, F1 Score=0.6885 | Val: Loss=0.7419, F1 Score=0.6752
# Epoch   2/300 | Train: Loss=0.5600, F1 Score=0.7493 | Val: Loss=0.6325, F1 Score=0.7033
# Epoch   3/300 | Train: Loss=0.4562, F1 Score=0.8069 | Val: Loss=0.5931, F1 Score=0.7200
# Epoch   4/300 | Train: Loss=0.3879, F1 Score=0.8584 | Val: Loss=0.6049, F1 Score=0.7637
# Epoch   5/300 | Train: Loss=0.3637, F1 Score=0.8588 | Val: Loss=0.6590, F1 Score=0.7595
# Epoch   6/300 | Train: Loss=0.3351, F1 Score=0.8743 | Val: Loss=0.6649, F1 Score=0.7451
# Epoch   7/300 | Train: Loss=0.3066, F1 Score=0.8875 | Val: Loss=0.6533, F1 Score=0.7672
# Epoch   8/300 | Train: Loss=0.3197, F1 Score=0.8821 | Val: Loss=0.5617, F1 Score=0.7963
# Epoch   9/300 | Train: Loss=0.2883, F1 Score=0.8950 | Val: Loss=0.6026, F1 Score=0.7546
# Epoch  10/300 | Train: Loss=0.2826, F1 Score=0.8992 | Val: Loss=0.5828, F1 Score=0.7776
# Epoch  11/300 | Train: Loss=0.2568, F1 Score=0.9151 | Val: Loss=0.8579, F1 Score=0.7333
# Epoch  12/300 | Train: Loss=0.2560, F1 Score=0.9156 | Val: Loss=0.5357, F1 Score=0.8130
# Epoch  13/300 | Train: Loss=0.3261, F1 Score=0.8919 | Val: Loss=0.6015, F1 Score=0.7178
# Epoch  14/300 | Train: Loss=0.2321, F1 Score=0.9231 | Val: Loss=0.6515, F1 Score=0.8058
# Epoch  15/300 | Train: Loss=0.2996, F1 Score=0.8997 | Val: Loss=0.5423, F1 Score=0.7895
# Epoch  16/300 | Train: Loss=0.2182, F1 Score=0.9266 | Val: Loss=0.6386, F1 Score=0.7867
# Epoch  17/300 | Train: Loss=0.1787, F1 Score=0.9414 | Val: Loss=0.5818, F1 Score=0.7879
# Epoch  18/300 | Train: Loss=0.4146, F1 Score=0.8611 | Val: Loss=0.5997, F1 Score=0.7441
# Epoch  19/300 | Train: Loss=0.3164, F1 Score=0.8885 | Val: Loss=0.5110, F1 Score=0.8101
# Epoch  20/300 | Train: Loss=0.2334, F1 Score=0.9257 | Val: Loss=0.5667, F1 Score=0.8024
# Epoch  21/300 | Train: Loss=0.2307, F1 Score=0.9226 | Val: Loss=0.5371, F1 Score=0.8194
# ...
# Epoch 179/300 | Train: Loss=0.0454, F1 Score=0.9847 | Val: Loss=0.7266, F1 Score=0.8593
# Epoch 180/300 | Train: Loss=0.0312, F1 Score=0.9896 | Val: Loss=0.7808, F1 Score=0.8591
# Epoch 181/300 | Train: Loss=0.0187, F1 Score=0.9938 | Val: Loss=0.8706, F1 Score=0.8420
# Epoch 182/300 | Train: Loss=0.0347, F1 Score=0.9883 | Val: Loss=0.7391, F1 Score=0.8592
# Epoch 183/300 | Train: Loss=0.0262, F1 Score=0.9894 | Val: Loss=0.8571, F1 Score=0.8400
# Epoch 184/300 | Train: Loss=0.0270, F1 Score=0.9904 | Val: Loss=0.8179, F1 Score=0.8544
# Epoch 185/300 | Train: Loss=0.0285, F1 Score=0.9900 | Val: Loss=0.8396, F1 Score=0.8536
# Epoch 186/300 | Train: Loss=0.0407, F1 Score=0.9864 | Val: Loss=0.8145, F1 Score=0.8578
# Epoch 187/300 | Train: Loss=0.0208, F1 Score=0.9924 | Val: Loss=0.7321, F1 Score=0.8713
# Epoch 188/300 | Train: Loss=0.0308, F1 Score=0.9898 | Val: Loss=0.7482, F1 Score=0.8625
# Epoch 189/300 | Train: Loss=0.0289, F1 Score=0.9886 | Val: Loss=0.8133, F1 Score=0.8567
# Epoch 190/300 | Train: Loss=0.0232, F1 Score=0.9926 | Val: Loss=0.9326, F1 Score=0.8285
# Epoch 191/300 | Train: Loss=0.0480, F1 Score=0.9839 | Val: Loss=0.9979, F1 Score=0.8451
# Epoch 192/300 | Train: Loss=0.0663, F1 Score=0.9788 | Val: Loss=0.5497, F1 Score=0.8683
# Epoch 193/300 | Train: Loss=0.0584, F1 Score=0.9787 | Val: Loss=0.7169, F1 Score=0.8540
# Epoch 194/300 | Train: Loss=0.0356, F1 Score=0.9873 | Val: Loss=0.8746, F1 Score=0.8474
# Epoch 195/300 | Train: Loss=0.0241, F1 Score=0.9924 | Val: Loss=0.8963, F1 Score=0.8520
# Epoch 196/300 | Train: Loss=0.0234, F1 Score=0.9922 | Val: Loss=0.8107, F1 Score=0.8724
# Epoch 197/300 | Train: Loss=0.0450, F1 Score=0.9850 | Val: Loss=0.6310, F1 Score=0.8616
# Epoch 198/300 | Train: Loss=0.0253, F1 Score=0.9909 | Val: Loss=0.7721, F1 Score=0.8601
# Epoch 199/300 | Train: Loss=0.0465, F1 Score=0.9850 | Val: Loss=0.6626, F1 Score=0.8435
# Epoch 200/300 | Train: Loss=0.0402, F1 Score=0.9845 | Val: Loss=0.7479, F1 Score=0.8553
# Epoch 201/300 | Train: Loss=0.0221, F1 Score=0.9924 | Val: Loss=0.8660, F1 Score=0.8532
# Epoch 202/300 | Train: Loss=0.0260, F1 Score=0.9913 | Val: Loss=0.7692, F1 Score=0.8683
# Epoch 203/300 | Train: Loss=0.0373, F1 Score=0.9873 | Val: Loss=0.7315, F1 Score=0.8415
# Epoch 204/300 | Train: Loss=0.0221, F1 Score=0.9913 | Val: Loss=0.7572, F1 Score=0.8710
# Epoch 205/300 | Train: Loss=0.0197, F1 Score=0.9917 | Val: Loss=0.7362, F1 Score=0.8776
# Epoch 206/300 | Train: Loss=0.0230, F1 Score=0.9916 | Val: Loss=0.6601, F1 Score=0.8871
# Epoch 207/300 | Train: Loss=0.0163, F1 Score=0.9937 | Val: Loss=0.7264, F1 Score=0.8714
# Epoch 208/300 | Train: Loss=0.0148, F1 Score=0.9937 | Val: Loss=0.9734, F1 Score=0.8465
# Epoch 209/300 | Train: Loss=0.0975, F1 Score=0.9694 | Val: Loss=0.8767, F1 Score=0.8461
# Epoch 210/300 | Train: Loss=0.0653, F1 Score=0.9792 | Val: Loss=0.8484, F1 Score=0.8463
# Epoch 211/300 | Train: Loss=0.0402, F1 Score=0.9867 | Val: Loss=0.6861, F1 Score=0.8737
# Epoch 212/300 | Train: Loss=0.0256, F1 Score=0.9905 | Val: Loss=0.8322, F1 Score=0.8656
# Epoch 213/300 | Train: Loss=0.0354, F1 Score=0.9879 | Val: Loss=0.7361, F1 Score=0.8675
# Epoch 214/300 | Train: Loss=0.0253, F1 Score=0.9928 | Val: Loss=0.7279, F1 Score=0.8752
# Epoch 215/300 | Train: Loss=0.0173, F1 Score=0.9945 | Val: Loss=0.7268, F1 Score=0.8789
# Epoch 216/300 | Train: Loss=0.0234, F1 Score=0.9913 | Val: Loss=0.8910, F1 Score=0.8564
# Epoch 217/300 | Train: Loss=0.0555, F1 Score=0.9793 | Val: Loss=0.7075, F1 Score=0.8701
# Epoch 218/300 | Train: Loss=0.0201, F1 Score=0.9926 | Val: Loss=0.8300, F1 Score=0.8675
# Epoch 219/300 | Train: Loss=0.0233, F1 Score=0.9894 | Val: Loss=0.7314, F1 Score=0.8806
# Epoch 220/300 | Train: Loss=0.0205, F1 Score=0.9920 | Val: Loss=0.8422, F1 Score=0.8686
# Epoch 221/300 | Train: Loss=0.0149, F1 Score=0.9947 | Val: Loss=0.9072, F1 Score=0.8462
# Epoch 222/300 | Train: Loss=0.0211, F1 Score=0.9922 | Val: Loss=0.8075, F1 Score=0.8656
# Epoch 223/300 | Train: Loss=0.0173, F1 Score=0.9934 | Val: Loss=0.9169, F1 Score=0.8541
# Epoch 224/300 | Train: Loss=0.0149, F1 Score=0.9937 | Val: Loss=0.8685, F1 Score=0.8620
# Epoch 225/300 | Train: Loss=0.0266, F1 Score=0.9911 | Val: Loss=0.9855, F1 Score=0.8393
# Epoch 226/300 | Train: Loss=0.0344, F1 Score=0.9883 | Val: Loss=0.8578, F1 Score=0.8580
# Epoch 227/300 | Train: Loss=0.0696, F1 Score=0.9773 | Val: Loss=0.7991, F1 Score=0.8487
# Epoch 228/300 | Train: Loss=0.0374, F1 Score=0.9870 | Val: Loss=0.7148, F1 Score=0.8719
# Epoch 229/300 | Train: Loss=0.0297, F1 Score=0.9901 | Val: Loss=0.7424, F1 Score=0.8719
# Epoch 230/300 | Train: Loss=0.0211, F1 Score=0.9924 | Val: Loss=0.8768, F1 Score=0.8603
# Epoch 231/300 | Train: Loss=0.0125, F1 Score=0.9960 | Val: Loss=0.9051, F1 Score=0.8627
# Epoch 232/300 | Train: Loss=0.0491, F1 Score=0.9842 | Val: Loss=0.9015, F1 Score=0.8477
# Epoch 233/300 | Train: Loss=0.0329, F1 Score=0.9883 | Val: Loss=0.8432, F1 Score=0.8592
# Epoch 234/300 | Train: Loss=0.0216, F1 Score=0.9941 | Val: Loss=0.8938, F1 Score=0.8544
# Epoch 235/300 | Train: Loss=0.0138, F1 Score=0.9964 | Val: Loss=0.8752, F1 Score=0.8646
# Epoch 236/300 | Train: Loss=0.0155, F1 Score=0.9945 | Val: Loss=0.9924, F1 Score=0.8471
# Epoch 237/300 | Train: Loss=0.0121, F1 Score=0.9956 | Val: Loss=0.9574, F1 Score=0.8585
# Epoch 238/300 | Train: Loss=0.0126, F1 Score=0.9947 | Val: Loss=0.9560, F1 Score=0.8407
# Epoch 239/300 | Train: Loss=0.0272, F1 Score=0.9901 | Val: Loss=0.7405, F1 Score=0.8723
# Epoch 240/300 | Train: Loss=0.0161, F1 Score=0.9943 | Val: Loss=0.8939, F1 Score=0.8568
# Epoch 241/300 | Train: Loss=0.0170, F1 Score=0.9930 | Val: Loss=1.0411, F1 Score=0.8448
# Epoch 242/300 | Train: Loss=0.0122, F1 Score=0.9964 | Val: Loss=0.9846, F1 Score=0.8526
# Epoch 243/300 | Train: Loss=0.0100, F1 Score=0.9951 | Val: Loss=0.9252, F1 Score=0.8660
# Epoch 244/300 | Train: Loss=0.0297, F1 Score=0.9910 | Val: Loss=0.9968, F1 Score=0.8604
# Epoch 245/300 | Train: Loss=0.0409, F1 Score=0.9851 | Val: Loss=0.8983, F1 Score=0.8645
# Epoch 246/300 | Train: Loss=0.0443, F1 Score=0.9853 | Val: Loss=0.8600, F1 Score=0.8541
# Epoch 247/300 | Train: Loss=0.0229, F1 Score=0.9926 | Val: Loss=0.7585, F1 Score=0.8589
# Epoch 248/300 | Train: Loss=0.0153, F1 Score=0.9949 | Val: Loss=0.8217, F1 Score=0.8564
# Epoch 249/300 | Train: Loss=0.0428, F1 Score=0.9833 | Val: Loss=0.7350, F1 Score=0.8718
# Epoch 250/300 | Train: Loss=0.0223, F1 Score=0.9930 | Val: Loss=0.7780, F1 Score=0.8601
# Epoch 251/300 | Train: Loss=0.0083, F1 Score=0.9977 | Val: Loss=0.8660, F1 Score=0.8572
# Epoch 252/300 | Train: Loss=0.0260, F1 Score=0.9918 | Val: Loss=0.7581, F1 Score=0.8647
# Epoch 253/300 | Train: Loss=0.0115, F1 Score=0.9966 | Val: Loss=0.9045, F1 Score=0.8679
# Epoch 254/300 | Train: Loss=0.0135, F1 Score=0.9954 | Val: Loss=0.8687, F1 Score=0.8728
# Epoch 255/300 | Train: Loss=0.0105, F1 Score=0.9968 | Val: Loss=0.8700, F1 Score=0.8741
# Epoch 256/300 | Train: Loss=0.0435, F1 Score=0.9888 | Val: Loss=0.7902, F1 Score=0.8658
# Early stopping triggered after 256 epochs.
# Best model restored from epoch 206 with val_f1 0.8871
# Split 5/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.6476, F1 Score=0.7011 | Val: Loss=0.7518, F1 Score=0.6086
# Epoch   2/300 | Train: Loss=0.5375, F1 Score=0.7554 | Val: Loss=0.8020, F1 Score=0.6540
# Epoch   3/300 | Train: Loss=0.4728, F1 Score=0.8045 | Val: Loss=0.6472, F1 Score=0.7165
# Epoch   4/300 | Train: Loss=0.4361, F1 Score=0.8128 | Val: Loss=0.6451, F1 Score=0.7437
# Epoch   5/300 | Train: Loss=0.4053, F1 Score=0.8333 | Val: Loss=0.6177, F1 Score=0.7541
# Epoch   6/300 | Train: Loss=0.3598, F1 Score=0.8632 | Val: Loss=0.5766, F1 Score=0.8189
# Epoch   7/300 | Train: Loss=0.3201, F1 Score=0.8752 | Val: Loss=0.5085, F1 Score=0.8020
# Epoch   8/300 | Train: Loss=0.3159, F1 Score=0.8855 | Val: Loss=0.4781, F1 Score=0.8145
# Epoch   9/300 | Train: Loss=0.3034, F1 Score=0.8873 | Val: Loss=0.4681, F1 Score=0.8098
# Epoch  10/300 | Train: Loss=0.2930, F1 Score=0.8969 | Val: Loss=0.5277, F1 Score=0.8088
# Epoch  11/300 | Train: Loss=0.3198, F1 Score=0.8771 | Val: Loss=0.4688, F1 Score=0.8268
# Epoch  12/300 | Train: Loss=0.2841, F1 Score=0.8949 | Val: Loss=0.4184, F1 Score=0.8394
# Epoch  13/300 | Train: Loss=0.2678, F1 Score=0.9036 | Val: Loss=0.4384, F1 Score=0.8281
# Epoch  14/300 | Train: Loss=0.2562, F1 Score=0.9099 | Val: Loss=0.4348, F1 Score=0.8515
# Epoch  15/300 | Train: Loss=0.2545, F1 Score=0.9113 | Val: Loss=0.4872, F1 Score=0.8457
# Epoch  16/300 | Train: Loss=0.2326, F1 Score=0.9197 | Val: Loss=0.4858, F1 Score=0.8377
# Epoch  17/300 | Train: Loss=0.2129, F1 Score=0.9224 | Val: Loss=0.4236, F1 Score=0.8420
# Epoch  18/300 | Train: Loss=0.1898, F1 Score=0.9327 | Val: Loss=0.4420, F1 Score=0.8358
# Epoch  19/300 | Train: Loss=0.2213, F1 Score=0.9235 | Val: Loss=0.3550, F1 Score=0.8607
# Epoch  20/300 | Train: Loss=0.1741, F1 Score=0.9364 | Val: Loss=0.3596, F1 Score=0.8827
# Epoch  21/300 | Train: Loss=0.1856, F1 Score=0.9336 | Val: Loss=0.3760, F1 Score=0.8702
# Epoch  22/300 | Train: Loss=0.1570, F1 Score=0.9443 | Val: Loss=0.3545, F1 Score=0.8897
# Epoch  23/300 | Train: Loss=0.1570, F1 Score=0.9408 | Val: Loss=0.3531, F1 Score=0.8840
# Epoch  24/300 | Train: Loss=0.1484, F1 Score=0.9508 | Val: Loss=0.3629, F1 Score=0.8808
# Epoch  25/300 | Train: Loss=0.1625, F1 Score=0.9433 | Val: Loss=0.3136, F1 Score=0.8976
# Epoch  26/300 | Train: Loss=0.1177, F1 Score=0.9602 | Val: Loss=0.3461, F1 Score=0.9131
# Epoch  27/300 | Train: Loss=0.1929, F1 Score=0.9369 | Val: Loss=0.4159, F1 Score=0.8543
# Epoch  28/300 | Train: Loss=0.1552, F1 Score=0.9480 | Val: Loss=0.4315, F1 Score=0.8756
# Epoch  29/300 | Train: Loss=0.1259, F1 Score=0.9575 | Val: Loss=0.4236, F1 Score=0.8924
# Epoch  30/300 | Train: Loss=0.1738, F1 Score=0.9412 | Val: Loss=0.3557, F1 Score=0.9082
# Epoch  31/300 | Train: Loss=0.1373, F1 Score=0.9514 | Val: Loss=0.5094, F1 Score=0.8653
# Epoch  32/300 | Train: Loss=0.1562, F1 Score=0.9486 | Val: Loss=0.3744, F1 Score=0.9005
# Epoch  33/300 | Train: Loss=0.1202, F1 Score=0.9602 | Val: Loss=0.5256, F1 Score=0.8615
# Epoch  34/300 | Train: Loss=0.1769, F1 Score=0.9363 | Val: Loss=0.3462, F1 Score=0.8925
# Epoch  35/300 | Train: Loss=0.1769, F1 Score=0.9486 | Val: Loss=0.3784, F1 Score=0.8918
# Epoch  36/300 | Train: Loss=0.2092, F1 Score=0.9359 | Val: Loss=0.3428, F1 Score=0.9010
# Epoch  37/300 | Train: Loss=0.1262, F1 Score=0.9561 | Val: Loss=0.3244, F1 Score=0.8990
# Epoch  38/300 | Train: Loss=0.1317, F1 Score=0.9569 | Val: Loss=0.3702, F1 Score=0.8838
# Epoch  39/300 | Train: Loss=0.1282, F1 Score=0.9563 | Val: Loss=0.5098, F1 Score=0.8566
# Epoch  40/300 | Train: Loss=0.1065, F1 Score=0.9618 | Val: Loss=0.3676, F1 Score=0.9055
# Epoch  41/300 | Train: Loss=0.1043, F1 Score=0.9637 | Val: Loss=0.3447, F1 Score=0.9085
# Epoch  42/300 | Train: Loss=0.0970, F1 Score=0.9674 | Val: Loss=0.6102, F1 Score=0.8463
# Epoch  43/300 | Train: Loss=0.1023, F1 Score=0.9665 | Val: Loss=0.3220, F1 Score=0.9172
# Epoch  44/300 | Train: Loss=0.0695, F1 Score=0.9755 | Val: Loss=0.3998, F1 Score=0.8864
# Epoch  45/300 | Train: Loss=0.0867, F1 Score=0.9740 | Val: Loss=0.7423, F1 Score=0.8157
# Epoch  46/300 | Train: Loss=0.1279, F1 Score=0.9554 | Val: Loss=0.3697, F1 Score=0.9097
# Epoch  47/300 | Train: Loss=0.1608, F1 Score=0.9473 | Val: Loss=0.4090, F1 Score=0.8830
# Epoch  48/300 | Train: Loss=0.1132, F1 Score=0.9616 | Val: Loss=0.3283, F1 Score=0.9173
# Epoch  49/300 | Train: Loss=0.0900, F1 Score=0.9701 | Val: Loss=0.3085, F1 Score=0.9148
# Epoch  50/300 | Train: Loss=0.1257, F1 Score=0.9545 | Val: Loss=0.2480, F1 Score=0.9337
# Epoch  51/300 | Train: Loss=0.0981, F1 Score=0.9676 | Val: Loss=0.3506, F1 Score=0.9097
# Epoch  52/300 | Train: Loss=0.1121, F1 Score=0.9619 | Val: Loss=0.2777, F1 Score=0.9136
# Epoch  53/300 | Train: Loss=0.0664, F1 Score=0.9777 | Val: Loss=0.3381, F1 Score=0.9024
# Epoch  54/300 | Train: Loss=0.1494, F1 Score=0.9543 | Val: Loss=0.2972, F1 Score=0.8984
# Epoch  55/300 | Train: Loss=0.0792, F1 Score=0.9714 | Val: Loss=0.3644, F1 Score=0.9048
# Epoch  56/300 | Train: Loss=0.0642, F1 Score=0.9779 | Val: Loss=0.3173, F1 Score=0.9168
# Epoch  57/300 | Train: Loss=0.0596, F1 Score=0.9800 | Val: Loss=0.3567, F1 Score=0.9108
# Epoch  58/300 | Train: Loss=0.1700, F1 Score=0.9503 | Val: Loss=0.4370, F1 Score=0.8290
# Epoch  59/300 | Train: Loss=0.0925, F1 Score=0.9698 | Val: Loss=0.3034, F1 Score=0.9166
# Epoch  60/300 | Train: Loss=0.0700, F1 Score=0.9789 | Val: Loss=0.3087, F1 Score=0.9123
# Epoch  61/300 | Train: Loss=0.0554, F1 Score=0.9816 | Val: Loss=0.3547, F1 Score=0.9155
# Epoch  62/300 | Train: Loss=0.0825, F1 Score=0.9735 | Val: Loss=0.2792, F1 Score=0.9205
# Epoch  63/300 | Train: Loss=0.0637, F1 Score=0.9803 | Val: Loss=0.3055, F1 Score=0.9189
# Epoch  64/300 | Train: Loss=0.0561, F1 Score=0.9816 | Val: Loss=0.3586, F1 Score=0.9195
# Epoch  65/300 | Train: Loss=0.0627, F1 Score=0.9790 | Val: Loss=0.2758, F1 Score=0.9252
# Epoch  66/300 | Train: Loss=0.0641, F1 Score=0.9796 | Val: Loss=0.2990, F1 Score=0.9239
# Epoch  67/300 | Train: Loss=0.0595, F1 Score=0.9784 | Val: Loss=0.3073, F1 Score=0.9220
# Epoch  68/300 | Train: Loss=0.0435, F1 Score=0.9852 | Val: Loss=0.3856, F1 Score=0.9211
# Epoch  69/300 | Train: Loss=0.0495, F1 Score=0.9833 | Val: Loss=0.3479, F1 Score=0.9157
# Epoch  70/300 | Train: Loss=0.1503, F1 Score=0.9484 | Val: Loss=0.3256, F1 Score=0.8996
# Epoch  71/300 | Train: Loss=0.0854, F1 Score=0.9714 | Val: Loss=0.3498, F1 Score=0.9099
# Epoch  72/300 | Train: Loss=0.1331, F1 Score=0.9597 | Val: Loss=0.3738, F1 Score=0.8929
# Epoch  73/300 | Train: Loss=0.0948, F1 Score=0.9663 | Val: Loss=0.3993, F1 Score=0.8946
# Epoch  74/300 | Train: Loss=0.0847, F1 Score=0.9739 | Val: Loss=0.3443, F1 Score=0.9115
# Epoch  75/300 | Train: Loss=0.0663, F1 Score=0.9781 | Val: Loss=0.3992, F1 Score=0.9136
# Epoch  76/300 | Train: Loss=0.0740, F1 Score=0.9761 | Val: Loss=0.3147, F1 Score=0.9176
# Epoch  77/300 | Train: Loss=0.1290, F1 Score=0.9580 | Val: Loss=0.3139, F1 Score=0.9134
# Epoch  78/300 | Train: Loss=0.0571, F1 Score=0.9797 | Val: Loss=0.3780, F1 Score=0.9066
# Epoch  79/300 | Train: Loss=0.0537, F1 Score=0.9828 | Val: Loss=0.5159, F1 Score=0.8900
# Epoch  80/300 | Train: Loss=0.0785, F1 Score=0.9767 | Val: Loss=0.3956, F1 Score=0.9095
# Epoch  81/300 | Train: Loss=0.0715, F1 Score=0.9731 | Val: Loss=0.4459, F1 Score=0.9061
# Epoch  82/300 | Train: Loss=0.0514, F1 Score=0.9835 | Val: Loss=0.3723, F1 Score=0.9112
# Epoch  83/300 | Train: Loss=0.0501, F1 Score=0.9826 | Val: Loss=0.4418, F1 Score=0.9006
# Epoch  84/300 | Train: Loss=0.0711, F1 Score=0.9792 | Val: Loss=0.3750, F1 Score=0.9081
# Epoch  85/300 | Train: Loss=0.0949, F1 Score=0.9703 | Val: Loss=0.4149, F1 Score=0.8959
# Epoch  86/300 | Train: Loss=0.1343, F1 Score=0.9608 | Val: Loss=0.5544, F1 Score=0.8712
# Epoch  87/300 | Train: Loss=0.1071, F1 Score=0.9693 | Val: Loss=0.4707, F1 Score=0.8878
# Epoch  88/300 | Train: Loss=0.0800, F1 Score=0.9778 | Val: Loss=0.4452, F1 Score=0.9071
# Epoch  89/300 | Train: Loss=0.0650, F1 Score=0.9801 | Val: Loss=0.3796, F1 Score=0.9099
# Epoch  90/300 | Train: Loss=0.0611, F1 Score=0.9808 | Val: Loss=0.5729, F1 Score=0.8817
# Epoch  91/300 | Train: Loss=0.1064, F1 Score=0.9662 | Val: Loss=0.4226, F1 Score=0.8924
# Epoch  92/300 | Train: Loss=0.0831, F1 Score=0.9720 | Val: Loss=0.3764, F1 Score=0.8988
# Epoch  93/300 | Train: Loss=0.0487, F1 Score=0.9810 | Val: Loss=0.4580, F1 Score=0.8871
# Epoch  94/300 | Train: Loss=0.0610, F1 Score=0.9801 | Val: Loss=0.4052, F1 Score=0.9193
# Epoch  95/300 | Train: Loss=0.0475, F1 Score=0.9836 | Val: Loss=0.4082, F1 Score=0.9134
# Epoch  96/300 | Train: Loss=0.0476, F1 Score=0.9823 | Val: Loss=0.4064, F1 Score=0.9206
# Epoch  97/300 | Train: Loss=0.0494, F1 Score=0.9859 | Val: Loss=0.4779, F1 Score=0.8928
# Epoch  98/300 | Train: Loss=0.0520, F1 Score=0.9842 | Val: Loss=0.3881, F1 Score=0.8982
# Epoch  99/300 | Train: Loss=0.0582, F1 Score=0.9811 | Val: Loss=0.5302, F1 Score=0.8952
# Epoch 100/300 | Train: Loss=0.0947, F1 Score=0.9671 | Val: Loss=0.3595, F1 Score=0.9020
# Early stopping triggered after 100 epochs.
# Best model restored from epoch 50 with val_f1 0.9337
# Best score: 0.9111±0.0188
# CPU times: user 26min 13s, sys: 3min 33s, total: 29min 46s
# Wall time: 28min 38s

# %%
# @title Plot History
# Create figure with two subplots sharing x axis
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 5), sharex=True)

# Color palette for K splits
colors = plt.cm.get_cmap('tab10', K)

# Plot validation loss for each split
for split in range(K):
    axes[0].plot(losses[f'split_{split}'][:-PATIENCE], label=f'Split {split+1}',
                 color=colors(split), alpha=0.6)
axes[0].set_title('Validation Loss per Split')
axes[0].set_ylabel('Loss')
axes[0].set_xlabel('Epoch')
axes[0].grid(alpha=0.3)

# Plot validation F1 score for each split
for split in range(K):
    axes[1].plot(metrics[f'split_{split}'][:-PATIENCE], label=f'Split {split+1}',
                 color=colors(split), alpha=0.6)
axes[1].set_title('Validation F1 Score per Split')
axes[1].set_ylabel('F1 Score')
axes[1].set_xlabel('Epoch')
axes[1].grid(alpha=0.3)

# Add shared legend on the right
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='small')

# Adjust layout
plt.tight_layout()
plt.subplots_adjust(right=0.975)
plt.show()
