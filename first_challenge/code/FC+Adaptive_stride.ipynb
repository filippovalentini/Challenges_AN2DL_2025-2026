# %% [markdown]
# # Notebook description
#
# In this notebook, we performed **cross validation** on a *GRU* (Gated Recurrent Unit) based recurrent network.
#
# The network is composed of two recurrent layers each one including 64 recurrent units.
# The output of the Recurrent Newtork is linked to a fully connected layer composed of 64 neurons, which is then linked to the linear classifier layer.
#
# The sequence building algorithm assigns to each sequence a different stride, based on the class it belongs to. This technique is used to balance the classes distribution in the training sequences.

# %% [markdown]
# # Google Drive connection

# %%
from google.colab import drive
drive.mount("/gdrive")
current_dir = "/gdrive/My\\ Drive/challengeAN2DL"
# %cd $current_dir
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1FBs0a25Urpk8cZPLeXuOnI8nzY3Yx1TA/challengeAN2DL

# %% [markdown]
# # Import libraries

# %%
# Set seed for reproducibility
SEED = 170412

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# # Data loading

# %%
# DATASET NAMES
DATASET_NAME_TRAINING = "an2dl2526c1/pirate_pain_train.csv"
DATASET_NAME_LABELS = "an2dl2526c1/pirate_pain_train_labels.csv"
DATASET_NAME_TEST = "an2dl2526c1/pirate_pain_test.csv"

df = pd.read_csv(DATASET_NAME_TRAINING)
labels = pd.read_csv(DATASET_NAME_LABELS)
df_test = pd.read_csv(DATASET_NAME_TEST)

# %% [markdown]
# # Data preprocessing

# %%
# Drop constant features
df = df.drop('joint_30', axis=1)
df_test = df_test.drop('joint_30', axis=1)

# Drop redundant features
df = df.drop('n_eyes', axis=1)
df_test = df_test.drop('n_eyes', axis=1)
df = df.drop('n_hands', axis=1)
df_test = df_test.drop('n_hands', axis=1)
df = df.drop('n_legs', axis=1)
df_test = df_test.drop('n_legs', axis=1)

# Drop outliers
drop_indeces = [16, 21, 137, 152, 225, 357, 381, 418, 439, 444, 511, 513, 521, 566, 628, 657,
                44, 338, 465,
                92, 300]

df = df[~df["sample_index"].isin(drop_indeces)]
labels = labels[~labels["sample_index"].isin(drop_indeces)]

# %%
# Transformation to float32
# pain_survey
for index in range(4):
    i = index + 1
    column = 'pain_survey_' + str(i)
    df[column] = df[column].astype(np.float32)
    df_test[column] = df_test[column].astype(np.float32)

# joints
for index in range(30):
    column = 'joint_' + str(index).zfill(2)
    df[column] = df[column].astype(np.float32)
    df_test[column] = df_test[column].astype(np.float32)

# %%
# Add labels to training set
df = df.merge(labels, on='sample_index', how='left')
df = df.rename(columns={'label': 'pain_level'})
scale_columns = df.columns[2:-1].tolist()

# %% [markdown]
# # Sequence building

# %%
WINDOW_SIZE = 64
STRIDE = 16

# %%
# Class adaptive stride

STRIDE_0 = STRIDE   # Class 0 stride
STRIDE_1 = 8        # Class 1 stride
STRIDE_2 = 4        # Class 2 stride

# %%
# Define a function to build sequences from the dataset
def build_sequences(df, validation, window=40, stride=40):
    # Sanity check to ensure the window is divisible by the stride
    assert window % stride == 0

    # Initialise lists to store sequences and their corresponding labels
    dataset = []
    labels = []

    # Iterate over unique IDs in the DataFrame
    for id in df['sample_index'].unique():
        # Extract sensor data for the current ID
        temp = df[df['sample_index'] == id][scale_columns].values

        # Retrieve the activity label for the current ID
        label = df[df['sample_index'] == id]['pain_level'].values[0]

        # Calculate padding length to ensure full windows
        padding_len = window - len(temp) % window

        # Create zero padding and concatenate with the data
        padding = np.zeros((padding_len, len(scale_columns)), dtype='float32')
        temp = np.concatenate((temp, padding))

        # Build feature windows and associate them with labels
        idx = 0
        if validation :
          stride=STRIDE
        elif label == 0:
            stride = STRIDE_0
        elif label == 1 :
            stride = STRIDE_1
        elif label == 2 :
            stride = STRIDE_2


        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            labels.append(label)
            idx += stride

    # Convert lists to numpy arrays for further processing
    dataset = np.array(dataset)
    labels = np.array(labels)

    return dataset, labels

# %%
# Define the batch size, which is the number of samples in each batch
BATCH_SIZE = 128

# %%
def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %% [markdown]
# # Model building

# %%
def recurrent_summary(model, input_size):
    """
    Custom summary function that emulates torchinfo's output while correctly
    counting parameters for RNN/GRU/LSTM layers.

    This function is designed for models whose direct children are
    nn.Linear, nn.RNN, nn.GRU, or nn.LSTM layers.

    Args:
        model (nn.Module): The model to analyze.
        input_size (tuple): Shape of the input tensor (e.g., (seq_len, features)).
    """

    # Dictionary to store output shapes captured by forward hooks
    output_shapes = {}
    # List to track hook handles for later removal
    hooks = []

    def get_hook(name):
        """Factory function to create a forward hook for a specific module."""
        def hook(module, input, output):
            # Handle RNN layer outputs (returns a tuple)
            if isinstance(output, tuple):
                # output[0]: all hidden states with shape (batch, seq_len, hidden*directions)
                shape1 = list(output[0].shape)
                shape1[0] = -1  # Replace batch dimension with -1

                # output[1]: final hidden state h_n (or tuple (h_n, c_n) for LSTM)
                if isinstance(output[1], tuple):  # LSTM case: (h_n, c_n)
                    shape2 = list(output[1][0].shape)  # Extract h_n only
                else:  # RNN/GRU case: h_n only
                    shape2 = list(output[1].shape)

                # Replace batch dimension (middle position) with -1
                shape2[1] = -1

                output_shapes[name] = f"[{shape1}, {shape2}]"

            # Handle standard layer outputs (e.g., Linear)
            else:
                shape = list(output.shape)
                shape[0] = -1  # Replace batch dimension with -1
                output_shapes[name] = f"{shape}"
        return hook

    # 1. Determine the device where model parameters reside
    try:
        device = next(model.parameters()).device
    except StopIteration:
        device = torch.device("cpu")  # Fallback for models without parameters

    # 2. Create a dummy input tensor with batch_size=1
    dummy_input = torch.randn(1, *input_size).to(device)

    # 3. Register forward hooks on target layers
    # Iterate through direct children of the model (e.g., self.rnn, self.classifier)
    for name, module in model.named_children():
        if isinstance(module, (nn.Linear, nn.RNN, nn.GRU, nn.LSTM)):
            # Register the hook and store its handle for cleanup
            hook_handle = module.register_forward_hook(get_hook(name))
            hooks.append(hook_handle)

    # 4. Execute a dummy forward pass in evaluation mode
    model.eval()
    with torch.no_grad():
        try:
            model(dummy_input)
        except Exception as e:
            print(f"Error during dummy forward pass: {e}")
            # Clean up hooks even if an error occurs
            for h in hooks:
                h.remove()
            return

    # 5. Remove all registered hooks
    for h in hooks:
        h.remove()

    # --- 6. Print the summary table ---

    print("-" * 79)
    # Column headers
    print(f"{'Layer (type)':<25} {'Output Shape':<28} {'Param #':<18}")
    print("=" * 79)

    total_params = 0
    total_trainable_params = 0

    # Iterate through modules again to collect and display parameter information
    for name, module in model.named_children():
        if name in output_shapes:
            # Count total and trainable parameters for this module
            module_params = sum(p.numel() for p in module.parameters())
            trainable_params = sum(p.numel() for p in module.parameters() if p.requires_grad)

            total_params += module_params
            total_trainable_params += trainable_params

            # Format strings for display
            layer_name = f"{name} ({type(module).__name__})"
            output_shape_str = str(output_shapes[name])
            params_str = f"{trainable_params:,}"

            print(f"{layer_name:<25} {output_shape_str:<28} {params_str:<15}")

    print("=" * 79)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {total_trainable_params:,}")
    print(f"Non-trainable params: {total_params - total_trainable_params:,}")
    print("-" * 79)

# %%
class RecurrentClassifier(nn.Module):
    """
    Generic RNN classifier (RNN, LSTM, GRU).
    Uses the last hidden state for classification.
    Optionally adds a dense layer after the recurrent block.
    """
    def __init__(
            self,
            input_size,
            hidden_size,
            num_layers,
            num_classes,
            rnn_type='GRU',        # 'RNN', 'LSTM', or 'GRU'
            bidirectional=False,
            dropout_rate=0.2,      # dropout between RNN layers
            fc_hidden_size=None,   # None = no extra dense layer; else int
            fc_dropout=0.0         # dropout after dense layer
        ):
        super().__init__()

        self.rnn_type = rnn_type
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.bidirectional = bidirectional

        # Map string name to PyTorch RNN class
        rnn_map = {
            'RNN': nn.RNN,
            'LSTM': nn.LSTM,
            'GRU': nn.GRU
        }

        if rnn_type not in rnn_map:
            raise ValueError("rnn_type must be 'RNN', 'LSTM', or 'GRU'")

        rnn_module = rnn_map[rnn_type]

        # Dropout is only applied between layers (if num_layers > 1)
        rnn_dropout = dropout_rate if num_layers > 1 else 0.0

        # Recurrent layer
        self.rnn = rnn_module(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=bidirectional,
            dropout=rnn_dropout
        )

        # Size of RNN output used for classification
        rnn_out_dim = hidden_size * (2 if bidirectional else 1)

        # Optional dense layer block
        self.has_fc = fc_hidden_size is not None
        if self.has_fc:
            self.fc = nn.Sequential(
                nn.Linear(rnn_out_dim, fc_hidden_size),
                nn.ReLU(),
                nn.Dropout(fc_dropout)
            )
            classifier_input_dim = fc_hidden_size
        else:
            self.fc = nn.Identity()
            classifier_input_dim = rnn_out_dim

        # Final classifier
        self.classifier = nn.Linear(classifier_input_dim, num_classes)

    def forward(self, x):
        """
        x shape: (batch_size, seq_length, input_size)
        """
        rnn_out, hidden = self.rnn(x)

        # LSTM: hidden = (h_n, c_n) → use h_n
        if self.rnn_type == 'LSTM':
            hidden = hidden[0]

        # hidden shape: (num_layers * num_directions, batch_size, hidden_size)

        if self.bidirectional:
            # (num_layers, 2, batch, hidden)
            hidden = hidden.view(self.num_layers, 2, -1, self.hidden_size)
            # concat last layer forward & backward
            hidden_to_classify = torch.cat(
                [hidden[-1, 0, :, :], hidden[-1, 1, :, :]],
                dim=1
            )  # (batch, hidden*2)
        else:
            hidden_to_classify = hidden[-1]  # (batch, hidden)

        # Optional dense layer(s)
        feats = self.fc(hidden_to_classify)

        # Final logits
        logits = self.classifier(feats)
        return logits

# %% [markdown]
# # Network and training hyperparameters

# %%
# Training configuration
LEARNING_RATE = 7e-4
EPOCHS = 300
PATIENCE = 50

# Architecture
HIDDEN_LAYERS = 2       # Hidden layers
HIDDEN_SIZE =  64       # Neurons per layer

# Dense layer
DENSE_HIDDEN_SIZE = 64
DENSE_DROPOUT = 0.3

# Regularisation
DROPOUT_RATE = 0.4       # Dropout probability
L1_LAMBDA = 0            # L1 penalty
L2_LAMBDA = 0.001        # L2 penalty

# Set up loss function and optimizer
criterion = nn.CrossEntropyLoss()

# CROSS VALIDATION FOLDS
K = 5

# %% [markdown]
# # Model Training

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()

        # Gradient clipping
        scaler.unscale_(optimizer)

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=3.0)

        scaler.step(optimizer)

        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """
    Log training metrics and model parameters to TensorBoard for visualization.

    Args:
        writer (SummaryWriter): TensorBoard SummaryWriter object for logging
        epoch (int): Current epoch number (used as x-axis in TensorBoard plots)
        train_loss (float): Training loss for this epoch
        train_f1 (float): Training f1 score for this epoch
        val_loss (float): Validation loss for this epoch
        val_f1 (float): Validation f1 score for this epoch
        model (nn.Module): The neural network model (for logging weights/gradients)

    Note:
        This function logs scalar metrics (loss/f1 score) and histograms of model
        parameters and gradients, which helps monitor training progress and detect
        issues like vanishing/exploding gradients.
    """
    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name="",scheduler=None):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Step the scheduler if provided (typically after validation)
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(val_loss)
            else:
                scheduler.step()

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# # Cross Validation

# %%
def k_shuffle_split_cross_validation_round_rnn(df, train_split_ratio, epochs, criterion, device,
                            k, batch_size, hidden_layers, hidden_size, learning_rate, dropout_rate,
                            bidirectional, rnn_type, fc_hidden_size, fc_dropout, l1_lambda=0, l2_lambda=0, patience=0, window_size=WINDOW_SIZE, stride=STRIDE,
                            evaluation_metric="val_f1", mode='max', restore_best_weights=True, writer=None,
                            verbose=10, seed=SEED, experiment_name=""):


    # The (merged) dataframe must contain features (2 to end - 1) and pain_level (last column)
    # Initialise containers for results across all splits

    fold_losses = {}
    fold_metrics = {}
    best_scores = {}

    # Retrieve number of input features and number of classes

    # scale_columns = ['pain_survey_1', 'pain_survey_2', 'pain_survey_3', 'pain_survey_4',
    #                  'n_legs', 'n_hands', 'n_eyes', joint00, ..., joint29]

    scale_columns = df.columns[2:-1].tolist()
    in_features = len(scale_columns)
    num_classes = len(df['pain_level'].unique())

    rnn_model = RecurrentClassifier(
        input_size=in_features,
        hidden_size=hidden_size,
        num_layers=hidden_layers,
        num_classes=num_classes,
        dropout_rate=dropout_rate,
        bidirectional=bidirectional,
        rnn_type=rnn_type,
        fc_hidden_size=DENSE_HIDDEN_SIZE,
        fc_dropout=DENSE_DROPOUT
        ).to(device)

    # Store initial weights to reset model for each split
    initial_state = copy.deepcopy(rnn_model.state_dict())

    # Iterate through K random splits
    for split_idx in range(k):

        if verbose > 0:
            print(f"Split {split_idx+1}/{k}")

        # Create random split
        unique_pirates = df['sample_index'].unique()
        random.seed(seed + split_idx) # Different shuffle for every index
        random.shuffle(unique_pirates)

        # Number of sequences for training
        N_TRAIN_PIRATES = int(len(unique_pirates) * train_split_ratio)

        # Number of seuences for validation
        N_VAL_PIRATES = len(unique_pirates) - N_TRAIN_PIRATES

        # Training sequence indeces
        train_pirates = unique_pirates[:N_TRAIN_PIRATES]

        # Validation sequence indeces
        val_pirates = unique_pirates[N_TRAIN_PIRATES:]

        # Training dataframe
        df_train = df[df['sample_index'].isin(train_pirates)]

        # Validation dataframe
        df_val = df[df['sample_index'].isin(val_pirates)]

        # Label mapping from categorical to numerical
        label_mapping = {
            'no_pain': 0,
            'low_pain': 1,
            'high_pain': 2
        }

        df_train['pain_level'] = df_train['pain_level'].map(label_mapping)

        df_val['pain_level'] = df_val['pain_level'].map(label_mapping)

        # Calculate the minimum and maximum values from the training data only
        mins = df_train[scale_columns].min()
        maxs = df_train[scale_columns].max()

        # Apply normalisation to the specified columns in all datasets
        for column in scale_columns:
            # Normalise the training set
            df_train[column] = (df_train[column] - mins[column]) / (maxs[column] - mins[column])

            # Normalise the validation set
            df_val[column] = (df_val[column] - mins[column]) / (maxs[column] - mins[column])


        # Build sequences
        X_train, y_train = build_sequences(df_train, False, window_size, stride)
        X_val, y_val = build_sequences(df_val, True, window_size, stride)

        # Create PyTorch datasets
        train_ds = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
        val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val))

        # Create data loaders
        train_loader = make_loader(train_ds, batch_size=batch_size, shuffle=True, drop_last=False)
        val_loader   = make_loader(val_ds, batch_size=batch_size, shuffle=False, drop_last=False)

        # Reset model to initial weights for fair comparison across splits
        rnn_model.load_state_dict(initial_state)

        optimizer = torch.optim.AdamW(rnn_model.parameters(), lr=learning_rate, weight_decay=l2_lambda)

        # Enable mixed precision training for GPU acceleration
        scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

        # Create directory for model checkpoints
        os.makedirs(f"models/{experiment_name}", exist_ok=True)

        # Train model on current split
        rnn_model, training_history = fit(
            model=rnn_model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=epochs,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            device=device,
            writer=writer,
            patience=patience,
            verbose=verbose,
            experiment_name=experiment_name+"/split_"+str(split_idx),
            l1_lambda=l1_lambda,
            evaluation_metric=evaluation_metric,
            mode=mode,
            restore_best_weights=restore_best_weights
            )

        # Store results for this split
        fold_losses[f"split_{split_idx}"] = training_history['val_loss']
        fold_metrics[f"split_{split_idx}"] = training_history['val_f1']
        best_scores[f"split_{split_idx}"] = max(training_history['val_f1'])

    # Compute mean and standard deviation of best scores across splits
    best_scores["mean"] = np.mean([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])
    best_scores["std"] = np.std([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])

    if verbose > 0:
        print(f"Best score: {best_scores['mean']:.4f}±{best_scores['std']:.4f}")

    return fold_losses, fold_metrics, best_scores

# %%
# CALL TO CROSS-VALIDATION
# %%time
# Execute K-fold cross-validation with baseline configuration
losses, metrics, best_scores = k_shuffle_split_cross_validation_round_rnn(
    df=df,
    train_split_ratio=0.9,
    epochs=EPOCHS,
    criterion=criterion,
    device=device,
    k=K,
    batch_size=BATCH_SIZE,
    hidden_layers=HIDDEN_LAYERS,
    hidden_size=HIDDEN_SIZE,
    learning_rate=LEARNING_RATE,
    dropout_rate=DROPOUT_RATE,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    verbose=1,
    patience=PATIENCE,
    seed=SEED,
    experiment_name="cvRecurrentDenseLayerDynamicStride",
    window_size=WINDOW_SIZE,
    stride=STRIDE,
    rnn_type="GRU",
    bidirectional=True,
    fc_hidden_size=DENSE_HIDDEN_SIZE,
    fc_dropout=DENSE_DROPOUT
)
# Out:
# Split 1/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9935, F1 Score=0.4098 | Val: Loss=0.6845, F1 Score=0.7722
# Epoch   2/300 | Train: Loss=0.8932, F1 Score=0.5257 | Val: Loss=0.5273, F1 Score=0.8075
# Epoch   3/300 | Train: Loss=0.8037, F1 Score=0.6056 | Val: Loss=0.5071, F1 Score=0.8356
# Epoch   4/300 | Train: Loss=0.7504, F1 Score=0.6732 | Val: Loss=0.4554, F1 Score=0.8493
# Epoch   5/300 | Train: Loss=0.6908, F1 Score=0.7054 | Val: Loss=0.4570, F1 Score=0.8648
# Epoch   6/300 | Train: Loss=0.5876, F1 Score=0.7517 | Val: Loss=0.3163, F1 Score=0.8994
# Epoch   7/300 | Train: Loss=0.4950, F1 Score=0.8037 | Val: Loss=0.3513, F1 Score=0.8825
# Epoch   8/300 | Train: Loss=0.4085, F1 Score=0.8437 | Val: Loss=0.4526, F1 Score=0.8402
# Epoch   9/300 | Train: Loss=0.4272, F1 Score=0.8273 | Val: Loss=0.2964, F1 Score=0.9100
# Epoch  10/300 | Train: Loss=0.3495, F1 Score=0.8677 | Val: Loss=0.3062, F1 Score=0.9120
# Epoch  11/300 | Train: Loss=0.3039, F1 Score=0.8899 | Val: Loss=0.3323, F1 Score=0.8795
# Epoch  12/300 | Train: Loss=0.2895, F1 Score=0.8892 | Val: Loss=0.2363, F1 Score=0.9097
# Epoch  13/300 | Train: Loss=0.2561, F1 Score=0.9066 | Val: Loss=0.2371, F1 Score=0.9205
# Epoch  14/300 | Train: Loss=0.2411, F1 Score=0.9106 | Val: Loss=0.2381, F1 Score=0.9283
# Epoch  15/300 | Train: Loss=0.2282, F1 Score=0.9128 | Val: Loss=0.2769, F1 Score=0.9026
# Epoch  16/300 | Train: Loss=0.2125, F1 Score=0.9169 | Val: Loss=0.2620, F1 Score=0.9175
# Epoch  17/300 | Train: Loss=0.1976, F1 Score=0.9262 | Val: Loss=0.2252, F1 Score=0.9354
# Epoch  18/300 | Train: Loss=0.1640, F1 Score=0.9379 | Val: Loss=0.2712, F1 Score=0.9177
# Epoch  19/300 | Train: Loss=0.1671, F1 Score=0.9364 | Val: Loss=0.3286, F1 Score=0.8992
# Epoch  20/300 | Train: Loss=0.1478, F1 Score=0.9465 | Val: Loss=0.4291, F1 Score=0.9006
# Epoch  21/300 | Train: Loss=0.1450, F1 Score=0.9492 | Val: Loss=0.3480, F1 Score=0.9239
# Epoch  22/300 | Train: Loss=0.1623, F1 Score=0.9391 | Val: Loss=0.2901, F1 Score=0.9260
# Epoch  23/300 | Train: Loss=0.1291, F1 Score=0.9523 | Val: Loss=0.3861, F1 Score=0.8964
# Epoch  24/300 | Train: Loss=0.1169, F1 Score=0.9557 | Val: Loss=0.3235, F1 Score=0.9260
# Epoch  25/300 | Train: Loss=0.1157, F1 Score=0.9567 | Val: Loss=0.5060, F1 Score=0.9073
# Epoch  26/300 | Train: Loss=0.1248, F1 Score=0.9603 | Val: Loss=0.3012, F1 Score=0.9215
# Epoch  27/300 | Train: Loss=0.1165, F1 Score=0.9613 | Val: Loss=0.5398, F1 Score=0.9043
# Epoch  28/300 | Train: Loss=0.0995, F1 Score=0.9640 | Val: Loss=0.5396, F1 Score=0.9041
# Epoch  29/300 | Train: Loss=0.0885, F1 Score=0.9694 | Val: Loss=0.3711, F1 Score=0.9224
# Epoch  30/300 | Train: Loss=0.0983, F1 Score=0.9651 | Val: Loss=0.4070, F1 Score=0.9192
# Epoch  31/300 | Train: Loss=0.1033, F1 Score=0.9621 | Val: Loss=0.4447, F1 Score=0.9182
# Epoch  32/300 | Train: Loss=0.0747, F1 Score=0.9753 | Val: Loss=0.3981, F1 Score=0.9155
# Epoch  33/300 | Train: Loss=0.1076, F1 Score=0.9633 | Val: Loss=0.4030, F1 Score=0.9306
# Epoch  34/300 | Train: Loss=0.0945, F1 Score=0.9720 | Val: Loss=0.4945, F1 Score=0.9138
# Epoch  35/300 | Train: Loss=0.0721, F1 Score=0.9728 | Val: Loss=0.4561, F1 Score=0.9171
# Epoch  36/300 | Train: Loss=0.0635, F1 Score=0.9772 | Val: Loss=0.4488, F1 Score=0.9211
# Epoch  37/300 | Train: Loss=0.0866, F1 Score=0.9687 | Val: Loss=0.4244, F1 Score=0.9235
# Epoch  38/300 | Train: Loss=0.0819, F1 Score=0.9732 | Val: Loss=0.4653, F1 Score=0.9303
# Epoch  39/300 | Train: Loss=0.0983, F1 Score=0.9677 | Val: Loss=0.4788, F1 Score=0.9252
# Epoch  40/300 | Train: Loss=0.0917, F1 Score=0.9723 | Val: Loss=0.4939, F1 Score=0.9183
# Epoch  41/300 | Train: Loss=0.0747, F1 Score=0.9746 | Val: Loss=0.4034, F1 Score=0.9353
# Epoch  42/300 | Train: Loss=0.0653, F1 Score=0.9773 | Val: Loss=0.5086, F1 Score=0.9209
# Epoch  43/300 | Train: Loss=0.0751, F1 Score=0.9750 | Val: Loss=0.5092, F1 Score=0.9026
# Epoch  44/300 | Train: Loss=0.0744, F1 Score=0.9724 | Val: Loss=0.4468, F1 Score=0.9383
# Epoch  45/300 | Train: Loss=0.0402, F1 Score=0.9847 | Val: Loss=0.5690, F1 Score=0.9242
# Epoch  46/300 | Train: Loss=0.0602, F1 Score=0.9789 | Val: Loss=0.6185, F1 Score=0.9096
# Epoch  47/300 | Train: Loss=0.0550, F1 Score=0.9833 | Val: Loss=0.5345, F1 Score=0.9179
# Epoch  48/300 | Train: Loss=0.0604, F1 Score=0.9793 | Val: Loss=0.4398, F1 Score=0.9339
# Epoch  49/300 | Train: Loss=0.0424, F1 Score=0.9857 | Val: Loss=0.5591, F1 Score=0.9299
# Epoch  50/300 | Train: Loss=0.0644, F1 Score=0.9782 | Val: Loss=0.6005, F1 Score=0.9215
# Epoch  51/300 | Train: Loss=0.0907, F1 Score=0.9706 | Val: Loss=0.4692, F1 Score=0.9396
# Epoch  52/300 | Train: Loss=0.0404, F1 Score=0.9861 | Val: Loss=0.5545, F1 Score=0.9281
# Epoch  53/300 | Train: Loss=0.0486, F1 Score=0.9825 | Val: Loss=0.5646, F1 Score=0.9198
# Epoch  54/300 | Train: Loss=0.0541, F1 Score=0.9823 | Val: Loss=0.5329, F1 Score=0.9292
# Epoch  55/300 | Train: Loss=0.0508, F1 Score=0.9827 | Val: Loss=0.5595, F1 Score=0.9195
# Epoch  56/300 | Train: Loss=0.0426, F1 Score=0.9862 | Val: Loss=0.6415, F1 Score=0.9077
# Epoch  57/300 | Train: Loss=0.0409, F1 Score=0.9868 | Val: Loss=0.5623, F1 Score=0.9288
# Epoch  58/300 | Train: Loss=0.0300, F1 Score=0.9906 | Val: Loss=0.5535, F1 Score=0.9248
# Epoch  59/300 | Train: Loss=0.0441, F1 Score=0.9857 | Val: Loss=0.5819, F1 Score=0.9368
# Epoch  60/300 | Train: Loss=0.0669, F1 Score=0.9795 | Val: Loss=0.6706, F1 Score=0.9145
# Epoch  61/300 | Train: Loss=0.0539, F1 Score=0.9824 | Val: Loss=0.5898, F1 Score=0.9198
# Epoch  62/300 | Train: Loss=0.0308, F1 Score=0.9896 | Val: Loss=0.6468, F1 Score=0.9211
# Epoch  63/300 | Train: Loss=0.0286, F1 Score=0.9918 | Val: Loss=0.5117, F1 Score=0.9252
# Epoch  64/300 | Train: Loss=0.0510, F1 Score=0.9811 | Val: Loss=0.5778, F1 Score=0.9156
# Epoch  65/300 | Train: Loss=0.0287, F1 Score=0.9887 | Val: Loss=0.5385, F1 Score=0.9319
# Epoch  66/300 | Train: Loss=0.0242, F1 Score=0.9929 | Val: Loss=0.6471, F1 Score=0.9243
# Epoch  67/300 | Train: Loss=0.0385, F1 Score=0.9879 | Val: Loss=0.6256, F1 Score=0.9270
# Epoch  68/300 | Train: Loss=0.0268, F1 Score=0.9913 | Val: Loss=0.5678, F1 Score=0.9319
# Epoch  69/300 | Train: Loss=0.0189, F1 Score=0.9933 | Val: Loss=0.6487, F1 Score=0.9238
# Epoch  70/300 | Train: Loss=0.0292, F1 Score=0.9912 | Val: Loss=0.5556, F1 Score=0.9356
# Epoch  71/300 | Train: Loss=0.0334, F1 Score=0.9892 | Val: Loss=0.6008, F1 Score=0.9194
# Epoch  72/300 | Train: Loss=0.0371, F1 Score=0.9887 | Val: Loss=0.5952, F1 Score=0.9297
# Epoch  73/300 | Train: Loss=0.0435, F1 Score=0.9854 | Val: Loss=0.6519, F1 Score=0.9166
# Epoch  74/300 | Train: Loss=0.0307, F1 Score=0.9918 | Val: Loss=0.5993, F1 Score=0.9311
# Epoch  75/300 | Train: Loss=0.0494, F1 Score=0.9850 | Val: Loss=0.6971, F1 Score=0.9152
# Epoch  76/300 | Train: Loss=0.0532, F1 Score=0.9838 | Val: Loss=0.7112, F1 Score=0.9145
# Epoch  77/300 | Train: Loss=0.0405, F1 Score=0.9862 | Val: Loss=0.6641, F1 Score=0.9184
# Epoch  78/300 | Train: Loss=0.0285, F1 Score=0.9897 | Val: Loss=0.6447, F1 Score=0.9253
# Epoch  79/300 | Train: Loss=0.0345, F1 Score=0.9885 | Val: Loss=0.7070, F1 Score=0.9197
# Epoch  80/300 | Train: Loss=0.0416, F1 Score=0.9862 | Val: Loss=0.6594, F1 Score=0.9269
# Epoch  81/300 | Train: Loss=0.0132, F1 Score=0.9956 | Val: Loss=0.6568, F1 Score=0.9361
# Epoch  82/300 | Train: Loss=0.0086, F1 Score=0.9973 | Val: Loss=0.6724, F1 Score=0.9270
# Epoch  83/300 | Train: Loss=0.0210, F1 Score=0.9938 | Val: Loss=0.7481, F1 Score=0.9238
# Epoch  84/300 | Train: Loss=0.0273, F1 Score=0.9923 | Val: Loss=0.8389, F1 Score=0.9156
# Epoch  85/300 | Train: Loss=0.0212, F1 Score=0.9935 | Val: Loss=0.7135, F1 Score=0.9217
# Epoch  86/300 | Train: Loss=0.0224, F1 Score=0.9933 | Val: Loss=0.7459, F1 Score=0.9191
# Epoch  87/300 | Train: Loss=0.0211, F1 Score=0.9939 | Val: Loss=0.6849, F1 Score=0.9222
# Epoch  88/300 | Train: Loss=0.0203, F1 Score=0.9928 | Val: Loss=0.7364, F1 Score=0.9291
# Epoch  89/300 | Train: Loss=0.0454, F1 Score=0.9852 | Val: Loss=0.6671, F1 Score=0.9242
# Epoch  90/300 | Train: Loss=0.0265, F1 Score=0.9906 | Val: Loss=0.6641, F1 Score=0.9376
# Epoch  91/300 | Train: Loss=0.0289, F1 Score=0.9901 | Val: Loss=0.6769, F1 Score=0.9283
# Epoch  92/300 | Train: Loss=0.0286, F1 Score=0.9895 | Val: Loss=0.7110, F1 Score=0.9242
# Epoch  93/300 | Train: Loss=0.0421, F1 Score=0.9881 | Val: Loss=0.6648, F1 Score=0.9405
# Epoch  94/300 | Train: Loss=0.0314, F1 Score=0.9906 | Val: Loss=0.6111, F1 Score=0.9405
# Epoch  95/300 | Train: Loss=0.0217, F1 Score=0.9929 | Val: Loss=0.6665, F1 Score=0.9235
# Epoch  96/300 | Train: Loss=0.0429, F1 Score=0.9871 | Val: Loss=0.6500, F1 Score=0.9291
# Epoch  97/300 | Train: Loss=0.0123, F1 Score=0.9965 | Val: Loss=0.7476, F1 Score=0.9314
# Epoch  98/300 | Train: Loss=0.0191, F1 Score=0.9938 | Val: Loss=0.6965, F1 Score=0.9305
# Epoch  99/300 | Train: Loss=0.0168, F1 Score=0.9936 | Val: Loss=0.7303, F1 Score=0.9325
# Epoch 100/300 | Train: Loss=0.0211, F1 Score=0.9948 | Val: Loss=0.7401, F1 Score=0.9341
# Epoch 101/300 | Train: Loss=0.0169, F1 Score=0.9949 | Val: Loss=0.6843, F1 Score=0.9339
# Epoch 102/300 | Train: Loss=0.0250, F1 Score=0.9915 | Val: Loss=0.8122, F1 Score=0.8950
# Epoch 103/300 | Train: Loss=0.0225, F1 Score=0.9930 | Val: Loss=0.7789, F1 Score=0.9215
# Epoch 104/300 | Train: Loss=0.0228, F1 Score=0.9945 | Val: Loss=0.8226, F1 Score=0.9171
# Epoch 105/300 | Train: Loss=0.0296, F1 Score=0.9902 | Val: Loss=0.6771, F1 Score=0.9257
# Epoch 106/300 | Train: Loss=0.0319, F1 Score=0.9891 | Val: Loss=0.6711, F1 Score=0.9288
# Epoch 107/300 | Train: Loss=0.0127, F1 Score=0.9952 | Val: Loss=0.6701, F1 Score=0.9405
# Epoch 108/300 | Train: Loss=0.0166, F1 Score=0.9953 | Val: Loss=0.7520, F1 Score=0.9256
# Epoch 109/300 | Train: Loss=0.0166, F1 Score=0.9948 | Val: Loss=0.6773, F1 Score=0.9295
# Epoch 110/300 | Train: Loss=0.0231, F1 Score=0.9919 | Val: Loss=0.6922, F1 Score=0.9235
# Epoch 111/300 | Train: Loss=0.0458, F1 Score=0.9878 | Val: Loss=0.7757, F1 Score=0.9191
# Epoch 112/300 | Train: Loss=0.0092, F1 Score=0.9976 | Val: Loss=0.6415, F1 Score=0.9390
# Epoch 113/300 | Train: Loss=0.0251, F1 Score=0.9922 | Val: Loss=0.6865, F1 Score=0.9425
# Epoch 114/300 | Train: Loss=0.0207, F1 Score=0.9925 | Val: Loss=0.7458, F1 Score=0.9256
# Epoch 115/300 | Train: Loss=0.0114, F1 Score=0.9963 | Val: Loss=0.7220, F1 Score=0.9319
# Epoch 116/300 | Train: Loss=0.0035, F1 Score=0.9987 | Val: Loss=0.7728, F1 Score=0.9294
# Epoch 117/300 | Train: Loss=0.0143, F1 Score=0.9953 | Val: Loss=0.8548, F1 Score=0.9197
# Epoch 118/300 | Train: Loss=0.0277, F1 Score=0.9911 | Val: Loss=0.7268, F1 Score=0.9312
# Epoch 119/300 | Train: Loss=0.0106, F1 Score=0.9969 | Val: Loss=0.7581, F1 Score=0.9209
# Epoch 120/300 | Train: Loss=0.0180, F1 Score=0.9940 | Val: Loss=0.6879, F1 Score=0.9327
# Epoch 121/300 | Train: Loss=0.0177, F1 Score=0.9940 | Val: Loss=0.7550, F1 Score=0.9281
# Epoch 122/300 | Train: Loss=0.0111, F1 Score=0.9970 | Val: Loss=0.7377, F1 Score=0.9184
# Epoch 123/300 | Train: Loss=0.0016, F1 Score=0.9999 | Val: Loss=0.8438, F1 Score=0.9239
# Epoch 124/300 | Train: Loss=0.0080, F1 Score=0.9970 | Val: Loss=0.8572, F1 Score=0.9274
# Epoch 125/300 | Train: Loss=0.0516, F1 Score=0.9884 | Val: Loss=0.7138, F1 Score=0.9308
# Epoch 126/300 | Train: Loss=0.0169, F1 Score=0.9946 | Val: Loss=1.0110, F1 Score=0.9209
# Epoch 127/300 | Train: Loss=0.0162, F1 Score=0.9948 | Val: Loss=0.7375, F1 Score=0.9319
# Epoch 128/300 | Train: Loss=0.0075, F1 Score=0.9972 | Val: Loss=0.8703, F1 Score=0.9239
# Epoch 129/300 | Train: Loss=0.0134, F1 Score=0.9959 | Val: Loss=0.7971, F1 Score=0.9242
# Epoch 130/300 | Train: Loss=0.0074, F1 Score=0.9972 | Val: Loss=0.7621, F1 Score=0.9284
# Epoch 131/300 | Train: Loss=0.0050, F1 Score=0.9984 | Val: Loss=0.8928, F1 Score=0.9211
# Epoch 132/300 | Train: Loss=0.0097, F1 Score=0.9974 | Val: Loss=0.8497, F1 Score=0.9347
# Epoch 133/300 | Train: Loss=0.0195, F1 Score=0.9940 | Val: Loss=0.6989, F1 Score=0.9250
# Epoch 134/300 | Train: Loss=0.0167, F1 Score=0.9947 | Val: Loss=0.7722, F1 Score=0.9317
# Epoch 135/300 | Train: Loss=0.0077, F1 Score=0.9980 | Val: Loss=0.9247, F1 Score=0.9242
# Epoch 136/300 | Train: Loss=0.0165, F1 Score=0.9949 | Val: Loss=0.7422, F1 Score=0.9330
# Epoch 137/300 | Train: Loss=0.0211, F1 Score=0.9940 | Val: Loss=0.6917, F1 Score=0.9295
# Epoch 138/300 | Train: Loss=0.0114, F1 Score=0.9962 | Val: Loss=0.7336, F1 Score=0.9298
# Epoch 139/300 | Train: Loss=0.0276, F1 Score=0.9915 | Val: Loss=0.9252, F1 Score=0.9161
# Epoch 140/300 | Train: Loss=0.0247, F1 Score=0.9925 | Val: Loss=0.6878, F1 Score=0.9266
# Epoch 141/300 | Train: Loss=0.0245, F1 Score=0.9933 | Val: Loss=0.8328, F1 Score=0.9207
# Epoch 142/300 | Train: Loss=0.0330, F1 Score=0.9913 | Val: Loss=0.5283, F1 Score=0.9306
# Epoch 143/300 | Train: Loss=0.0152, F1 Score=0.9960 | Val: Loss=0.6079, F1 Score=0.9361
# Epoch 144/300 | Train: Loss=0.0054, F1 Score=0.9984 | Val: Loss=0.8601, F1 Score=0.9277
# Epoch 145/300 | Train: Loss=0.0212, F1 Score=0.9938 | Val: Loss=0.8199, F1 Score=0.9101
# Epoch 146/300 | Train: Loss=0.0109, F1 Score=0.9966 | Val: Loss=0.7861, F1 Score=0.9305
# Epoch 147/300 | Train: Loss=0.0076, F1 Score=0.9977 | Val: Loss=0.6471, F1 Score=0.9312
# Epoch 148/300 | Train: Loss=0.0066, F1 Score=0.9984 | Val: Loss=0.7093, F1 Score=0.9400
# Epoch 149/300 | Train: Loss=0.0098, F1 Score=0.9960 | Val: Loss=0.9101, F1 Score=0.9206
# Epoch 150/300 | Train: Loss=0.0116, F1 Score=0.9956 | Val: Loss=0.6687, F1 Score=0.9376
# Epoch 151/300 | Train: Loss=0.0075, F1 Score=0.9980 | Val: Loss=0.8579, F1 Score=0.9184
# Epoch 152/300 | Train: Loss=0.0154, F1 Score=0.9967 | Val: Loss=1.1756, F1 Score=0.9215
# Epoch 153/300 | Train: Loss=0.0142, F1 Score=0.9965 | Val: Loss=0.8323, F1 Score=0.9217
# Epoch 154/300 | Train: Loss=0.0156, F1 Score=0.9959 | Val: Loss=0.8976, F1 Score=0.9250
# Epoch 155/300 | Train: Loss=0.0218, F1 Score=0.9939 | Val: Loss=0.8249, F1 Score=0.9247
# Epoch 156/300 | Train: Loss=0.0071, F1 Score=0.9979 | Val: Loss=0.8520, F1 Score=0.9225
# Epoch 157/300 | Train: Loss=0.0107, F1 Score=0.9966 | Val: Loss=0.9375, F1 Score=0.9171
# Epoch 158/300 | Train: Loss=0.0016, F1 Score=0.9996 | Val: Loss=0.9437, F1 Score=0.9229
# Epoch 159/300 | Train: Loss=0.0004, F1 Score=1.0000 | Val: Loss=1.0093, F1 Score=0.9277
# Epoch 160/300 | Train: Loss=0.0090, F1 Score=0.9973 | Val: Loss=1.1394, F1 Score=0.9052
# Epoch 161/300 | Train: Loss=0.0192, F1 Score=0.9946 | Val: Loss=0.9020, F1 Score=0.9260
# Epoch 162/300 | Train: Loss=0.0293, F1 Score=0.9926 | Val: Loss=0.7666, F1 Score=0.9292
# Epoch 163/300 | Train: Loss=0.0343, F1 Score=0.9885 | Val: Loss=0.8413, F1 Score=0.9206
# Early stopping triggered after 163 epochs.
# Best model restored from epoch 113 with val_f1 0.9425
# Split 2/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9848, F1 Score=0.4227 | Val: Loss=0.7399, F1 Score=0.7068
# Epoch   2/300 | Train: Loss=0.8806, F1 Score=0.5443 | Val: Loss=0.6641, F1 Score=0.7549
# Epoch   3/300 | Train: Loss=0.7811, F1 Score=0.6197 | Val: Loss=0.5779, F1 Score=0.8255
# Epoch   4/300 | Train: Loss=0.7139, F1 Score=0.6645 | Val: Loss=0.6221, F1 Score=0.8152
# Epoch   5/300 | Train: Loss=0.6181, F1 Score=0.7402 | Val: Loss=0.4432, F1 Score=0.8615
# Epoch   6/300 | Train: Loss=0.5377, F1 Score=0.7969 | Val: Loss=0.4542, F1 Score=0.8702
# Epoch   7/300 | Train: Loss=0.4772, F1 Score=0.8176 | Val: Loss=0.4315, F1 Score=0.8744
# Epoch   8/300 | Train: Loss=0.4453, F1 Score=0.8307 | Val: Loss=0.5289, F1 Score=0.8479
# Epoch   9/300 | Train: Loss=0.4072, F1 Score=0.8392 | Val: Loss=0.3677, F1 Score=0.8932
# Epoch  10/300 | Train: Loss=0.3815, F1 Score=0.8449 | Val: Loss=0.3365, F1 Score=0.9086
# Epoch  11/300 | Train: Loss=0.3300, F1 Score=0.8739 | Val: Loss=0.3554, F1 Score=0.8993
# Epoch  12/300 | Train: Loss=0.3057, F1 Score=0.8840 | Val: Loss=0.6508, F1 Score=0.8287
# Epoch  13/300 | Train: Loss=0.3024, F1 Score=0.8821 | Val: Loss=0.4702, F1 Score=0.8810
# Epoch  14/300 | Train: Loss=0.2626, F1 Score=0.9003 | Val: Loss=0.3669, F1 Score=0.8976
# Epoch  15/300 | Train: Loss=0.2424, F1 Score=0.9097 | Val: Loss=0.3262, F1 Score=0.9217
# Epoch  16/300 | Train: Loss=0.2471, F1 Score=0.9068 | Val: Loss=0.3220, F1 Score=0.9056
# Epoch  17/300 | Train: Loss=0.2090, F1 Score=0.9242 | Val: Loss=0.4425, F1 Score=0.9006
# Epoch  18/300 | Train: Loss=0.2149, F1 Score=0.9211 | Val: Loss=0.3803, F1 Score=0.9100
# Epoch  19/300 | Train: Loss=0.2281, F1 Score=0.9217 | Val: Loss=0.3684, F1 Score=0.9070
# Epoch  20/300 | Train: Loss=0.1685, F1 Score=0.9399 | Val: Loss=0.2369, F1 Score=0.9380
# Epoch  21/300 | Train: Loss=0.1604, F1 Score=0.9405 | Val: Loss=0.3046, F1 Score=0.9302
# Epoch  22/300 | Train: Loss=0.1547, F1 Score=0.9438 | Val: Loss=0.3053, F1 Score=0.8998
# Epoch  23/300 | Train: Loss=0.1394, F1 Score=0.9494 | Val: Loss=0.3322, F1 Score=0.8972
# Epoch  24/300 | Train: Loss=0.1279, F1 Score=0.9527 | Val: Loss=0.1365, F1 Score=0.9578
# Epoch  25/300 | Train: Loss=0.1434, F1 Score=0.9472 | Val: Loss=0.2840, F1 Score=0.9308
# Epoch  26/300 | Train: Loss=0.1343, F1 Score=0.9494 | Val: Loss=0.2618, F1 Score=0.9387
# Epoch  27/300 | Train: Loss=0.1263, F1 Score=0.9498 | Val: Loss=0.2397, F1 Score=0.9397
# Epoch  28/300 | Train: Loss=0.1212, F1 Score=0.9564 | Val: Loss=0.2277, F1 Score=0.9379
# Epoch  29/300 | Train: Loss=0.1108, F1 Score=0.9571 | Val: Loss=0.1966, F1 Score=0.9425
# Epoch  30/300 | Train: Loss=0.0983, F1 Score=0.9620 | Val: Loss=0.1927, F1 Score=0.9503
# Epoch  31/300 | Train: Loss=0.1029, F1 Score=0.9586 | Val: Loss=0.1631, F1 Score=0.9596
# Epoch  32/300 | Train: Loss=0.0829, F1 Score=0.9670 | Val: Loss=0.2049, F1 Score=0.9539
# Epoch  33/300 | Train: Loss=0.0971, F1 Score=0.9638 | Val: Loss=0.2287, F1 Score=0.9496
# Epoch  34/300 | Train: Loss=0.1105, F1 Score=0.9595 | Val: Loss=0.2403, F1 Score=0.9416
# Epoch  35/300 | Train: Loss=0.0791, F1 Score=0.9668 | Val: Loss=0.2276, F1 Score=0.9528
# Epoch  36/300 | Train: Loss=0.0856, F1 Score=0.9653 | Val: Loss=0.1746, F1 Score=0.9547
# Epoch  37/300 | Train: Loss=0.0784, F1 Score=0.9706 | Val: Loss=0.2306, F1 Score=0.9529
# Epoch  38/300 | Train: Loss=0.0693, F1 Score=0.9730 | Val: Loss=0.3328, F1 Score=0.9255
# Epoch  39/300 | Train: Loss=0.0755, F1 Score=0.9695 | Val: Loss=0.1697, F1 Score=0.9516
# Epoch  40/300 | Train: Loss=0.0704, F1 Score=0.9721 | Val: Loss=0.2109, F1 Score=0.9564
# Epoch  41/300 | Train: Loss=0.0710, F1 Score=0.9722 | Val: Loss=0.2984, F1 Score=0.9087
# Epoch  42/300 | Train: Loss=0.1056, F1 Score=0.9630 | Val: Loss=0.3531, F1 Score=0.9050
# Epoch  43/300 | Train: Loss=0.0829, F1 Score=0.9673 | Val: Loss=0.3458, F1 Score=0.9212
# Epoch  44/300 | Train: Loss=0.0679, F1 Score=0.9760 | Val: Loss=0.2128, F1 Score=0.9458
# Epoch  45/300 | Train: Loss=0.0587, F1 Score=0.9783 | Val: Loss=0.1582, F1 Score=0.9625
# Epoch  46/300 | Train: Loss=0.0598, F1 Score=0.9767 | Val: Loss=0.2264, F1 Score=0.9514
# Epoch  47/300 | Train: Loss=0.0503, F1 Score=0.9797 | Val: Loss=0.1714, F1 Score=0.9628
# Epoch  48/300 | Train: Loss=0.0476, F1 Score=0.9794 | Val: Loss=0.1750, F1 Score=0.9626
# Epoch  49/300 | Train: Loss=0.0561, F1 Score=0.9795 | Val: Loss=0.2348, F1 Score=0.9576
# Epoch  50/300 | Train: Loss=0.0548, F1 Score=0.9790 | Val: Loss=0.2108, F1 Score=0.9644
# Epoch  51/300 | Train: Loss=0.0416, F1 Score=0.9851 | Val: Loss=0.1929, F1 Score=0.9628
# Epoch  52/300 | Train: Loss=0.0467, F1 Score=0.9813 | Val: Loss=0.3412, F1 Score=0.9368
# Epoch  53/300 | Train: Loss=0.0495, F1 Score=0.9833 | Val: Loss=0.2733, F1 Score=0.9551
# Epoch  54/300 | Train: Loss=0.0593, F1 Score=0.9798 | Val: Loss=0.2892, F1 Score=0.9459
# Epoch  55/300 | Train: Loss=0.0809, F1 Score=0.9727 | Val: Loss=0.1649, F1 Score=0.9692
# Epoch  56/300 | Train: Loss=0.0499, F1 Score=0.9828 | Val: Loss=0.2766, F1 Score=0.9580
# Epoch  57/300 | Train: Loss=0.0533, F1 Score=0.9812 | Val: Loss=0.2829, F1 Score=0.9388
# Epoch  58/300 | Train: Loss=0.0497, F1 Score=0.9807 | Val: Loss=0.2661, F1 Score=0.9488
# Epoch  59/300 | Train: Loss=0.0522, F1 Score=0.9797 | Val: Loss=0.3132, F1 Score=0.9618
# Epoch  60/300 | Train: Loss=0.0477, F1 Score=0.9830 | Val: Loss=0.4256, F1 Score=0.9523
# Epoch  61/300 | Train: Loss=0.0478, F1 Score=0.9818 | Val: Loss=0.2381, F1 Score=0.9564
# Epoch  62/300 | Train: Loss=0.0399, F1 Score=0.9858 | Val: Loss=0.2561, F1 Score=0.9596
# Epoch  63/300 | Train: Loss=0.0357, F1 Score=0.9864 | Val: Loss=0.1968, F1 Score=0.9642
# Epoch  64/300 | Train: Loss=0.0474, F1 Score=0.9839 | Val: Loss=0.2164, F1 Score=0.9575
# Epoch  65/300 | Train: Loss=0.0342, F1 Score=0.9878 | Val: Loss=0.2297, F1 Score=0.9629
# Epoch  66/300 | Train: Loss=0.0391, F1 Score=0.9847 | Val: Loss=0.1856, F1 Score=0.9695
# Epoch  67/300 | Train: Loss=0.0327, F1 Score=0.9882 | Val: Loss=0.2566, F1 Score=0.9646
# Epoch  68/300 | Train: Loss=0.0369, F1 Score=0.9869 | Val: Loss=0.3718, F1 Score=0.9310
# Epoch  69/300 | Train: Loss=0.0463, F1 Score=0.9839 | Val: Loss=0.2749, F1 Score=0.9612
# Epoch  70/300 | Train: Loss=0.0380, F1 Score=0.9861 | Val: Loss=0.2574, F1 Score=0.9596
# Epoch  71/300 | Train: Loss=0.0436, F1 Score=0.9845 | Val: Loss=0.2363, F1 Score=0.9609
# Epoch  72/300 | Train: Loss=0.0384, F1 Score=0.9871 | Val: Loss=0.2545, F1 Score=0.9646
# Epoch  73/300 | Train: Loss=0.0300, F1 Score=0.9892 | Val: Loss=0.2978, F1 Score=0.9565
# Epoch  74/300 | Train: Loss=0.0430, F1 Score=0.9856 | Val: Loss=0.2482, F1 Score=0.9629
# Epoch  75/300 | Train: Loss=0.0314, F1 Score=0.9879 | Val: Loss=0.2379, F1 Score=0.9625
# Epoch  76/300 | Train: Loss=0.0241, F1 Score=0.9908 | Val: Loss=0.2776, F1 Score=0.9616
# Epoch  77/300 | Train: Loss=0.0371, F1 Score=0.9878 | Val: Loss=0.2222, F1 Score=0.9661
# Epoch  78/300 | Train: Loss=0.0254, F1 Score=0.9916 | Val: Loss=0.3050, F1 Score=0.9615
# Epoch  79/300 | Train: Loss=0.0278, F1 Score=0.9902 | Val: Loss=0.2265, F1 Score=0.9643
# Epoch  80/300 | Train: Loss=0.0407, F1 Score=0.9876 | Val: Loss=0.3365, F1 Score=0.9370
# Epoch  81/300 | Train: Loss=0.0294, F1 Score=0.9892 | Val: Loss=0.2088, F1 Score=0.9577
# Epoch  82/300 | Train: Loss=0.0374, F1 Score=0.9875 | Val: Loss=0.3096, F1 Score=0.9580
# Epoch  83/300 | Train: Loss=0.0265, F1 Score=0.9909 | Val: Loss=0.4011, F1 Score=0.9504
# Epoch  84/300 | Train: Loss=0.0319, F1 Score=0.9870 | Val: Loss=0.2809, F1 Score=0.9581
# Epoch  85/300 | Train: Loss=0.0246, F1 Score=0.9923 | Val: Loss=0.3326, F1 Score=0.9566
# Epoch  86/300 | Train: Loss=0.0429, F1 Score=0.9853 | Val: Loss=0.1650, F1 Score=0.9743
# Epoch  87/300 | Train: Loss=0.0217, F1 Score=0.9925 | Val: Loss=0.3136, F1 Score=0.9646
# Epoch  88/300 | Train: Loss=0.0243, F1 Score=0.9908 | Val: Loss=0.2970, F1 Score=0.9650
# Epoch  89/300 | Train: Loss=0.0218, F1 Score=0.9919 | Val: Loss=0.2623, F1 Score=0.9665
# Epoch  90/300 | Train: Loss=0.0198, F1 Score=0.9933 | Val: Loss=0.2840, F1 Score=0.9613
# Epoch  91/300 | Train: Loss=0.0195, F1 Score=0.9926 | Val: Loss=0.1882, F1 Score=0.9745
# Epoch  92/300 | Train: Loss=0.0295, F1 Score=0.9902 | Val: Loss=0.2822, F1 Score=0.9643
# Epoch  93/300 | Train: Loss=0.0165, F1 Score=0.9940 | Val: Loss=0.2132, F1 Score=0.9695
# Epoch  94/300 | Train: Loss=0.0206, F1 Score=0.9933 | Val: Loss=0.2579, F1 Score=0.9642
# Epoch  95/300 | Train: Loss=0.0207, F1 Score=0.9920 | Val: Loss=0.2943, F1 Score=0.9519
# Epoch  96/300 | Train: Loss=0.0351, F1 Score=0.9891 | Val: Loss=0.4250, F1 Score=0.9496
# Epoch  97/300 | Train: Loss=0.0342, F1 Score=0.9899 | Val: Loss=0.4312, F1 Score=0.9532
# Epoch  98/300 | Train: Loss=0.0299, F1 Score=0.9898 | Val: Loss=0.2244, F1 Score=0.9679
# Epoch  99/300 | Train: Loss=0.0140, F1 Score=0.9949 | Val: Loss=0.3501, F1 Score=0.9549
# Epoch 100/300 | Train: Loss=0.0228, F1 Score=0.9918 | Val: Loss=0.2259, F1 Score=0.9728
# Epoch 101/300 | Train: Loss=0.0235, F1 Score=0.9915 | Val: Loss=0.2703, F1 Score=0.9643
# Epoch 102/300 | Train: Loss=0.0314, F1 Score=0.9911 | Val: Loss=0.2723, F1 Score=0.9646
# Epoch 103/300 | Train: Loss=0.0161, F1 Score=0.9945 | Val: Loss=0.2944, F1 Score=0.9645
# Epoch 104/300 | Train: Loss=0.0188, F1 Score=0.9929 | Val: Loss=0.1840, F1 Score=0.9727
# Epoch 105/300 | Train: Loss=0.0219, F1 Score=0.9913 | Val: Loss=0.3460, F1 Score=0.9648
# Epoch 106/300 | Train: Loss=0.0152, F1 Score=0.9945 | Val: Loss=0.3445, F1 Score=0.9513
# Epoch 107/300 | Train: Loss=0.0137, F1 Score=0.9955 | Val: Loss=0.3241, F1 Score=0.9612
# Epoch 108/300 | Train: Loss=0.0137, F1 Score=0.9963 | Val: Loss=0.3168, F1 Score=0.9648
# Epoch 109/300 | Train: Loss=0.0088, F1 Score=0.9973 | Val: Loss=0.3087, F1 Score=0.9609
# Epoch 110/300 | Train: Loss=0.0202, F1 Score=0.9937 | Val: Loss=0.2274, F1 Score=0.9674
# Epoch 111/300 | Train: Loss=0.0243, F1 Score=0.9935 | Val: Loss=0.2282, F1 Score=0.9694
# Epoch 112/300 | Train: Loss=0.0189, F1 Score=0.9933 | Val: Loss=0.4106, F1 Score=0.9599
# Epoch 113/300 | Train: Loss=0.0147, F1 Score=0.9943 | Val: Loss=0.2425, F1 Score=0.9677
# Epoch 114/300 | Train: Loss=0.0291, F1 Score=0.9916 | Val: Loss=0.3236, F1 Score=0.9567
# Epoch 115/300 | Train: Loss=0.0141, F1 Score=0.9940 | Val: Loss=0.2889, F1 Score=0.9580
# Epoch 116/300 | Train: Loss=0.0130, F1 Score=0.9947 | Val: Loss=0.2704, F1 Score=0.9660
# Epoch 117/300 | Train: Loss=0.0093, F1 Score=0.9970 | Val: Loss=0.2695, F1 Score=0.9695
# Epoch 118/300 | Train: Loss=0.0128, F1 Score=0.9963 | Val: Loss=0.4297, F1 Score=0.9499
# Epoch 119/300 | Train: Loss=0.0225, F1 Score=0.9922 | Val: Loss=0.3882, F1 Score=0.9563
# Epoch 120/300 | Train: Loss=0.0179, F1 Score=0.9942 | Val: Loss=0.3932, F1 Score=0.9634
# Epoch 121/300 | Train: Loss=0.0134, F1 Score=0.9957 | Val: Loss=0.4293, F1 Score=0.9614
# Epoch 122/300 | Train: Loss=0.0073, F1 Score=0.9974 | Val: Loss=0.2901, F1 Score=0.9661
# Epoch 123/300 | Train: Loss=0.0344, F1 Score=0.9918 | Val: Loss=0.1532, F1 Score=0.9687
# Epoch 124/300 | Train: Loss=0.0186, F1 Score=0.9936 | Val: Loss=0.3093, F1 Score=0.9677
# Epoch 125/300 | Train: Loss=0.0147, F1 Score=0.9950 | Val: Loss=0.3633, F1 Score=0.9612
# Epoch 126/300 | Train: Loss=0.0129, F1 Score=0.9963 | Val: Loss=0.3242, F1 Score=0.9581
# Epoch 127/300 | Train: Loss=0.0109, F1 Score=0.9960 | Val: Loss=0.3206, F1 Score=0.9664
# Epoch 128/300 | Train: Loss=0.0209, F1 Score=0.9937 | Val: Loss=0.6005, F1 Score=0.9456
# Epoch 129/300 | Train: Loss=0.0076, F1 Score=0.9970 | Val: Loss=0.3323, F1 Score=0.9650
# Epoch 130/300 | Train: Loss=0.0072, F1 Score=0.9974 | Val: Loss=0.2922, F1 Score=0.9713
# Epoch 131/300 | Train: Loss=0.0051, F1 Score=0.9990 | Val: Loss=0.3583, F1 Score=0.9647
# Epoch 132/300 | Train: Loss=0.0102, F1 Score=0.9967 | Val: Loss=0.2865, F1 Score=0.9695
# Epoch 133/300 | Train: Loss=0.0114, F1 Score=0.9963 | Val: Loss=0.4445, F1 Score=0.9570
# Epoch 134/300 | Train: Loss=0.0238, F1 Score=0.9916 | Val: Loss=0.3381, F1 Score=0.9665
# Epoch 135/300 | Train: Loss=0.0191, F1 Score=0.9930 | Val: Loss=0.3090, F1 Score=0.9643
# Epoch 136/300 | Train: Loss=0.0068, F1 Score=0.9976 | Val: Loss=0.2537, F1 Score=0.9681
# Epoch 137/300 | Train: Loss=0.0085, F1 Score=0.9970 | Val: Loss=0.2732, F1 Score=0.9678
# Epoch 138/300 | Train: Loss=0.0303, F1 Score=0.9909 | Val: Loss=0.4865, F1 Score=0.9633
# Epoch 139/300 | Train: Loss=0.0238, F1 Score=0.9926 | Val: Loss=0.3188, F1 Score=0.9612
# Epoch 140/300 | Train: Loss=0.0247, F1 Score=0.9925 | Val: Loss=0.4436, F1 Score=0.9467
# Epoch 141/300 | Train: Loss=0.0106, F1 Score=0.9966 | Val: Loss=0.2700, F1 Score=0.9713
# Early stopping triggered after 141 epochs.
# Best model restored from epoch 91 with val_f1 0.9745
# Split 3/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9814, F1 Score=0.4272 | Val: Loss=0.7634, F1 Score=0.6660
# Epoch   2/300 | Train: Loss=0.8480, F1 Score=0.5645 | Val: Loss=0.6658, F1 Score=0.7117
# Epoch   3/300 | Train: Loss=0.7503, F1 Score=0.6518 | Val: Loss=0.6623, F1 Score=0.7296
# Epoch   4/300 | Train: Loss=0.7230, F1 Score=0.6841 | Val: Loss=0.8281, F1 Score=0.6610
# Epoch   5/300 | Train: Loss=0.6659, F1 Score=0.7228 | Val: Loss=0.7856, F1 Score=0.6856
# Epoch   6/300 | Train: Loss=0.6025, F1 Score=0.7552 | Val: Loss=0.4890, F1 Score=0.7959
# Epoch   7/300 | Train: Loss=0.5003, F1 Score=0.8109 | Val: Loss=0.4634, F1 Score=0.8122
# Epoch   8/300 | Train: Loss=0.4541, F1 Score=0.8295 | Val: Loss=0.4582, F1 Score=0.8021
# Epoch   9/300 | Train: Loss=0.4335, F1 Score=0.8337 | Val: Loss=0.4865, F1 Score=0.8126
# Epoch  10/300 | Train: Loss=0.3899, F1 Score=0.8528 | Val: Loss=0.4527, F1 Score=0.8228
# Epoch  11/300 | Train: Loss=0.3733, F1 Score=0.8642 | Val: Loss=0.3581, F1 Score=0.8476
# Epoch  12/300 | Train: Loss=0.3586, F1 Score=0.8688 | Val: Loss=0.4519, F1 Score=0.8274
# Epoch  13/300 | Train: Loss=0.3122, F1 Score=0.8873 | Val: Loss=0.3095, F1 Score=0.8992
# Epoch  14/300 | Train: Loss=0.3036, F1 Score=0.8866 | Val: Loss=0.3464, F1 Score=0.8783
# Epoch  15/300 | Train: Loss=0.2374, F1 Score=0.9158 | Val: Loss=0.4687, F1 Score=0.8543
# Epoch  16/300 | Train: Loss=0.2158, F1 Score=0.9221 | Val: Loss=0.3420, F1 Score=0.8975
# Epoch  17/300 | Train: Loss=0.1925, F1 Score=0.9284 | Val: Loss=0.4399, F1 Score=0.8712
# Epoch  18/300 | Train: Loss=0.1894, F1 Score=0.9319 | Val: Loss=0.3439, F1 Score=0.9104
# Epoch  19/300 | Train: Loss=0.1684, F1 Score=0.9400 | Val: Loss=0.4421, F1 Score=0.8796
# Epoch  20/300 | Train: Loss=0.1776, F1 Score=0.9359 | Val: Loss=0.3431, F1 Score=0.9024
# Epoch  21/300 | Train: Loss=0.1635, F1 Score=0.9422 | Val: Loss=0.3796, F1 Score=0.9109
# Epoch  22/300 | Train: Loss=0.1550, F1 Score=0.9455 | Val: Loss=0.4140, F1 Score=0.9100
# Epoch  23/300 | Train: Loss=0.1349, F1 Score=0.9490 | Val: Loss=0.5456, F1 Score=0.8720
# Epoch  24/300 | Train: Loss=0.1432, F1 Score=0.9482 | Val: Loss=0.3973, F1 Score=0.9061
# Epoch  25/300 | Train: Loss=0.1341, F1 Score=0.9469 | Val: Loss=0.4462, F1 Score=0.9056
# Epoch  26/300 | Train: Loss=0.1424, F1 Score=0.9458 | Val: Loss=0.4341, F1 Score=0.9071
# Epoch  27/300 | Train: Loss=0.1288, F1 Score=0.9544 | Val: Loss=0.5307, F1 Score=0.8928
# Epoch  28/300 | Train: Loss=0.1110, F1 Score=0.9587 | Val: Loss=0.3891, F1 Score=0.9099
# Epoch  29/300 | Train: Loss=0.1109, F1 Score=0.9586 | Val: Loss=0.4064, F1 Score=0.9123
# Epoch  30/300 | Train: Loss=0.0985, F1 Score=0.9635 | Val: Loss=0.4041, F1 Score=0.9263
# Epoch  31/300 | Train: Loss=0.0934, F1 Score=0.9685 | Val: Loss=0.4362, F1 Score=0.9008
# Epoch  32/300 | Train: Loss=0.1313, F1 Score=0.9522 | Val: Loss=0.3508, F1 Score=0.9183
# Epoch  33/300 | Train: Loss=0.0797, F1 Score=0.9697 | Val: Loss=0.4452, F1 Score=0.9089
# Epoch  34/300 | Train: Loss=0.0831, F1 Score=0.9699 | Val: Loss=0.5442, F1 Score=0.9102
# Epoch  35/300 | Train: Loss=0.0855, F1 Score=0.9676 | Val: Loss=0.3933, F1 Score=0.9237
# Epoch  36/300 | Train: Loss=0.0744, F1 Score=0.9729 | Val: Loss=0.4146, F1 Score=0.9124
# Epoch  37/300 | Train: Loss=0.0642, F1 Score=0.9766 | Val: Loss=0.5182, F1 Score=0.9038
# Epoch  38/300 | Train: Loss=0.0718, F1 Score=0.9731 | Val: Loss=0.4666, F1 Score=0.9162
# Epoch  39/300 | Train: Loss=0.0777, F1 Score=0.9694 | Val: Loss=0.4483, F1 Score=0.9193
# Epoch  40/300 | Train: Loss=0.0555, F1 Score=0.9806 | Val: Loss=0.4791, F1 Score=0.9194
# Epoch  41/300 | Train: Loss=0.0712, F1 Score=0.9742 | Val: Loss=0.4807, F1 Score=0.8989
# Epoch  42/300 | Train: Loss=0.0668, F1 Score=0.9737 | Val: Loss=0.3849, F1 Score=0.9265
# Epoch  43/300 | Train: Loss=0.0529, F1 Score=0.9796 | Val: Loss=0.4027, F1 Score=0.9151
# Epoch  44/300 | Train: Loss=0.0698, F1 Score=0.9774 | Val: Loss=0.5011, F1 Score=0.9052
# Epoch  45/300 | Train: Loss=0.0504, F1 Score=0.9804 | Val: Loss=0.4152, F1 Score=0.9050
# Epoch  46/300 | Train: Loss=0.0549, F1 Score=0.9792 | Val: Loss=0.5206, F1 Score=0.9119
# Epoch  47/300 | Train: Loss=0.0657, F1 Score=0.9796 | Val: Loss=0.4048, F1 Score=0.9275
# Epoch  48/300 | Train: Loss=0.0507, F1 Score=0.9813 | Val: Loss=0.4681, F1 Score=0.9212
# Epoch  49/300 | Train: Loss=0.0597, F1 Score=0.9810 | Val: Loss=0.4323, F1 Score=0.9187
# Epoch  50/300 | Train: Loss=0.0530, F1 Score=0.9815 | Val: Loss=0.4497, F1 Score=0.9206
# Epoch  51/300 | Train: Loss=0.0467, F1 Score=0.9832 | Val: Loss=0.4019, F1 Score=0.9221
# Epoch  52/300 | Train: Loss=0.0660, F1 Score=0.9769 | Val: Loss=0.3300, F1 Score=0.9385
# Epoch  53/300 | Train: Loss=0.0397, F1 Score=0.9839 | Val: Loss=0.3580, F1 Score=0.9352
# Epoch  54/300 | Train: Loss=0.0388, F1 Score=0.9846 | Val: Loss=0.4055, F1 Score=0.9298
# Epoch  55/300 | Train: Loss=0.0593, F1 Score=0.9796 | Val: Loss=0.6665, F1 Score=0.8801
# Epoch  56/300 | Train: Loss=0.0630, F1 Score=0.9772 | Val: Loss=0.3656, F1 Score=0.9170
# Epoch  57/300 | Train: Loss=0.0366, F1 Score=0.9894 | Val: Loss=0.4596, F1 Score=0.9296
# Epoch  58/300 | Train: Loss=0.0372, F1 Score=0.9856 | Val: Loss=0.5048, F1 Score=0.9238
# Epoch  59/300 | Train: Loss=0.0379, F1 Score=0.9873 | Val: Loss=0.5240, F1 Score=0.9218
# Epoch  60/300 | Train: Loss=0.0431, F1 Score=0.9847 | Val: Loss=0.4536, F1 Score=0.9299
# Epoch  61/300 | Train: Loss=0.0349, F1 Score=0.9880 | Val: Loss=0.5015, F1 Score=0.9235
# Epoch  62/300 | Train: Loss=0.0310, F1 Score=0.9887 | Val: Loss=0.2894, F1 Score=0.9321
# Epoch  63/300 | Train: Loss=0.0424, F1 Score=0.9847 | Val: Loss=0.4001, F1 Score=0.9338
# Epoch  64/300 | Train: Loss=0.0375, F1 Score=0.9862 | Val: Loss=0.4571, F1 Score=0.9056
# Epoch  65/300 | Train: Loss=0.0417, F1 Score=0.9846 | Val: Loss=0.4548, F1 Score=0.9201
# Epoch  66/300 | Train: Loss=0.0357, F1 Score=0.9867 | Val: Loss=0.5175, F1 Score=0.9248
# Epoch  67/300 | Train: Loss=0.0373, F1 Score=0.9873 | Val: Loss=0.3724, F1 Score=0.9285
# Epoch  68/300 | Train: Loss=0.0246, F1 Score=0.9899 | Val: Loss=0.4973, F1 Score=0.9249
# Epoch  69/300 | Train: Loss=0.0447, F1 Score=0.9859 | Val: Loss=0.5055, F1 Score=0.9283
# Epoch  70/300 | Train: Loss=0.0378, F1 Score=0.9873 | Val: Loss=0.4407, F1 Score=0.9309
# Epoch  71/300 | Train: Loss=0.0288, F1 Score=0.9906 | Val: Loss=0.5367, F1 Score=0.9225
# Epoch  72/300 | Train: Loss=0.0357, F1 Score=0.9889 | Val: Loss=0.4589, F1 Score=0.9293
# Epoch  73/300 | Train: Loss=0.0230, F1 Score=0.9913 | Val: Loss=0.3500, F1 Score=0.9296
# Epoch  74/300 | Train: Loss=0.0296, F1 Score=0.9900 | Val: Loss=0.5575, F1 Score=0.9134
# Epoch  75/300 | Train: Loss=0.0507, F1 Score=0.9852 | Val: Loss=0.4540, F1 Score=0.9260
# Epoch  76/300 | Train: Loss=0.0301, F1 Score=0.9897 | Val: Loss=0.5395, F1 Score=0.9189
# Epoch  77/300 | Train: Loss=0.0240, F1 Score=0.9902 | Val: Loss=0.4518, F1 Score=0.9267
# Epoch  78/300 | Train: Loss=0.0160, F1 Score=0.9930 | Val: Loss=0.4580, F1 Score=0.9289
# Epoch  79/300 | Train: Loss=0.0292, F1 Score=0.9906 | Val: Loss=0.4508, F1 Score=0.9211
# Epoch  80/300 | Train: Loss=0.0315, F1 Score=0.9903 | Val: Loss=0.3379, F1 Score=0.9351
# Epoch  81/300 | Train: Loss=0.0201, F1 Score=0.9927 | Val: Loss=0.4804, F1 Score=0.9284
# Epoch  82/300 | Train: Loss=0.0119, F1 Score=0.9961 | Val: Loss=0.3938, F1 Score=0.9275
# Epoch  83/300 | Train: Loss=0.0382, F1 Score=0.9876 | Val: Loss=0.3996, F1 Score=0.9307
# Epoch  84/300 | Train: Loss=0.0212, F1 Score=0.9929 | Val: Loss=0.4242, F1 Score=0.9358
# Epoch  85/300 | Train: Loss=0.0234, F1 Score=0.9927 | Val: Loss=0.3611, F1 Score=0.9499
# Epoch  86/300 | Train: Loss=0.0215, F1 Score=0.9934 | Val: Loss=0.5291, F1 Score=0.9341
# Epoch  87/300 | Train: Loss=0.0283, F1 Score=0.9912 | Val: Loss=0.4390, F1 Score=0.9288
# Epoch  88/300 | Train: Loss=0.0286, F1 Score=0.9912 | Val: Loss=0.3041, F1 Score=0.9365
# Epoch  89/300 | Train: Loss=0.0189, F1 Score=0.9939 | Val: Loss=0.3774, F1 Score=0.9451
# Epoch  90/300 | Train: Loss=0.0172, F1 Score=0.9942 | Val: Loss=0.5505, F1 Score=0.9202
# Epoch  91/300 | Train: Loss=0.0131, F1 Score=0.9964 | Val: Loss=0.4061, F1 Score=0.9319
# Epoch  92/300 | Train: Loss=0.0216, F1 Score=0.9924 | Val: Loss=0.3691, F1 Score=0.9424
# Epoch  93/300 | Train: Loss=0.0132, F1 Score=0.9963 | Val: Loss=0.5306, F1 Score=0.9256
# Epoch  94/300 | Train: Loss=0.0126, F1 Score=0.9960 | Val: Loss=0.3553, F1 Score=0.9533
# Epoch  95/300 | Train: Loss=0.0207, F1 Score=0.9933 | Val: Loss=0.6049, F1 Score=0.9109
# Epoch  96/300 | Train: Loss=0.0253, F1 Score=0.9923 | Val: Loss=0.4071, F1 Score=0.9414
# Epoch  97/300 | Train: Loss=0.0239, F1 Score=0.9926 | Val: Loss=0.3725, F1 Score=0.9377
# Epoch  98/300 | Train: Loss=0.0248, F1 Score=0.9929 | Val: Loss=0.3696, F1 Score=0.9386
# Epoch  99/300 | Train: Loss=0.0166, F1 Score=0.9944 | Val: Loss=0.2975, F1 Score=0.9515
# Epoch 100/300 | Train: Loss=0.0296, F1 Score=0.9917 | Val: Loss=0.4240, F1 Score=0.9454
# Epoch 101/300 | Train: Loss=0.0157, F1 Score=0.9949 | Val: Loss=0.3701, F1 Score=0.9385
# Epoch 102/300 | Train: Loss=0.0150, F1 Score=0.9944 | Val: Loss=0.5047, F1 Score=0.9252
# Epoch 103/300 | Train: Loss=0.0321, F1 Score=0.9890 | Val: Loss=0.4725, F1 Score=0.9159
# Epoch 104/300 | Train: Loss=0.0182, F1 Score=0.9940 | Val: Loss=0.4677, F1 Score=0.9291
# Epoch 105/300 | Train: Loss=0.0112, F1 Score=0.9964 | Val: Loss=0.4115, F1 Score=0.9407
# Epoch 106/300 | Train: Loss=0.0155, F1 Score=0.9951 | Val: Loss=0.4858, F1 Score=0.9316
# Epoch 107/300 | Train: Loss=0.0211, F1 Score=0.9923 | Val: Loss=0.2225, F1 Score=0.9625
# Epoch 108/300 | Train: Loss=0.0348, F1 Score=0.9913 | Val: Loss=0.3894, F1 Score=0.9314
# Epoch 109/300 | Train: Loss=0.0173, F1 Score=0.9941 | Val: Loss=0.3184, F1 Score=0.9434
# Epoch 110/300 | Train: Loss=0.0158, F1 Score=0.9953 | Val: Loss=0.4833, F1 Score=0.9261
# Epoch 111/300 | Train: Loss=0.0218, F1 Score=0.9926 | Val: Loss=0.3743, F1 Score=0.9387
# Epoch 112/300 | Train: Loss=0.0120, F1 Score=0.9959 | Val: Loss=0.3716, F1 Score=0.9305
# Epoch 113/300 | Train: Loss=0.0124, F1 Score=0.9966 | Val: Loss=0.4788, F1 Score=0.9217
# Epoch 114/300 | Train: Loss=0.0213, F1 Score=0.9932 | Val: Loss=0.8047, F1 Score=0.8709
# Epoch 115/300 | Train: Loss=0.0370, F1 Score=0.9902 | Val: Loss=0.6923, F1 Score=0.9184
# Epoch 116/300 | Train: Loss=0.0185, F1 Score=0.9950 | Val: Loss=0.5002, F1 Score=0.9246
# Epoch 117/300 | Train: Loss=0.0134, F1 Score=0.9949 | Val: Loss=0.4553, F1 Score=0.9317
# Epoch 118/300 | Train: Loss=0.0078, F1 Score=0.9974 | Val: Loss=0.3726, F1 Score=0.9389
# Epoch 119/300 | Train: Loss=0.0078, F1 Score=0.9967 | Val: Loss=0.7522, F1 Score=0.9092
# Epoch 120/300 | Train: Loss=0.0282, F1 Score=0.9931 | Val: Loss=0.6531, F1 Score=0.9203
# Epoch 121/300 | Train: Loss=0.0255, F1 Score=0.9917 | Val: Loss=0.3405, F1 Score=0.9420
# Epoch 122/300 | Train: Loss=0.0087, F1 Score=0.9961 | Val: Loss=0.5904, F1 Score=0.9371
# Epoch 123/300 | Train: Loss=0.0220, F1 Score=0.9926 | Val: Loss=0.6885, F1 Score=0.9158
# Epoch 124/300 | Train: Loss=0.0118, F1 Score=0.9966 | Val: Loss=0.5627, F1 Score=0.9302
# Epoch 125/300 | Train: Loss=0.0121, F1 Score=0.9959 | Val: Loss=0.5493, F1 Score=0.9306
# Epoch 126/300 | Train: Loss=0.0115, F1 Score=0.9964 | Val: Loss=0.4878, F1 Score=0.9394
# Epoch 127/300 | Train: Loss=0.0234, F1 Score=0.9919 | Val: Loss=0.4263, F1 Score=0.9382
# Epoch 128/300 | Train: Loss=0.0177, F1 Score=0.9947 | Val: Loss=0.5155, F1 Score=0.9444
# Epoch 129/300 | Train: Loss=0.0229, F1 Score=0.9924 | Val: Loss=0.5333, F1 Score=0.9387
# Epoch 130/300 | Train: Loss=0.0101, F1 Score=0.9964 | Val: Loss=0.5489, F1 Score=0.9215
# Epoch 131/300 | Train: Loss=0.0165, F1 Score=0.9954 | Val: Loss=0.6264, F1 Score=0.9142
# Epoch 132/300 | Train: Loss=0.0110, F1 Score=0.9967 | Val: Loss=0.4698, F1 Score=0.9333
# Epoch 133/300 | Train: Loss=0.0441, F1 Score=0.9884 | Val: Loss=0.7038, F1 Score=0.9230
# Epoch 134/300 | Train: Loss=0.0121, F1 Score=0.9963 | Val: Loss=0.5836, F1 Score=0.9227
# Epoch 135/300 | Train: Loss=0.0067, F1 Score=0.9980 | Val: Loss=0.6180, F1 Score=0.9250
# Epoch 136/300 | Train: Loss=0.0055, F1 Score=0.9984 | Val: Loss=0.6425, F1 Score=0.9090
# Epoch 137/300 | Train: Loss=0.0115, F1 Score=0.9960 | Val: Loss=0.4970, F1 Score=0.9403
# Epoch 138/300 | Train: Loss=0.0076, F1 Score=0.9969 | Val: Loss=0.5235, F1 Score=0.9254
# Epoch 139/300 | Train: Loss=0.0083, F1 Score=0.9979 | Val: Loss=0.5721, F1 Score=0.9215
# Epoch 140/300 | Train: Loss=0.0037, F1 Score=0.9987 | Val: Loss=0.4659, F1 Score=0.9325
# Epoch 141/300 | Train: Loss=0.0093, F1 Score=0.9980 | Val: Loss=0.5484, F1 Score=0.9116
# Epoch 142/300 | Train: Loss=0.0197, F1 Score=0.9937 | Val: Loss=0.5012, F1 Score=0.9326
# Epoch 143/300 | Train: Loss=0.0053, F1 Score=0.9981 | Val: Loss=0.4615, F1 Score=0.9336
# Epoch 144/300 | Train: Loss=0.0022, F1 Score=0.9993 | Val: Loss=0.4672, F1 Score=0.9297
# Epoch 145/300 | Train: Loss=0.0122, F1 Score=0.9964 | Val: Loss=0.5327, F1 Score=0.9266
# Epoch 146/300 | Train: Loss=0.0235, F1 Score=0.9932 | Val: Loss=0.6571, F1 Score=0.9306
# Epoch 147/300 | Train: Loss=0.0282, F1 Score=0.9922 | Val: Loss=0.6173, F1 Score=0.9194
# Epoch 148/300 | Train: Loss=0.0068, F1 Score=0.9983 | Val: Loss=0.6802, F1 Score=0.9209
# Epoch 149/300 | Train: Loss=0.0045, F1 Score=0.9989 | Val: Loss=0.4829, F1 Score=0.9265
# Epoch 150/300 | Train: Loss=0.0072, F1 Score=0.9977 | Val: Loss=0.6002, F1 Score=0.9196
# Epoch 151/300 | Train: Loss=0.0103, F1 Score=0.9971 | Val: Loss=0.8115, F1 Score=0.9130
# Epoch 152/300 | Train: Loss=0.0187, F1 Score=0.9953 | Val: Loss=0.7549, F1 Score=0.9178
# Epoch 153/300 | Train: Loss=0.0086, F1 Score=0.9976 | Val: Loss=0.5531, F1 Score=0.9247
# Epoch 154/300 | Train: Loss=0.0111, F1 Score=0.9973 | Val: Loss=0.6148, F1 Score=0.9193
# Epoch 155/300 | Train: Loss=0.0074, F1 Score=0.9976 | Val: Loss=0.5777, F1 Score=0.9205
# Epoch 156/300 | Train: Loss=0.0120, F1 Score=0.9971 | Val: Loss=0.4677, F1 Score=0.9288
# Epoch 157/300 | Train: Loss=0.0105, F1 Score=0.9961 | Val: Loss=0.4164, F1 Score=0.9394
# Early stopping triggered after 157 epochs.
# Best model restored from epoch 107 with val_f1 0.9625
# Split 4/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9663, F1 Score=0.4473 | Val: Loss=0.8555, F1 Score=0.5400
# Epoch   2/300 | Train: Loss=0.8246, F1 Score=0.5777 | Val: Loss=0.7635, F1 Score=0.6358
# Epoch   3/300 | Train: Loss=0.7592, F1 Score=0.6232 | Val: Loss=0.7399, F1 Score=0.6471
# Epoch   4/300 | Train: Loss=0.7305, F1 Score=0.6456 | Val: Loss=0.7249, F1 Score=0.6915
# Epoch   5/300 | Train: Loss=0.6665, F1 Score=0.6875 | Val: Loss=0.6569, F1 Score=0.7248
# Epoch   6/300 | Train: Loss=0.5990, F1 Score=0.7253 | Val: Loss=0.6476, F1 Score=0.7670
# Epoch   7/300 | Train: Loss=0.5132, F1 Score=0.7988 | Val: Loss=0.5940, F1 Score=0.8274
# Epoch   8/300 | Train: Loss=0.4701, F1 Score=0.8216 | Val: Loss=0.5720, F1 Score=0.8151
# Epoch   9/300 | Train: Loss=0.4186, F1 Score=0.8401 | Val: Loss=0.6069, F1 Score=0.8049
# Epoch  10/300 | Train: Loss=0.3989, F1 Score=0.8424 | Val: Loss=0.5249, F1 Score=0.8219
# Epoch  11/300 | Train: Loss=0.3641, F1 Score=0.8608 | Val: Loss=0.5535, F1 Score=0.8073
# Epoch  12/300 | Train: Loss=0.3638, F1 Score=0.8636 | Val: Loss=0.6080, F1 Score=0.8049
# Epoch  13/300 | Train: Loss=0.3346, F1 Score=0.8752 | Val: Loss=0.5517, F1 Score=0.8372
# Epoch  14/300 | Train: Loss=0.3070, F1 Score=0.8854 | Val: Loss=0.4949, F1 Score=0.8558
# Epoch  15/300 | Train: Loss=0.2817, F1 Score=0.8981 | Val: Loss=0.5585, F1 Score=0.8479
# Epoch  16/300 | Train: Loss=0.2696, F1 Score=0.9021 | Val: Loss=0.5289, F1 Score=0.8521
# Epoch  17/300 | Train: Loss=0.2482, F1 Score=0.9091 | Val: Loss=0.5668, F1 Score=0.8546
# Epoch  18/300 | Train: Loss=0.2290, F1 Score=0.9160 | Val: Loss=0.5170, F1 Score=0.8389
# Epoch  19/300 | Train: Loss=0.2021, F1 Score=0.9288 | Val: Loss=0.5474, F1 Score=0.8461
# Epoch  20/300 | Train: Loss=0.1953, F1 Score=0.9288 | Val: Loss=0.5154, F1 Score=0.8682
# Epoch  21/300 | Train: Loss=0.1795, F1 Score=0.9378 | Val: Loss=0.4970, F1 Score=0.8989
# Epoch  22/300 | Train: Loss=0.1545, F1 Score=0.9447 | Val: Loss=0.4448, F1 Score=0.9069
# Epoch  23/300 | Train: Loss=0.1542, F1 Score=0.9447 | Val: Loss=0.4406, F1 Score=0.9152
# Epoch  24/300 | Train: Loss=0.1572, F1 Score=0.9454 | Val: Loss=0.4842, F1 Score=0.9012
# Epoch  25/300 | Train: Loss=0.1486, F1 Score=0.9435 | Val: Loss=0.4983, F1 Score=0.8882
# Epoch  26/300 | Train: Loss=0.1334, F1 Score=0.9533 | Val: Loss=0.5244, F1 Score=0.9106
# Epoch  27/300 | Train: Loss=0.1443, F1 Score=0.9471 | Val: Loss=0.5068, F1 Score=0.9002
# Epoch  28/300 | Train: Loss=0.1342, F1 Score=0.9498 | Val: Loss=0.4584, F1 Score=0.9260
# Epoch  29/300 | Train: Loss=0.1146, F1 Score=0.9559 | Val: Loss=0.4891, F1 Score=0.9191
# Epoch  30/300 | Train: Loss=0.1139, F1 Score=0.9588 | Val: Loss=0.4264, F1 Score=0.9356
# Epoch  31/300 | Train: Loss=0.1155, F1 Score=0.9578 | Val: Loss=0.4385, F1 Score=0.9291
# Epoch  32/300 | Train: Loss=0.0934, F1 Score=0.9649 | Val: Loss=0.4896, F1 Score=0.9265
# Epoch  33/300 | Train: Loss=0.1094, F1 Score=0.9601 | Val: Loss=0.4701, F1 Score=0.9204
# Epoch  34/300 | Train: Loss=0.0822, F1 Score=0.9681 | Val: Loss=0.5304, F1 Score=0.9181
# Epoch  35/300 | Train: Loss=0.0677, F1 Score=0.9711 | Val: Loss=0.5079, F1 Score=0.9189
# Epoch  36/300 | Train: Loss=0.0722, F1 Score=0.9723 | Val: Loss=0.6185, F1 Score=0.8889
# Epoch  37/300 | Train: Loss=0.0840, F1 Score=0.9681 | Val: Loss=0.5268, F1 Score=0.9137
# Epoch  38/300 | Train: Loss=0.1069, F1 Score=0.9624 | Val: Loss=0.5526, F1 Score=0.8931
# Epoch  39/300 | Train: Loss=0.0778, F1 Score=0.9701 | Val: Loss=0.5599, F1 Score=0.8992
# Epoch  40/300 | Train: Loss=0.0707, F1 Score=0.9732 | Val: Loss=0.5306, F1 Score=0.9260
# Epoch  41/300 | Train: Loss=0.0760, F1 Score=0.9688 | Val: Loss=0.5110, F1 Score=0.9300
# Epoch  42/300 | Train: Loss=0.0962, F1 Score=0.9630 | Val: Loss=0.4840, F1 Score=0.9356
# Epoch  43/300 | Train: Loss=0.0592, F1 Score=0.9768 | Val: Loss=0.5049, F1 Score=0.9361
# Epoch  44/300 | Train: Loss=0.0662, F1 Score=0.9756 | Val: Loss=0.5456, F1 Score=0.9288
# Epoch  45/300 | Train: Loss=0.0597, F1 Score=0.9791 | Val: Loss=0.5793, F1 Score=0.9301
# Epoch  46/300 | Train: Loss=0.0779, F1 Score=0.9688 | Val: Loss=0.6860, F1 Score=0.8930
# Epoch  47/300 | Train: Loss=0.0936, F1 Score=0.9694 | Val: Loss=0.5351, F1 Score=0.9208
# Epoch  48/300 | Train: Loss=0.0630, F1 Score=0.9746 | Val: Loss=0.5668, F1 Score=0.9295
# Epoch  49/300 | Train: Loss=0.0585, F1 Score=0.9778 | Val: Loss=0.5807, F1 Score=0.9168
# Epoch  50/300 | Train: Loss=0.0548, F1 Score=0.9800 | Val: Loss=0.5568, F1 Score=0.9412
# Epoch  51/300 | Train: Loss=0.0549, F1 Score=0.9783 | Val: Loss=0.5438, F1 Score=0.9354
# Epoch  52/300 | Train: Loss=0.0474, F1 Score=0.9810 | Val: Loss=0.5589, F1 Score=0.9256
# Epoch  53/300 | Train: Loss=0.0455, F1 Score=0.9816 | Val: Loss=0.6102, F1 Score=0.9315
# Epoch  54/300 | Train: Loss=0.0493, F1 Score=0.9822 | Val: Loss=0.5484, F1 Score=0.9246
# Epoch  55/300 | Train: Loss=0.0491, F1 Score=0.9837 | Val: Loss=0.5671, F1 Score=0.9253
# Epoch  56/300 | Train: Loss=0.0437, F1 Score=0.9823 | Val: Loss=0.6498, F1 Score=0.9220
# Epoch  57/300 | Train: Loss=0.0436, F1 Score=0.9835 | Val: Loss=0.6747, F1 Score=0.9119
# Epoch  58/300 | Train: Loss=0.0478, F1 Score=0.9832 | Val: Loss=0.6242, F1 Score=0.9336
# Epoch  59/300 | Train: Loss=0.0499, F1 Score=0.9819 | Val: Loss=0.7568, F1 Score=0.9072
# Epoch  60/300 | Train: Loss=0.0587, F1 Score=0.9784 | Val: Loss=0.6124, F1 Score=0.9241
# Epoch  61/300 | Train: Loss=0.0373, F1 Score=0.9848 | Val: Loss=0.6622, F1 Score=0.8983
# Epoch  62/300 | Train: Loss=0.0452, F1 Score=0.9852 | Val: Loss=0.8109, F1 Score=0.9067
# Epoch  63/300 | Train: Loss=0.0623, F1 Score=0.9811 | Val: Loss=0.6385, F1 Score=0.9212
# Epoch  64/300 | Train: Loss=0.0353, F1 Score=0.9872 | Val: Loss=0.5985, F1 Score=0.9232
# Epoch  65/300 | Train: Loss=0.0351, F1 Score=0.9857 | Val: Loss=0.5696, F1 Score=0.9314
# Epoch  66/300 | Train: Loss=0.0439, F1 Score=0.9843 | Val: Loss=0.5990, F1 Score=0.9355
# Epoch  67/300 | Train: Loss=0.0398, F1 Score=0.9855 | Val: Loss=0.5639, F1 Score=0.9238
# Epoch  68/300 | Train: Loss=0.0421, F1 Score=0.9842 | Val: Loss=0.7232, F1 Score=0.9297
# Epoch  69/300 | Train: Loss=0.0395, F1 Score=0.9851 | Val: Loss=0.6870, F1 Score=0.9276
# Epoch  70/300 | Train: Loss=0.0685, F1 Score=0.9813 | Val: Loss=0.7057, F1 Score=0.9206
# Epoch  71/300 | Train: Loss=0.0485, F1 Score=0.9826 | Val: Loss=0.5715, F1 Score=0.9273
# Epoch  72/300 | Train: Loss=0.0350, F1 Score=0.9872 | Val: Loss=0.6486, F1 Score=0.9310
# Epoch  73/300 | Train: Loss=0.0416, F1 Score=0.9843 | Val: Loss=0.6248, F1 Score=0.9301
# Epoch  74/300 | Train: Loss=0.0284, F1 Score=0.9887 | Val: Loss=0.6194, F1 Score=0.9291
# Epoch  75/300 | Train: Loss=0.0289, F1 Score=0.9896 | Val: Loss=0.6591, F1 Score=0.9165
# Epoch  76/300 | Train: Loss=0.0224, F1 Score=0.9914 | Val: Loss=0.6490, F1 Score=0.9376
# Epoch  77/300 | Train: Loss=0.0286, F1 Score=0.9901 | Val: Loss=0.6474, F1 Score=0.9321
# Epoch  78/300 | Train: Loss=0.0437, F1 Score=0.9852 | Val: Loss=0.6730, F1 Score=0.9248
# Epoch  79/300 | Train: Loss=0.0249, F1 Score=0.9900 | Val: Loss=0.6994, F1 Score=0.9261
# ...
# Epoch  97/300 | Train: Loss=0.0211, F1 Score=0.9928 | Val: Loss=0.7977, F1 Score=0.9209
# Epoch  98/300 | Train: Loss=0.0143, F1 Score=0.9945 | Val: Loss=0.7858, F1 Score=0.9341
# Epoch  99/300 | Train: Loss=0.0197, F1 Score=0.9929 | Val: Loss=0.7321, F1 Score=0.9323
# Epoch 100/300 | Train: Loss=0.0164, F1 Score=0.9948 | Val: Loss=0.7266, F1 Score=0.9332
# Early stopping triggered after 100 epochs.
# Best model restored from epoch 50 with val_f1 0.9412
# Split 5/5
# Training 300 epochs...
# Epoch   1/300 | Train: Loss=0.9878, F1 Score=0.4204 | Val: Loss=0.6516, F1 Score=0.7752
# Epoch   2/300 | Train: Loss=0.8733, F1 Score=0.5402 | Val: Loss=0.4637, F1 Score=0.8262
# Epoch   3/300 | Train: Loss=0.7811, F1 Score=0.6251 | Val: Loss=0.5287, F1 Score=0.8523
# Epoch   4/300 | Train: Loss=0.6926, F1 Score=0.7071 | Val: Loss=0.5076, F1 Score=0.8314
# Epoch   5/300 | Train: Loss=0.5660, F1 Score=0.7796 | Val: Loss=0.3690, F1 Score=0.8931
# Epoch   6/300 | Train: Loss=0.4679, F1 Score=0.8244 | Val: Loss=0.2770, F1 Score=0.8994
# Epoch   7/300 | Train: Loss=0.4639, F1 Score=0.8248 | Val: Loss=0.3194, F1 Score=0.8972
# Epoch   8/300 | Train: Loss=0.3919, F1 Score=0.8537 | Val: Loss=0.3217, F1 Score=0.8885
# Epoch   9/300 | Train: Loss=0.3785, F1 Score=0.8570 | Val: Loss=0.3776, F1 Score=0.8731
# Epoch  10/300 | Train: Loss=0.3416, F1 Score=0.8722 | Val: Loss=0.4697, F1 Score=0.8369
# Epoch  11/300 | Train: Loss=0.3234, F1 Score=0.8837 | Val: Loss=0.3165, F1 Score=0.8935
# Epoch  12/300 | Train: Loss=0.3189, F1 Score=0.8809 | Val: Loss=0.2743, F1 Score=0.9211
# Epoch  13/300 | Train: Loss=0.2849, F1 Score=0.8987 | Val: Loss=0.3014, F1 Score=0.9025
# Epoch  14/300 | Train: Loss=0.2679, F1 Score=0.9007 | Val: Loss=0.3113, F1 Score=0.9056
# Epoch  15/300 | Train: Loss=0.2431, F1 Score=0.9155 | Val: Loss=0.4387, F1 Score=0.8512
# Epoch  16/300 | Train: Loss=0.2325, F1 Score=0.9148 | Val: Loss=0.2706, F1 Score=0.9098
# Epoch  17/300 | Train: Loss=0.2211, F1 Score=0.9209 | Val: Loss=0.3300, F1 Score=0.9096
# Epoch  18/300 | Train: Loss=0.2011, F1 Score=0.9228 | Val: Loss=0.3573, F1 Score=0.9004
# Epoch  19/300 | Train: Loss=0.1960, F1 Score=0.9260 | Val: Loss=0.2970, F1 Score=0.9270
# Epoch  20/300 | Train: Loss=0.1770, F1 Score=0.9340 | Val: Loss=0.4152, F1 Score=0.8933
# Epoch  21/300 | Train: Loss=0.1798, F1 Score=0.9370 | Val: Loss=0.2721, F1 Score=0.9040
# Epoch  22/300 | Train: Loss=0.1526, F1 Score=0.9447 | Val: Loss=0.3022, F1 Score=0.9272
# Epoch  23/300 | Train: Loss=0.1305, F1 Score=0.9551 | Val: Loss=0.2744, F1 Score=0.9335
# Epoch  24/300 | Train: Loss=0.1472, F1 Score=0.9480 | Val: Loss=0.2624, F1 Score=0.9412
# Epoch  25/300 | Train: Loss=0.1387, F1 Score=0.9535 | Val: Loss=0.2968, F1 Score=0.9153
# Epoch  26/300 | Train: Loss=0.1093, F1 Score=0.9644 | Val: Loss=0.2735, F1 Score=0.9288
# Epoch  27/300 | Train: Loss=0.1113, F1 Score=0.9641 | Val: Loss=0.3844, F1 Score=0.9222
# Epoch  28/300 | Train: Loss=0.1192, F1 Score=0.9584 | Val: Loss=0.6137, F1 Score=0.8509
# Epoch  29/300 | Train: Loss=0.1154, F1 Score=0.9588 | Val: Loss=0.2502, F1 Score=0.9313
# Epoch  30/300 | Train: Loss=0.1103, F1 Score=0.9622 | Val: Loss=0.2422, F1 Score=0.9420
# Epoch  31/300 | Train: Loss=0.0921, F1 Score=0.9699 | Val: Loss=0.3784, F1 Score=0.9235
# Epoch  32/300 | Train: Loss=0.1092, F1 Score=0.9583 | Val: Loss=0.3193, F1 Score=0.9277
# Epoch  33/300 | Train: Loss=0.0804, F1 Score=0.9712 | Val: Loss=0.3167, F1 Score=0.9280
# Epoch  34/300 | Train: Loss=0.0804, F1 Score=0.9749 | Val: Loss=0.2915, F1 Score=0.9359
# Epoch  35/300 | Train: Loss=0.0869, F1 Score=0.9690 | Val: Loss=0.3118, F1 Score=0.9301
# Epoch  36/300 | Train: Loss=0.0859, F1 Score=0.9698 | Val: Loss=0.2993, F1 Score=0.9295
# Epoch  37/300 | Train: Loss=0.0717, F1 Score=0.9748 | Val: Loss=0.2622, F1 Score=0.9319
# Epoch  38/300 | Train: Loss=0.0659, F1 Score=0.9756 | Val: Loss=0.3372, F1 Score=0.9357
# Epoch  39/300 | Train: Loss=0.0800, F1 Score=0.9728 | Val: Loss=0.2714, F1 Score=0.9335
# Epoch  40/300 | Train: Loss=0.0739, F1 Score=0.9742 | Val: Loss=0.2893, F1 Score=0.9339
# Epoch  41/300 | Train: Loss=0.0649, F1 Score=0.9797 | Val: Loss=0.4132, F1 Score=0.9150
# Epoch  42/300 | Train: Loss=0.0844, F1 Score=0.9706 | Val: Loss=0.7042, F1 Score=0.8160
# Epoch  43/300 | Train: Loss=0.1329, F1 Score=0.9570 | Val: Loss=0.2812, F1 Score=0.9059
# Epoch  44/300 | Train: Loss=0.0815, F1 Score=0.9725 | Val: Loss=0.2742, F1 Score=0.9278
# Epoch  45/300 | Train: Loss=0.0667, F1 Score=0.9765 | Val: Loss=0.2608, F1 Score=0.9259
# Epoch  46/300 | Train: Loss=0.0689, F1 Score=0.9765 | Val: Loss=0.2095, F1 Score=0.9404
# Epoch  47/300 | Train: Loss=0.0907, F1 Score=0.9680 | Val: Loss=0.3241, F1 Score=0.9321
# Epoch  48/300 | Train: Loss=0.0584, F1 Score=0.9803 | Val: Loss=0.2841, F1 Score=0.9268
# Epoch  49/300 | Train: Loss=0.0620, F1 Score=0.9796 | Val: Loss=0.2731, F1 Score=0.9415
# Epoch  50/300 | Train: Loss=0.0450, F1 Score=0.9848 | Val: Loss=0.2245, F1 Score=0.9329
# Epoch  51/300 | Train: Loss=0.0542, F1 Score=0.9799 | Val: Loss=0.2947, F1 Score=0.9390
# Epoch  52/300 | Train: Loss=0.0813, F1 Score=0.9746 | Val: Loss=0.2166, F1 Score=0.9288
# Epoch  53/300 | Train: Loss=0.0565, F1 Score=0.9814 | Val: Loss=0.2692, F1 Score=0.9301
# Epoch  54/300 | Train: Loss=0.0479, F1 Score=0.9817 | Val: Loss=0.2934, F1 Score=0.9293
# Epoch  55/300 | Train: Loss=0.0395, F1 Score=0.9861 | Val: Loss=0.2516, F1 Score=0.9443
# Epoch  56/300 | Train: Loss=0.0464, F1 Score=0.9847 | Val: Loss=0.3121, F1 Score=0.9308
# Epoch  57/300 | Train: Loss=0.0375, F1 Score=0.9874 | Val: Loss=0.4111, F1 Score=0.8977
# Epoch  58/300 | Train: Loss=0.0393, F1 Score=0.9870 | Val: Loss=0.2853, F1 Score=0.9408
# Epoch  59/300 | Train: Loss=0.0457, F1 Score=0.9836 | Val: Loss=0.2972, F1 Score=0.9353
# Epoch  60/300 | Train: Loss=0.0302, F1 Score=0.9902 | Val: Loss=0.2449, F1 Score=0.9448
# Epoch  61/300 | Train: Loss=0.0358, F1 Score=0.9878 | Val: Loss=0.3660, F1 Score=0.9171
# Epoch  62/300 | Train: Loss=0.0404, F1 Score=0.9862 | Val: Loss=0.2351, F1 Score=0.9432
# Epoch  63/300 | Train: Loss=0.0277, F1 Score=0.9908 | Val: Loss=0.2848, F1 Score=0.9526
# Epoch  64/300 | Train: Loss=0.0447, F1 Score=0.9858 | Val: Loss=0.3454, F1 Score=0.9270
# Epoch  65/300 | Train: Loss=0.0461, F1 Score=0.9845 | Val: Loss=0.2402, F1 Score=0.9442
# Epoch  66/300 | Train: Loss=0.0383, F1 Score=0.9864 | Val: Loss=0.3272, F1 Score=0.9408
# Epoch  67/300 | Train: Loss=0.0301, F1 Score=0.9889 | Val: Loss=0.2896, F1 Score=0.9469
# Epoch  68/300 | Train: Loss=0.0469, F1 Score=0.9851 | Val: Loss=0.3553, F1 Score=0.9433
# Epoch  69/300 | Train: Loss=0.0303, F1 Score=0.9895 | Val: Loss=0.3146, F1 Score=0.9479
# Epoch  70/300 | Train: Loss=0.0386, F1 Score=0.9889 | Val: Loss=0.7457, F1 Score=0.8371
# Epoch  71/300 | Train: Loss=0.0714, F1 Score=0.9805 | Val: Loss=0.4153, F1 Score=0.9258
# Epoch  72/300 | Train: Loss=0.0161, F1 Score=0.9942 | Val: Loss=0.4863, F1 Score=0.9327
# Epoch  73/300 | Train: Loss=0.0307, F1 Score=0.9909 | Val: Loss=0.4020, F1 Score=0.9261
# Epoch  74/300 | Train: Loss=0.0181, F1 Score=0.9932 | Val: Loss=0.2779, F1 Score=0.9516
# Epoch  75/300 | Train: Loss=0.0295, F1 Score=0.9918 | Val: Loss=0.4110, F1 Score=0.9143
# Epoch  76/300 | Train: Loss=0.0632, F1 Score=0.9801 | Val: Loss=0.3951, F1 Score=0.9391
# Epoch  77/300 | Train: Loss=0.0525, F1 Score=0.9855 | Val: Loss=0.3434, F1 Score=0.9164
# Epoch  78/300 | Train: Loss=0.0725, F1 Score=0.9787 | Val: Loss=0.5231, F1 Score=0.9043
# Epoch  79/300 | Train: Loss=0.0322, F1 Score=0.9895 | Val: Loss=0.3161, F1 Score=0.9341
# Epoch  80/300 | Train: Loss=0.0229, F1 Score=0.9923 | Val: Loss=0.2523, F1 Score=0.9499
# Epoch  81/300 | Train: Loss=0.0206, F1 Score=0.9925 | Val: Loss=0.3145, F1 Score=0.9461
# Epoch  82/300 | Train: Loss=0.0433, F1 Score=0.9885 | Val: Loss=0.3443, F1 Score=0.9382
# Epoch  83/300 | Train: Loss=0.0422, F1 Score=0.9874 | Val: Loss=0.2560, F1 Score=0.9544
# Epoch  84/300 | Train: Loss=0.0217, F1 Score=0.9932 | Val: Loss=0.3760, F1 Score=0.9434
# Epoch  85/300 | Train: Loss=0.0220, F1 Score=0.9933 | Val: Loss=0.5058, F1 Score=0.9151
# Epoch  86/300 | Train: Loss=0.0371, F1 Score=0.9896 | Val: Loss=0.4496, F1 Score=0.9337
# Epoch  87/300 | Train: Loss=0.0158, F1 Score=0.9940 | Val: Loss=0.3692, F1 Score=0.9500
# Epoch  88/300 | Train: Loss=0.0243, F1 Score=0.9936 | Val: Loss=0.3338, F1 Score=0.9461
# Epoch  89/300 | Train: Loss=0.0225, F1 Score=0.9936 | Val: Loss=0.5471, F1 Score=0.9142
# Epoch  90/300 | Train: Loss=0.0413, F1 Score=0.9874 | Val: Loss=0.4356, F1 Score=0.9262
# Epoch  91/300 | Train: Loss=0.0436, F1 Score=0.9874 | Val: Loss=0.2789, F1 Score=0.9512
# Epoch  92/300 | Train: Loss=0.0340, F1 Score=0.9891 | Val: Loss=0.2480, F1 Score=0.9431
# Epoch  93/300 | Train: Loss=0.0153, F1 Score=0.9946 | Val: Loss=0.3721, F1 Score=0.9399
# Epoch  94/300 | Train: Loss=0.0324, F1 Score=0.9906 | Val: Loss=0.3355, F1 Score=0.9274
# Epoch  95/300 | Train: Loss=0.0143, F1 Score=0.9946 | Val: Loss=0.3539, F1 Score=0.9401
# Epoch  96/300 | Train: Loss=0.0179, F1 Score=0.9950 | Val: Loss=0.4102, F1 Score=0.9288
# Epoch  97/300 | Train: Loss=0.0188, F1 Score=0.9952 | Val: Loss=0.3503, F1 Score=0.9384
# Epoch  98/300 | Train: Loss=0.0157, F1 Score=0.9949 | Val: Loss=0.4656, F1 Score=0.9251
# Epoch  99/300 | Train: Loss=0.0691, F1 Score=0.9820 | Val: Loss=0.3453, F1 Score=0.9347
# Epoch 100/300 | Train: Loss=0.0156, F1 Score=0.9949 | Val: Loss=0.4223, F1 Score=0.9386
# Epoch 101/300 | Train: Loss=0.0205, F1 Score=0.9930 | Val: Loss=0.2700, F1 Score=0.9266
# Epoch 102/300 | Train: Loss=0.0221, F1 Score=0.9923 | Val: Loss=0.3629, F1 Score=0.9355
# Epoch 103/300 | Train: Loss=0.0274, F1 Score=0.9932 | Val: Loss=0.3908, F1 Score=0.9478
# Epoch 104/300 | Train: Loss=0.0230, F1 Score=0.9925 | Val: Loss=0.7165, F1 Score=0.9153
# Epoch 105/300 | Train: Loss=0.0328, F1 Score=0.9896 | Val: Loss=0.3896, F1 Score=0.9223
# Epoch 106/300 | Train: Loss=0.0283, F1 Score=0.9901 | Val: Loss=0.3679, F1 Score=0.9449
# Epoch 107/300 | Train: Loss=0.0323, F1 Score=0.9904 | Val: Loss=0.2261, F1 Score=0.9594
# Epoch 108/300 | Train: Loss=0.0147, F1 Score=0.9948 | Val: Loss=0.4202, F1 Score=0.9256
# Epoch 109/300 | Train: Loss=0.0070, F1 Score=0.9979 | Val: Loss=0.3526, F1 Score=0.9410
# Epoch 110/300 | Train: Loss=0.0117, F1 Score=0.9960 | Val: Loss=0.4445, F1 Score=0.9378
# Epoch 111/300 | Train: Loss=0.0063, F1 Score=0.9986 | Val: Loss=0.3965, F1 Score=0.9453
# Epoch 112/300 | Train: Loss=0.0037, F1 Score=0.9990 | Val: Loss=0.3562, F1 Score=0.9388
# Epoch 113/300 | Train: Loss=0.0275, F1 Score=0.9935 | Val: Loss=0.5283, F1 Score=0.9247
# Epoch 114/300 | Train: Loss=0.0380, F1 Score=0.9895 | Val: Loss=0.6065, F1 Score=0.9118
# Epoch 115/300 | Train: Loss=0.0126, F1 Score=0.9966 | Val: Loss=0.4337, F1 Score=0.9350
# Epoch 116/300 | Train: Loss=0.0203, F1 Score=0.9926 | Val: Loss=0.3630, F1 Score=0.9506
# Epoch 117/300 | Train: Loss=0.0316, F1 Score=0.9911 | Val: Loss=0.4745, F1 Score=0.9394
# Epoch 118/300 | Train: Loss=0.0121, F1 Score=0.9963 | Val: Loss=0.4021, F1 Score=0.9520
# Epoch 119/300 | Train: Loss=0.0114, F1 Score=0.9966 | Val: Loss=0.3743, F1 Score=0.9336
# Epoch 120/300 | Train: Loss=0.0063, F1 Score=0.9977 | Val: Loss=0.5319, F1 Score=0.9262
# Epoch 121/300 | Train: Loss=0.0080, F1 Score=0.9974 | Val: Loss=0.5232, F1 Score=0.9328
# Epoch 122/300 | Train: Loss=0.0446, F1 Score=0.9881 | Val: Loss=0.3636, F1 Score=0.9599
# Epoch 123/300 | Train: Loss=0.0278, F1 Score=0.9913 | Val: Loss=0.2655, F1 Score=0.9543
# Epoch 124/300 | Train: Loss=0.0122, F1 Score=0.9963 | Val: Loss=0.3541, F1 Score=0.9607
# Epoch 125/300 | Train: Loss=0.0167, F1 Score=0.9949 | Val: Loss=0.3391, F1 Score=0.9500
# Epoch 126/300 | Train: Loss=0.0204, F1 Score=0.9947 | Val: Loss=0.2514, F1 Score=0.9569
# Epoch 127/300 | Train: Loss=0.0180, F1 Score=0.9939 | Val: Loss=0.3198, F1 Score=0.9540
# Epoch 128/300 | Train: Loss=0.0099, F1 Score=0.9966 | Val: Loss=0.3752, F1 Score=0.9376
# Epoch 129/300 | Train: Loss=0.0116, F1 Score=0.9965 | Val: Loss=0.3836, F1 Score=0.9461
# Epoch 130/300 | Train: Loss=0.0243, F1 Score=0.9939 | Val: Loss=0.4479, F1 Score=0.9422
# Epoch 131/300 | Train: Loss=0.0187, F1 Score=0.9943 | Val: Loss=0.4069, F1 Score=0.9430
# Epoch 132/300 | Train: Loss=0.0296, F1 Score=0.9919 | Val: Loss=0.5348, F1 Score=0.9280
# Epoch 133/300 | Train: Loss=0.0144, F1 Score=0.9942 | Val: Loss=0.3889, F1 Score=0.9510
# Epoch 134/300 | Train: Loss=0.0123, F1 Score=0.9955 | Val: Loss=0.4775, F1 Score=0.9389
# Epoch 135/300 | Train: Loss=0.0106, F1 Score=0.9960 | Val: Loss=0.3676, F1 Score=0.9540
# Epoch 136/300 | Train: Loss=0.0088, F1 Score=0.9973 | Val: Loss=0.3686, F1 Score=0.9409
# Epoch 137/300 | Train: Loss=0.0145, F1 Score=0.9955 | Val: Loss=0.4577, F1 Score=0.9300
# Epoch 138/300 | Train: Loss=0.0176, F1 Score=0.9956 | Val: Loss=0.3682, F1 Score=0.9498
# Epoch 139/300 | Train: Loss=0.0102, F1 Score=0.9966 | Val: Loss=0.4766, F1 Score=0.9471
# Epoch 140/300 | Train: Loss=0.0196, F1 Score=0.9945 | Val: Loss=0.3717, F1 Score=0.9421
# Epoch 141/300 | Train: Loss=0.0207, F1 Score=0.9939 | Val: Loss=0.3626, F1 Score=0.9365
# Epoch 142/300 | Train: Loss=0.0119, F1 Score=0.9972 | Val: Loss=0.4438, F1 Score=0.9406
# Epoch 143/300 | Train: Loss=0.0179, F1 Score=0.9960 | Val: Loss=0.3576, F1 Score=0.9511
# Epoch 144/300 | Train: Loss=0.0090, F1 Score=0.9967 | Val: Loss=0.4608, F1 Score=0.9436
# Epoch 145/300 | Train: Loss=0.0186, F1 Score=0.9940 | Val: Loss=0.6515, F1 Score=0.9235
# Epoch 146/300 | Train: Loss=0.0159, F1 Score=0.9965 | Val: Loss=0.4764, F1 Score=0.9334
# Epoch 147/300 | Train: Loss=0.0146, F1 Score=0.9963 | Val: Loss=0.3688, F1 Score=0.9489
# Epoch 148/300 | Train: Loss=0.0038, F1 Score=0.9990 | Val: Loss=0.3595, F1 Score=0.9503
# Epoch 149/300 | Train: Loss=0.0114, F1 Score=0.9965 | Val: Loss=0.4829, F1 Score=0.9373
# Epoch 150/300 | Train: Loss=0.0104, F1 Score=0.9972 | Val: Loss=0.4001, F1 Score=0.9425
# Epoch 151/300 | Train: Loss=0.0078, F1 Score=0.9986 | Val: Loss=0.5033, F1 Score=0.9238
# Epoch 152/300 | Train: Loss=0.0037, F1 Score=0.9990 | Val: Loss=0.3642, F1 Score=0.9514
# Epoch 153/300 | Train: Loss=0.0197, F1 Score=0.9949 | Val: Loss=0.3711, F1 Score=0.9351
# Epoch 154/300 | Train: Loss=0.0125, F1 Score=0.9965 | Val: Loss=0.4109, F1 Score=0.9459
# Epoch 155/300 | Train: Loss=0.0141, F1 Score=0.9955 | Val: Loss=0.7136, F1 Score=0.8926
# Epoch 156/300 | Train: Loss=0.0199, F1 Score=0.9945 | Val: Loss=0.3114, F1 Score=0.9522
# Epoch 157/300 | Train: Loss=0.0163, F1 Score=0.9949 | Val: Loss=0.3536, F1 Score=0.9432
# Epoch 158/300 | Train: Loss=0.0211, F1 Score=0.9936 | Val: Loss=0.4814, F1 Score=0.9310
# Epoch 159/300 | Train: Loss=0.0077, F1 Score=0.9977 | Val: Loss=0.6145, F1 Score=0.9259
# Epoch 160/300 | Train: Loss=0.0051, F1 Score=0.9979 | Val: Loss=0.4757, F1 Score=0.9367
# Epoch 161/300 | Train: Loss=0.0015, F1 Score=0.9997 | Val: Loss=0.6291, F1 Score=0.9284
# Epoch 162/300 | Train: Loss=0.0038, F1 Score=0.9990 | Val: Loss=0.5179, F1 Score=0.9334
# Epoch 163/300 | Train: Loss=0.0091, F1 Score=0.9973 | Val: Loss=0.3503, F1 Score=0.9467
# Epoch 164/300 | Train: Loss=0.0159, F1 Score=0.9959 | Val: Loss=0.4074, F1 Score=0.9491
# Epoch 165/300 | Train: Loss=0.0173, F1 Score=0.9943 | Val: Loss=0.3644, F1 Score=0.9345
# Epoch 166/300 | Train: Loss=0.0183, F1 Score=0.9955 | Val: Loss=0.4024, F1 Score=0.9536
# Epoch 167/300 | Train: Loss=0.0138, F1 Score=0.9969 | Val: Loss=0.4565, F1 Score=0.9450
# Epoch 168/300 | Train: Loss=0.0026, F1 Score=0.9991 | Val: Loss=0.3326, F1 Score=0.9570
# Epoch 169/300 | Train: Loss=0.0163, F1 Score=0.9953 | Val: Loss=0.5330, F1 Score=0.9289
# Epoch 170/300 | Train: Loss=0.0192, F1 Score=0.9942 | Val: Loss=0.3374, F1 Score=0.9267
# Epoch 171/300 | Train: Loss=0.0060, F1 Score=0.9977 | Val: Loss=0.4018, F1 Score=0.9434
# Epoch 172/300 | Train: Loss=0.0108, F1 Score=0.9963 | Val: Loss=0.4694, F1 Score=0.9392
# Epoch 173/300 | Train: Loss=0.0021, F1 Score=0.9996 | Val: Loss=0.4369, F1 Score=0.9366
# Epoch 174/300 | Train: Loss=0.0015, F1 Score=0.9996 | Val: Loss=0.5232, F1 Score=0.9320
# Early stopping triggered after 174 epochs.
# Best model restored from epoch 124 with val_f1 0.9607
# Best score: 0.9563±0.0127
# CPU times: user 9min 58s, sys: 1min 37s, total: 11min 36s
# Wall time: 13min 18s

# %%
# @title Plot History
# Create figure with two subplots sharing x axis
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 5), sharex=True)

# Color palette for K splits
colors = plt.cm.get_cmap('tab10', K)

# Plot validation loss for each split
for split in range(K):
    axes[0].plot(losses[f'split_{split}'][:-PATIENCE], label=f'Split {split+1}',
                 color=colors(split), alpha=0.6)
axes[0].set_title('Validation Loss per Split')
axes[0].set_ylabel('Loss')
axes[0].set_xlabel('Epoch')
axes[0].grid(alpha=0.3)

# Plot validation F1 score for each split
for split in range(K):
    axes[1].plot(metrics[f'split_{split}'][:-PATIENCE], label=f'Split {split+1}',
                 color=colors(split), alpha=0.6)
axes[1].set_title('Validation F1 Score per Split')
axes[1].set_ylabel('F1 Score')
axes[1].set_xlabel('Epoch')
axes[1].grid(alpha=0.3)

# Add shared legend on the right
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='small')

# Adjust layout
plt.tight_layout()
plt.subplots_adjust(right=0.975)
plt.show()
